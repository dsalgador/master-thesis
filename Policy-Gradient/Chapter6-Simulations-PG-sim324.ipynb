# %%
""" 
The algorithm is tested on the PDSystemEnv  gym task 
and developed with Tensorflow

Author: Daniel Salgado Rojo
"""

import tensorflow as tf
import numpy as np
import gym
import gym_pdsystem
from gym import wrappers
#import tflearn
import argparse
import pprint as pp

#from ddpg.replay_buffer import ReplayBuffer

from datetime import datetime

import random

from gym_pdsystem.envs.pdsystem_env import PDSystemEnv
import gym_pdsystem.utils.utilsq as ut
import gym_pdsystem.utils.constants as ct
import gym_pdsystem.utils.functions as fnc


from matplotlib import animation, rc
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import HTML


import pandas as pd
import time

from functools import partial

import os

#TO OMMIT WARNINGS
import warnings
warnings.filterwarnings('ignore')

def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)
    
simulations_directory = './simulations'
if not os.path.exists(simulations_directory):
    os.makedirs(simulations_directory)
# Out:
# /home/dsalgador/anaconda3/envs/tensorflow/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # System's parmeters

# %%
# In order to change the parameters of the system, such as number of shops, trucks, etc, one must change
# the corresponding constants in the 'constants.py' file from the 'gym pd_system' package.

CASE = ct.CASE
STOCHASTIC = ct.STOCHASTIC 

###########################################################

TANK_MAX_LOADS = ct.TANK_MAX_LOADS
LEVEL_PERCENTAGES = ct.LEVEL_PERCENTAGES 
TRUCK_MAX_LOADS = ct.TRUCK_MAX_LOADS
GRAPH_WEIGHTS = ct.GRAPH_WEIGHTS 
DISCRETE = ct.DISCRETE

n = len(TANK_MAX_LOADS)
k = len(TRUCK_MAX_LOADS)

env = gym.make("PDSystemEnv-v0")
episode_length = 30
env._max_episode_steps = episode_length

###########################################################

print("System with k={} trucks and n={} shops. Episodes of {} days.".format(k,n,episode_length))
# Out:
# System with k=2 trucks and n=5 shops. Episodes of 30 days.

# %%
import utils_pg
from utils_pg import int_to_action
from utils_pg import action_to_int
from utils_pg import discount_rewards
from utils_pg import normalize_rewards

# %% [markdown]
# # Tensorflow graph (DNN) for MC Policy Gradient Algorithm

# %%
simulation_id = 324

# Create directories for the simulations' outputs

simulation_directory = './simulations/simulation{}'.format(simulation_id)
rewards_file = simulation_directory+'/discrewards'+ '/rewards-sim{}.csv'.format(simulation_id)
states_file = simulation_directory+'/vis'+ '/states-sim{}.csv'.format(simulation_id) # for testing
models_dir = simulation_directory + '/NN-models'

if not os.path.exists(simulation_directory):
    os.makedirs(simulation_directory)
    os.makedirs(models_dir)
    os.makedirs(simulation_directory + '/discrewards')
    os.makedirs(simulation_directory + '/vis')
    
else:
    raise Exception("The simulation id you tried to use has been already used before. Try to change it to a new one.")

# Output headers to file
with open(rewards_file,'w') as f:
     np.savetxt(f, [["iteration", "discreward"]], fmt="%s", delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-1d631f995ebe> in <module>()
#      15
#      16 else:
# ---> 17     raise Exception("The simulation id you tried to use has been already used before. Try to change it to a new one.")
#      18
#      19 # Output headers to file
#
# Exception: The simulation id you tried to use has been already used before. Try to change it to a new one.

# %%
seed = 42
reset_graph(seed)

################################
# TensorBoard summary directories
now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
root_logdir = "tf_logs"
logdir = "{}/run-{}/".format(root_logdir, now)   
################################

## DNN hyperparameters ################
learning_rate = 0.01 #0.01

hidden1_neurons = 100 #100
hidden2_neurons = 50 #50

# batch_normalization = True  
# batch_norm_momentum = 0.9
######################################



######################################
#### Training hyperparameters ########
######################################
# File names for the model

model_file = models_dir + "/pdenv_policy_net_pg.ckpt"#.format(learning_rate)
best_model_file = models_dir + "/pdenv_best_policy_net_pg.ckpt"#.format(learning_rate)
graph_file =  '{}.meta'.format(model_file)


# Simulation / Training parameters
n_games_per_update = 10
n_max_steps = episode_length
n_iterations = 10**5 #2*10**4
save_iterations = 100 # USEFUL WHEN USING EARLY STOPPING
discount_rate = 0.9

info_freq = 100 #100
round_time = 2
round_reward = 6
summary_freq = 20#int(info_freq/2), 10

# Early stopping
max_checks_without_progress = np.inf # 10,  one for each "info_freq" (in terms of iterations it would be
                                                            #max_checks_without_progress *  info_freq)
checks_without_progress = 0
best_reward = -np.infty


retrain = False
########################################



###### TENSORFLOW GRAPH #########
tf.set_random_seed(seed)
with tf.name_scope("dnn"):
        
            # 1. Parameters to determine the NN architecture

            n_inputs = env.observation_space.shape[1]
            n_hidden1 = hidden1_neurons; activation1 = tf.nn.sigmoid#tf.nn.elu
            n_hidden2 = hidden2_neurons; activation2 = tf.nn.sigmoid#tf.nn.elu
            n_outputs = env.action_space.shape[1]**env.action_space.shape[0]
            
            he_init = tf.contrib.layers.variance_scaling_initializer(seed = seed)

            X = tf.placeholder(tf.float32, shape = (None, n_inputs), name = "X")
            
                    
            hidden1 = tf.layers.dense(X, n_hidden1, activation = activation1,
                                     kernel_initializer = he_init)
            hidden2 = tf.layers.dense(hidden1, n_hidden2, activation = activation2,
                                     kernel_initializer = he_init)
            logits = tf.layers.dense(hidden2, n_outputs, name = "logits"
                                     ,kernel_initializer = he_init)
            
            outputs = tf.nn.softmax(logits)
                   
            
with tf.name_scope("action"):
            # 3. Select a random action (where to go) based on the estimated probabilities
            action = tf.multinomial(tf.log(outputs), num_samples = 1)
            test_action = tf.argmax(outputs, axis = 1)
  
            y = tf.reshape(action, [1])
            
with tf.name_scope("loss"):
            xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels = y,logits = logits)
            loss = tf.reduce_mean(xentropy, name = "loss")
            
tf.summary.scalar('average_cross_entropy', loss)


with tf.name_scope("train"):
            # Optimization Op
            optimizer = tf.train.AdamOptimizer(learning_rate)
            
            grads_and_vars = optimizer.compute_gradients(xentropy)
            gradients = [grad for grad, variable in grads_and_vars]
            gradient_placeholders = []
            grads_and_vars_feed = []
            for grad, variable in grads_and_vars:
                gradient_placeholder = tf.placeholder(tf.float32, shape=grad.get_shape())
                gradient_placeholders.append(gradient_placeholder)
                grads_and_vars_feed.append((gradient_placeholder, variable))
            training_op = optimizer.apply_gradients(grads_and_vars_feed)
                        
                                       
merged = tf.summary.merge_all()
init = tf.global_variables_initializer()
file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
        
saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From /home/dsalgador/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %% [markdown]
# # PG Training

# %%
# with tf.Session() as sess:
    
#     #train_writer = tf.summary.FileWriter(logdir + '/pgtrain', sess.graph)
#     if retrain:
#         saver.restore(sess, model_file)
        
#     summary2 = tf.Summary()
#     if not retrain:
#         init.run()
#     time_start = time.time()

#     for iteration in range(n_iterations+1):
#         print("\rIteration: {}".format(iteration), end="")
#         all_rewards = []
#         all_gradients = []
#         for game in range(n_games_per_update):
#             current_rewards = []
#             current_gradients = []
#             obs = env.reset()
#             for step in range(n_max_steps):
#                 action_val, gradients_val = sess.run([action, gradients], feed_dict={X: obs.reshape(1, n_inputs)}) 
#                 #print(action_val)
#                 vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
#                 #print(vect_action)
#                 obs, reward, done, info = env.step(vect_action)
#                 current_rewards.append(reward)
#                 current_gradients.append(gradients_val)                
                
#                 if done:
#                     break
#             all_rewards.append(current_rewards)
#             all_gradients.append(current_gradients)
            
        
#         all_disc_rewards =  [discount_rewards(rewards, discount_rate) for rewards in all_rewards]
#         all_disc_norm_rewards = normalize_rewards(all_disc_rewards)     

#         feed_dict = {}
#         for var_index, gradient_placeholder in enumerate(gradient_placeholders):
#             mean_gradients = np.mean([reward * all_gradients[game_index][step][var_index]
#                                       for game_index, rewards in enumerate(all_disc_norm_rewards)
#                                           for step, reward in enumerate(rewards)], axis=0)
#             feed_dict[gradient_placeholder] = mean_gradients
         
       
#         #tf.summary.scalar('avg_rewards', avg_rewards)
#         #train_writer.add_summary(avg_rewards, iteration)

#         # Summary and info printings     ###################################################################
#         if iteration % info_freq == 0 or iteration % summary_freq == 0:  
            
#             #avg_rewards =np.array([np.mean(np.array(all_rewards)) / n_games_per_update])
#             avg_rewards =np.mean(np.array(all_disc_rewards)) / n_games_per_update
# #             print(avg_rewards)
#             #avg_rewards_list.append(avg_rewards)
#             if iteration % summary_freq == 0:
#                 summary2.value.add(tag='average_reward_per_game', simple_value = avg_rewards)
#                 file_writer.add_summary(summary2, iteration)

#                 feed_dict[X] = obs.reshape(1, n_inputs)
#                 summary = sess.run(merged, feed_dict= feed_dict)

#                 file_writer.add_summary(summary, iteration)
                
#                   # Disc rewards, etc ####
       
#                 with open(rewards_file,'ab') as f:
#                             np.savetxt(f, [np.array([iteration,  avg_rewards])], fmt=("%d",'%.10f'), delimiter=',') 

#             if iteration % info_freq == 0:
#                 time_end = time.time()
#                 print(". Average reward per game: ",  round(avg_rewards, round_reward), 
#                       ", Elapsed time ", round( (time_end-time_start)/60., round_time), " minutes.") 
                
                
#         ###########################################################################      
                
#         if avg_rewards > best_reward:
#                     saver.save(sess, best_model_file)
#                     print("Saved Model with average discounted rewards per game ", avg_rewards)
#                     best_reward = avg_rewards
#                     checks_without_progress = 0
#         else:
#                     checks_without_progress += 1
#                     if checks_without_progress > max_checks_without_progress:
#                         print("Early stopping!")
#                         break
#         ####################################################################################################
#         if iteration % save_iterations == 0:
#                  saver.save(sess, model_file)
        
#         sess.run(training_op, feed_dict=feed_dict)
    
#     #saver.save(sess, model_file + "final")
#     file_writer.flush()
#     file_writer.close()
                 
#     time_end = time.time()
#     print("Simulation finished. Elapsed time ", round( (time_end-time_start)/60., round_time), " minutes.")
# Out:
# Iteration: 0. Average reward per game:  -1.849614 , Elapsed time  0.0  minutes.
# Saved Model with average discounted rewards per game  -1.849613936456694
# Iteration: 20Saved Model with average discounted rewards per game  -1.1657467280189986
# Iteration: 40Saved Model with average discounted rewards per game  -0.83577557251988
# Iteration: 60Saved Model with average discounted rewards per game  -0.8217773165218905
# Iteration: 80Saved Model with average discounted rewards per game  -0.49139386249629347
# Iteration: 100. Average reward per game:  -0.423246 , Elapsed time  0.5  minutes.
# Saved Model with average discounted rewards per game  -0.42324555292242605
# Iteration: 120Saved Model with average discounted rewards per game  -0.27837468056466635
# Iteration: 140Saved Model with average discounted rewards per game  -0.26688700636341994
# Iteration: 160Saved Model with average discounted rewards per game  -0.12156529605322967
# Iteration: 200. Average reward per game:  -0.108005 , Elapsed time  1.01  minutes.
# Saved Model with average discounted rewards per game  -0.10800523764135923
# Iteration: 220Saved Model with average discounted rewards per game  -0.10426159127874246
# Iteration: 260Saved Model with average discounted rewards per game  -0.0716963597983835
# Iteration: 280Saved Model with average discounted rewards per game  -0.0667308704616912
# Iteration: 300. Average reward per game:  -0.070066 , Elapsed time  1.59  minutes.
# Iteration: 320Saved Model with average discounted rewards per game  -0.06063294706809404
# Iteration: 340Saved Model with average discounted rewards per game  -0.04962750780047047
# Iteration: 400. Average reward per game:  -0.099903 , Elapsed time  2.22  minutes.
# Iteration: 460Saved Model with average discounted rewards per game  -0.04776088269545088
# Iteration: 500. Average reward per game:  -0.08247 , Elapsed time  3.06  minutes.
# Iteration: 600. Average reward per game:  -0.038326 , Elapsed time  3.84  minutes.
# Saved Model with average discounted rewards per game  -0.03832644532174175
# Iteration: 700. Average reward per game:  -0.044807 , Elapsed time  4.45  minutes.
# Iteration: 720Saved Model with average discounted rewards per game  -0.024819899646877322
# Iteration: 800. Average reward per game:  -0.054407 , Elapsed time  5.09  minutes.
# Iteration: 900. Average reward per game:  -0.082502 , Elapsed time  5.77  minutes.
# Iteration: 1000. Average reward per game:  -0.050934 , Elapsed time  6.43  minutes.
# Iteration: 1100. Average reward per game:  -0.074741 , Elapsed time  7.02  minutes.
# Iteration: 1200. Average reward per game:  -0.063664 , Elapsed time  7.64  minutes.
# Iteration: 1300. Average reward per game:  -0.056093 , Elapsed time  8.26  minutes.
# Iteration: 1400. Average reward per game:  -0.0719 , Elapsed time  8.9  minutes.
# Iteration: 1500. Average reward per game:  -0.037654 , Elapsed time  9.42  minutes.
# Iteration: 1600. Average reward per game:  -0.055323 , Elapsed time  10.09  minutes.
# Iteration: 1700. Average reward per game:  -0.055299 , Elapsed time  10.6  minutes.
# Iteration: 1740Saved Model with average discounted rewards per game  -0.01923265881981554
# Iteration: 1800. Average reward per game:  -0.068719 , Elapsed time  11.24  minutes.
# Iteration: 1900. Average reward per game:  -0.036048 , Elapsed time  12.06  minutes.
# Iteration: 2000. Average reward per game:  -0.039827 , Elapsed time  12.7  minutes.
# Iteration: 2100. Average reward per game:  -0.085821 , Elapsed time  13.53  minutes.
# Iteration: 2200. Average reward per game:  -0.052877 , Elapsed time  14.12  minutes.
# Iteration: 2300. Average reward per game:  -0.071204 , Elapsed time  14.85  minutes.
# Iteration: 2400. Average reward per game:  -0.079868 , Elapsed time  15.57  minutes.
# Iteration: 2500. Average reward per game:  -0.062389 , Elapsed time  16.14  minutes.
# Iteration: 2600. Average reward per game:  -0.058244 , Elapsed time  16.9  minutes.
# Iteration: 2700. Average reward per game:  -0.044867 , Elapsed time  17.68  minutes.
# Iteration: 2800. Average reward per game:  -0.033791 , Elapsed time  18.25  minutes.
# Iteration: 2900. Average reward per game:  -0.061454 , Elapsed time  19.01  minutes.
# Iteration: 3000. Average reward per game:  -0.07688 , Elapsed time  19.57  minutes.
# Iteration: 3100. Average reward per game:  -0.093092 , Elapsed time  20.27  minutes.
# Iteration: 3200. Average reward per game:  -0.041517 , Elapsed time  20.88  minutes.
# Iteration: 3300. Average reward per game:  -0.051048 , Elapsed time  21.65  minutes.
# Iteration: 3400. Average reward per game:  -0.048314 , Elapsed time  22.47  minutes.
# Iteration: 3500. Average reward per game:  -0.072411 , Elapsed time  23.28  minutes.
# Iteration: 3600. Average reward per game:  -0.049826 , Elapsed time  24.13  minutes.
# Iteration: 3700. Average reward per game:  -0.028623 , Elapsed time  24.7  minutes.
# Iteration: 3800. Average reward per game:  -0.04345 , Elapsed time  25.25  minutes.
# Iteration: 3900. Average reward per game:  -0.143692 , Elapsed time  25.92  minutes.
# Iteration: 4000. Average reward per game:  -0.048465 , Elapsed time  26.73  minutes.
# Iteration: 4100. Average reward per game:  -0.043604 , Elapsed time  27.56  minutes.
# Iteration: 4200. Average reward per game:  -0.061511 , Elapsed time  28.36  minutes.
# Iteration: 4280Saved Model with average discounted rewards per game  -0.015724585130774536
# Iteration: 4300. Average reward per game:  -0.050366 , Elapsed time  28.93  minutes.
# Iteration: 4380Saved Model with average discounted rewards per game  -0.011775128716580771
# Iteration: 4400. Average reward per game:  -0.035637 , Elapsed time  29.75  minutes.
# Iteration: 4500. Average reward per game:  -0.044419 , Elapsed time  30.39  minutes.
# Iteration: 4600. Average reward per game:  -0.043936 , Elapsed time  31.15  minutes.
# Iteration: 4700. Average reward per game:  -0.031915 , Elapsed time  31.77  minutes.
# Iteration: 4800. Average reward per game:  -0.055256 , Elapsed time  32.64  minutes.
# Iteration: 4900. Average reward per game:  -0.109377 , Elapsed time  33.41  minutes.
# Iteration: 5000. Average reward per game:  -0.037074 , Elapsed time  33.96  minutes.
# Iteration: 5100. Average reward per game:  -0.063824 , Elapsed time  34.62  minutes.
# Iteration: 5200. Average reward per game:  -0.044837 , Elapsed time  35.22  minutes.
# Iteration: 5300. Average reward per game:  -0.038213 , Elapsed time  35.79  minutes.
# Iteration: 5400. Average reward per game:  -0.028701 , Elapsed time  36.49  minutes.
# Iteration: 5500. Average reward per game:  -0.033381 , Elapsed time  37.16  minutes.
# Iteration: 5600. Average reward per game:  -0.020586 , Elapsed time  37.87  minutes.
# Iteration: 5700. Average reward per game:  -0.054636 , Elapsed time  38.63  minutes.
# Iteration: 5800. Average reward per game:  -0.031045 , Elapsed time  39.23  minutes.
# Iteration: 5900. Average reward per game:  -0.032029 , Elapsed time  39.92  minutes.
# Iteration: 6000. Average reward per game:  -0.111327 , Elapsed time  40.53  minutes.
# Iteration: 6100. Average reward per game:  -0.044999 , Elapsed time  41.07  minutes.
# Iteration: 6200. Average reward per game:  -0.019724 , Elapsed time  41.78  minutes.
# Iteration: 6300. Average reward per game:  -0.024954 , Elapsed time  42.37  minutes.
# Iteration: 6400. Average reward per game:  -0.046006 , Elapsed time  43.17  minutes.
# Iteration: 6500. Average reward per game:  -0.026972 , Elapsed time  43.75  minutes.
# Iteration: 6600. Average reward per game:  -0.145526 , Elapsed time  44.44  minutes.
# Iteration: 6700. Average reward per game:  -0.03329 , Elapsed time  45.09  minutes.
# Iteration: 6800. Average reward per game:  -0.040456 , Elapsed time  45.68  minutes.
# Iteration: 6900. Average reward per game:  -0.065224 , Elapsed time  46.31  minutes.
# Iteration: 7000. Average reward per game:  -0.035004 , Elapsed time  46.85  minutes.
# Iteration: 7100. Average reward per game:  -0.040637 , Elapsed time  47.6  minutes.
# Iteration: 7200. Average reward per game:  -0.053455 , Elapsed time  48.36  minutes.
# Iteration: 7300. Average reward per game:  -0.04607 , Elapsed time  48.85  minutes.
# Iteration: 7400. Average reward per game:  -0.029097 , Elapsed time  49.45  minutes.
# Iteration: 7500. Average reward per game:  -0.06296 , Elapsed time  49.99  minutes.
# Iteration: 7600. Average reward per game:  -0.026594 , Elapsed time  50.5  minutes.
# Iteration: 7700. Average reward per game:  -0.032523 , Elapsed time  51.05  minutes.
# Iteration: 7800. Average reward per game:  -0.024297 , Elapsed time  51.81  minutes.
# Iteration: 7900. Average reward per game:  -0.01849 , Elapsed time  52.43  minutes.
# Iteration: 8000. Average reward per game:  -0.066251 , Elapsed time  53.09  minutes.
# Iteration: 8100. Average reward per game:  -0.046885 , Elapsed time  53.63  minutes.
# Iteration: 8200. Average reward per game:  -0.093982 , Elapsed time  54.32  minutes.
# Iteration: 8300. Average reward per game:  -0.029087 , Elapsed time  55.08  minutes.
# Iteration: 8400. Average reward per game:  -0.060511 , Elapsed time  55.67  minutes.
# Iteration: 8500. Average reward per game:  -0.035668 , Elapsed time  56.24  minutes.
# Iteration: 8600. Average reward per game:  -0.052589 , Elapsed time  56.79  minutes.
# Iteration: 8700. Average reward per game:  -0.035509 , Elapsed time  57.36  minutes.
# Iteration: 8800. Average reward per game:  -0.033674 , Elapsed time  58.12  minutes.
# Iteration: 8900. Average reward per game:  -0.027975 , Elapsed time  58.9  minutes.
# Iteration: 9000. Average reward per game:  -0.038062 , Elapsed time  59.48  minutes.
# Iteration: 9100. Average reward per game:  -0.034268 , Elapsed time  60.22  minutes.
# Iteration: 9200. Average reward per game:  -0.029214 , Elapsed time  60.75  minutes.
# Iteration: 9300. Average reward per game:  -0.04929 , Elapsed time  61.44  minutes.
# Iteration: 9400. Average reward per game:  -0.084992 , Elapsed time  62.12  minutes.
# Iteration: 9500. Average reward per game:  -0.044927 , Elapsed time  62.7  minutes.
# Iteration: 9600. Average reward per game:  -0.095012 , Elapsed time  63.27  minutes.
# Iteration: 9700. Average reward per game:  -0.027026 , Elapsed time  63.81  minutes.
# Iteration: 9800. Average reward per game:  -0.029366 , Elapsed time  64.55  minutes.
# Iteration: 9900. Average reward per game:  -0.038164 , Elapsed time  65.3  minutes.
# Iteration: 10000. Average reward per game:  -0.126001 , Elapsed time  65.83  minutes.
# Iteration: 10100. Average reward per game:  -0.073172 , Elapsed time  66.44  minutes.
# Iteration: 10200. Average reward per game:  -0.025765 , Elapsed time  66.94  minutes.
# Iteration: 10300. Average reward per game:  -0.052313 , Elapsed time  67.57  minutes.
# Iteration: 10400. Average reward per game:  -0.082117 , Elapsed time  68.2  minutes.
# Iteration: 10500. Average reward per game:  -0.066331 , Elapsed time  68.89  minutes.
# Iteration: 10600. Average reward per game:  -0.041322 , Elapsed time  69.55  minutes.
# Iteration: 10700. Average reward per game:  -0.025923 , Elapsed time  70.14  minutes.
# Iteration: 10800. Average reward per game:  -0.02937 , Elapsed time  70.69  minutes.
# Iteration: 10900. Average reward per game:  -0.039015 , Elapsed time  71.24  minutes.
# Iteration: 11000. Average reward per game:  -0.067386 , Elapsed time  72.0  minutes.
# Iteration: 11100. Average reward per game:  -0.056395 , Elapsed time  72.56  minutes.
# Iteration: 11200. Average reward per game:  -0.033148 , Elapsed time  73.08  minutes.
# Iteration: 11300. Average reward per game:  -0.050618 , Elapsed time  73.76  minutes.
# Iteration: 11400. Average reward per game:  -0.048831 , Elapsed time  74.41  minutes.
# Iteration: 11500. Average reward per game:  -0.048858 , Elapsed time  75.08  minutes.
# Iteration: 11600. Average reward per game:  -0.078936 , Elapsed time  75.67  minutes.
# Iteration: 11700. Average reward per game:  -0.024235 , Elapsed time  76.3  minutes.
# Iteration: 11800. Average reward per game:  -0.046175 , Elapsed time  76.85  minutes.
# Iteration: 11900. Average reward per game:  -0.050439 , Elapsed time  77.52  minutes.
# Iteration: 12000. Average reward per game:  -0.098629 , Elapsed time  78.12  minutes.
# Iteration: 12100. Average reward per game:  -0.023892 , Elapsed time  78.75  minutes.
# Iteration: 12200. Average reward per game:  -0.048977 , Elapsed time  79.33  minutes.
# Iteration: 12300. Average reward per game:  -0.056829 , Elapsed time  79.89  minutes.
# Iteration: 12400. Average reward per game:  -0.038433 , Elapsed time  80.56  minutes.
# Iteration: 12500. Average reward per game:  -0.062328 , Elapsed time  81.13  minutes.
# Iteration: 12600. Average reward per game:  -0.067208 , Elapsed time  81.78  minutes.
# Iteration: 12700. Average reward per game:  -0.034483 , Elapsed time  82.41  minutes.
# Iteration: 12800. Average reward per game:  -0.130069 , Elapsed time  82.94  minutes.
# Iteration: 12900. Average reward per game:  -0.030821 , Elapsed time  83.62  minutes.
# Iteration: 13000. Average reward per game:  -0.03045 , Elapsed time  84.19  minutes.
# Iteration: 13100. Average reward per game:  -0.039629 , Elapsed time  84.89  minutes.
# Iteration: 13200. Average reward per game:  -0.032682 , Elapsed time  85.52  minutes.
# Iteration: 13300. Average reward per game:  -0.030569 , Elapsed time  86.03  minutes.
# Iteration: 13400. Average reward per game:  -0.067927 , Elapsed time  86.69  minutes.
# Iteration: 13500. Average reward per game:  -0.030634 , Elapsed time  87.33  minutes.
# Iteration: 13600. Average reward per game:  -0.025968 , Elapsed time  87.91  minutes.
# Iteration: 13700. Average reward per game:  -0.031211 , Elapsed time  88.42  minutes.
# Iteration: 13800. Average reward per game:  -0.061938 , Elapsed time  89.08  minutes.
# Iteration: 13900. Average reward per game:  -0.058213 , Elapsed time  89.64  minutes.
# Iteration: 14000. Average reward per game:  -0.03509 , Elapsed time  90.29  minutes.
# Iteration: 14100. Average reward per game:  -0.030067 , Elapsed time  90.86  minutes.
# Iteration: 14120Saved Model with average discounted rewards per game  -0.009054803347043866
# Iteration: 14200. Average reward per game:  -0.055983 , Elapsed time  91.44  minutes.
# Iteration: 14300. Average reward per game:  -0.077598 , Elapsed time  92.19  minutes.
# Iteration: 14400. Average reward per game:  -0.008933 , Elapsed time  92.75  minutes.
# Saved Model with average discounted rewards per game  -0.008932694598614262
# Iteration: 14500. Average reward per game:  -0.042604 , Elapsed time  93.51  minutes.
# Iteration: 14600. Average reward per game:  -0.042696 , Elapsed time  94.16  minutes.
# Iteration: 14700. Average reward per game:  -0.008431 , Elapsed time  94.8  minutes.
# Saved Model with average discounted rewards per game  -0.008431483015816744
# Iteration: 14800. Average reward per game:  -0.06026 , Elapsed time  95.35  minutes.
# Iteration: 14900. Average reward per game:  -0.041338 , Elapsed time  96.06  minutes.
# Iteration: 15000. Average reward per game:  -0.03446 , Elapsed time  96.64  minutes.
# Iteration: 15100. Average reward per game:  -0.043789 , Elapsed time  97.19  minutes.
# Iteration: 15200. Average reward per game:  -0.049391 , Elapsed time  97.84  minutes.
# Iteration: 15300. Average reward per game:  -0.041464 , Elapsed time  98.38  minutes.
# Iteration: 15400. Average reward per game:  -0.030641 , Elapsed time  99.12  minutes.
# Iteration: 15500. Average reward per game:  -0.045971 , Elapsed time  99.68  minutes.
# Iteration: 15600. Average reward per game:  -0.031649 , Elapsed time  100.42  minutes.
# Iteration: 15700. Average reward per game:  -0.054884 , Elapsed time  101.02  minutes.
# Iteration: 15800. Average reward per game:  -0.038929 , Elapsed time  101.69  minutes.
# Iteration: 15900. Average reward per game:  -0.066425 , Elapsed time  102.21  minutes.
# Iteration: 16000. Average reward per game:  -0.053289 , Elapsed time  102.76  minutes.
# Iteration: 16100. Average reward per game:  -0.033023 , Elapsed time  103.49  minutes.
# Iteration: 16200. Average reward per game:  -0.027751 , Elapsed time  104.19  minutes.
# Iteration: 16300. Average reward per game:  -0.028557 , Elapsed time  104.83  minutes.
# Iteration: 16400. Average reward per game:  -0.028956 , Elapsed time  105.36  minutes.
# Iteration: 16500. Average reward per game:  -0.040219 , Elapsed time  105.97  minutes.
# Iteration: 16600. Average reward per game:  -0.057991 , Elapsed time  106.66  minutes.
# Iteration: 16700. Average reward per game:  -0.035979 , Elapsed time  107.26  minutes.
# Iteration: 16800. Average reward per game:  -0.054696 , Elapsed time  107.9  minutes.
# Iteration: 16900. Average reward per game:  -0.027394 , Elapsed time  108.44  minutes.
# Iteration: 17000. Average reward per game:  -0.024066 , Elapsed time  109.07  minutes.
# Iteration: 17100. Average reward per game:  -0.020765 , Elapsed time  109.73  minutes.
# Iteration: 17200. Average reward per game:  -0.062326 , Elapsed time  110.33  minutes.
# Iteration: 17300. Average reward per game:  -0.037457 , Elapsed time  110.95  minutes.
# Iteration: 17400. Average reward per game:  -0.057426 , Elapsed time  111.56  minutes.
# Iteration: 17500. Average reward per game:  -0.030731 , Elapsed time  112.31  minutes.
# Iteration: 17600. Average reward per game:  -0.023956 , Elapsed time  112.83  minutes.
# Iteration: 17700. Average reward per game:  -0.035587 , Elapsed time  113.58  minutes.
# Iteration: 17800. Average reward per game:  -0.078141 , Elapsed time  114.21  minutes.
# Iteration: 17900. Average reward per game:  -0.079598 , Elapsed time  114.74  minutes.
# Iteration: 18000. Average reward per game:  -0.017814 , Elapsed time  115.43  minutes.
# Iteration: 18100. Average reward per game:  -0.033659 , Elapsed time  116.02  minutes.
# Iteration: 18200. Average reward per game:  -0.046897 , Elapsed time  116.82  minutes.
# Iteration: 18300. Average reward per game:  -0.042143 , Elapsed time  117.68  minutes.
# Iteration: 18400. Average reward per game:  -0.010502 , Elapsed time  118.46  minutes.
# Iteration: 18500. Average reward per game:  -0.042894 , Elapsed time  119.01  minutes.
# Iteration: 18600. Average reward per game:  -0.033874 , Elapsed time  119.78  minutes.
# Iteration: 18700. Average reward per game:  -0.048392 , Elapsed time  120.4  minutes.
# Iteration: 18800. Average reward per game:  -0.042789 , Elapsed time  121.01  minutes.
# Iteration: 18900. Average reward per game:  -0.054734 , Elapsed time  121.77  minutes.
# Iteration: 19000. Average reward per game:  -0.033794 , Elapsed time  122.38  minutes.
# Iteration: 19100. Average reward per game:  -0.051031 , Elapsed time  122.92  minutes.
# Iteration: 19200. Average reward per game:  -0.039377 , Elapsed time  123.47  minutes.
# Iteration: 19300. Average reward per game:  -0.037327 , Elapsed time  124.22  minutes.
# Iteration: 19400. Average reward per game:  -0.052356 , Elapsed time  125.0  minutes.
# Iteration: 19500. Average reward per game:  -0.038854 , Elapsed time  125.79  minutes.
# Iteration: 19600. Average reward per game:  -0.033154 , Elapsed time  126.58  minutes.
# Iteration: 19700. Average reward per game:  -0.01693 , Elapsed time  127.48  minutes.
# Iteration: 19800. Average reward per game:  -0.046655 , Elapsed time  128.35  minutes.
# Iteration: 19900. Average reward per game:  -0.059973 , Elapsed time  128.96  minutes.
# Iteration: 20000. Average reward per game:  -0.039479 , Elapsed time  129.67  minutes.
# Iteration: 20100. Average reward per game:  -0.026557 , Elapsed time  130.24  minutes.
# Iteration: 20200. Average reward per game:  -0.090919 , Elapsed time  130.87  minutes.
# Iteration: 20300. Average reward per game:  -0.017038 , Elapsed time  131.58  minutes.
# Iteration: 20400. Average reward per game:  -0.086003 , Elapsed time  132.13  minutes.
# Iteration: 20500. Average reward per game:  -0.04195 , Elapsed time  132.75  minutes.
# Iteration: 20600. Average reward per game:  -0.029601 , Elapsed time  133.26  minutes.
# Iteration: 20700. Average reward per game:  -0.078135 , Elapsed time  133.78  minutes.
# Iteration: 20800. Average reward per game:  -0.03668 , Elapsed time  134.3  minutes.
# Iteration: 20900. Average reward per game:  -0.03128 , Elapsed time  134.87  minutes.
# Iteration: 21000. Average reward per game:  -0.046233 , Elapsed time  135.63  minutes.
# Iteration: 21100. Average reward per game:  -0.053017 , Elapsed time  136.23  minutes.
# Iteration: 21200. Average reward per game:  -0.032586 , Elapsed time  136.78  minutes.
# Iteration: 21300. Average reward per game:  -0.046861 , Elapsed time  137.38  minutes.
# Iteration: 21400. Average reward per game:  -0.025877 , Elapsed time  137.96  minutes.
# Iteration: 21500. Average reward per game:  -0.054002 , Elapsed time  138.54  minutes.
# Iteration: 21600. Average reward per game:  -0.022998 , Elapsed time  139.09  minutes.
# Iteration: 21700. Average reward per game:  -0.033012 , Elapsed time  139.65  minutes.
# Iteration: 21800. Average reward per game:  -0.0374 , Elapsed time  140.21  minutes.
# Iteration: 21900. Average reward per game:  -0.049586 , Elapsed time  140.75  minutes.
# Iteration: 22000. Average reward per game:  -0.032756 , Elapsed time  141.29  minutes.
# Iteration: 22100. Average reward per game:  -0.026291 , Elapsed time  141.81  minutes.
# Iteration: 22200. Average reward per game:  -0.031044 , Elapsed time  142.36  minutes.
# Iteration: 22300. Average reward per game:  -0.044365 , Elapsed time  142.95  minutes.
# Iteration: 22400. Average reward per game:  -0.031173 , Elapsed time  143.53  minutes.
# Iteration: 22500. Average reward per game:  -0.035992 , Elapsed time  144.1  minutes.
# Iteration: 22600. Average reward per game:  -0.016479 , Elapsed time  144.71  minutes.
# Iteration: 22700. Average reward per game:  -0.013848 , Elapsed time  145.21  minutes.
# Iteration: 22800. Average reward per game:  -0.049523 , Elapsed time  145.74  minutes.
# Iteration: 22900. Average reward per game:  -0.039371 , Elapsed time  146.3  minutes.
# Iteration: 23000. Average reward per game:  -0.079264 , Elapsed time  146.88  minutes.
# Iteration: 23100. Average reward per game:  -0.018957 , Elapsed time  147.44  minutes.
# Iteration: 23200. Average reward per game:  -0.058599 , Elapsed time  147.99  minutes.
# Iteration: 23240Saved Model with average discounted rewards per game  -0.007933637457734125
# Iteration: 23300. Average reward per game:  -0.035596 , Elapsed time  148.58  minutes.
# Iteration: 23400. Average reward per game:  -0.04131 , Elapsed time  149.13  minutes.
# Iteration: 23500. Average reward per game:  -0.035441 , Elapsed time  149.7  minutes.
# Iteration: 23600. Average reward per game:  -0.013344 , Elapsed time  150.27  minutes.
# Iteration: 23700. Average reward per game:  -0.056926 , Elapsed time  150.83  minutes.
# Iteration: 23800. Average reward per game:  -0.024529 , Elapsed time  151.45  minutes.
# Iteration: 23900. Average reward per game:  -0.036497 , Elapsed time  152.03  minutes.
# Iteration: 24000. Average reward per game:  -0.039751 , Elapsed time  152.62  minutes.
# Iteration: 24100. Average reward per game:  -0.072095 , Elapsed time  153.17  minutes.
# Iteration: 24200. Average reward per game:  -0.060482 , Elapsed time  153.76  minutes.
# Iteration: 24300. Average reward per game:  -0.028794 , Elapsed time  154.35  minutes.
# Iteration: 24400. Average reward per game:  -0.068165 , Elapsed time  154.91  minutes.
# Iteration: 24500. Average reward per game:  -0.069046 , Elapsed time  155.48  minutes.
# Iteration: 24600. Average reward per game:  -0.046235 , Elapsed time  156.06  minutes.
# Iteration: 24700. Average reward per game:  -0.04046 , Elapsed time  156.62  minutes.
# Iteration: 24800. Average reward per game:  -0.049013 , Elapsed time  157.19  minutes.
# Iteration: 24900. Average reward per game:  -0.037655 , Elapsed time  157.79  minutes.
# Iteration: 25000. Average reward per game:  -0.042777 , Elapsed time  158.38  minutes.
# Iteration: 25100. Average reward per game:  -0.06103 , Elapsed time  158.98  minutes.
# Iteration: 25200. Average reward per game:  -0.023526 , Elapsed time  159.58  minutes.
# Iteration: 25300. Average reward per game:  -0.062726 , Elapsed time  160.16  minutes.
# Iteration: 25380Saved Model with average discounted rewards per game  -0.0055257698513078565
# Iteration: 25400. Average reward per game:  -0.076722 , Elapsed time  160.75  minutes.
# Iteration: 25500. Average reward per game:  -0.020452 , Elapsed time  161.34  minutes.
# Iteration: 25600. Average reward per game:  -0.01921 , Elapsed time  161.92  minutes.
# Iteration: 25700. Average reward per game:  -0.031265 , Elapsed time  162.51  minutes.
# Iteration: 25800. Average reward per game:  -0.022307 , Elapsed time  163.07  minutes.
# Iteration: 25900. Average reward per game:  -0.018786 , Elapsed time  163.63  minutes.
# Iteration: 26000. Average reward per game:  -0.031022 , Elapsed time  164.22  minutes.
# Iteration: 26100. Average reward per game:  -0.04468 , Elapsed time  164.8  minutes.
# Iteration: 26200. Average reward per game:  -0.02948 , Elapsed time  165.38  minutes.
# Iteration: 26300. Average reward per game:  -0.03451 , Elapsed time  165.97  minutes.
# Iteration: 26400. Average reward per game:  -0.009235 , Elapsed time  166.53  minutes.
# Iteration: 26500. Average reward per game:  -0.049035 , Elapsed time  167.11  minutes.
# Iteration: 26600. Average reward per game:  -0.033219 , Elapsed time  167.72  minutes.
# Iteration: 26700. Average reward per game:  -0.016592 , Elapsed time  168.33  minutes.
# Iteration: 26800. Average reward per game:  -0.056505 , Elapsed time  168.92  minutes.
# Iteration: 26900. Average reward per game:  -0.036699 , Elapsed time  169.61  minutes.
# Iteration: 27000. Average reward per game:  -0.02094 , Elapsed time  170.29  minutes.
# Iteration: 27100. Average reward per game:  -0.075164 , Elapsed time  170.95  minutes.
# Iteration: 27200. Average reward per game:  -0.02766 , Elapsed time  171.73  minutes.
# Iteration: 27300. Average reward per game:  -0.032657 , Elapsed time  172.56  minutes.
# Iteration: 27400. Average reward per game:  -0.022607 , Elapsed time  173.34  minutes.
# Iteration: 27500. Average reward per game:  -0.017983 , Elapsed time  174.12  minutes.
# Iteration: 27600. Average reward per game:  -0.062146 , Elapsed time  174.95  minutes.
# Iteration: 27700. Average reward per game:  -0.050796 , Elapsed time  175.81  minutes.
# Iteration: 27800. Average reward per game:  -0.057552 , Elapsed time  176.61  minutes.
# Iteration: 27900. Average reward per game:  -0.022275 , Elapsed time  177.39  minutes.
# Iteration: 28000. Average reward per game:  -0.03536 , Elapsed time  178.06  minutes.
# Iteration: 28100. Average reward per game:  -0.03423 , Elapsed time  178.73  minutes.
# Iteration: 28200. Average reward per game:  -0.017574 , Elapsed time  179.4  minutes.
# Iteration: 28300. Average reward per game:  -0.058399 , Elapsed time  180.05  minutes.
# Iteration: 28400. Average reward per game:  -0.027723 , Elapsed time  180.72  minutes.
# Iteration: 28500. Average reward per game:  -0.083117 , Elapsed time  181.39  minutes.
# Iteration: 28600. Average reward per game:  -0.023464 , Elapsed time  182.05  minutes.
# Iteration: 28700. Average reward per game:  -0.07033 , Elapsed time  182.74  minutes.
# Iteration: 28800. Average reward per game:  -0.046418 , Elapsed time  183.4  minutes.
# Iteration: 28840Saved Model with average discounted rewards per game  -0.002761688366658449
# Iteration: 28900. Average reward per game:  -0.026601 , Elapsed time  184.2  minutes.
# Iteration: 29000. Average reward per game:  -0.02254 , Elapsed time  184.89  minutes.
# Iteration: 29100. Average reward per game:  -0.028494 , Elapsed time  185.54  minutes.
# Iteration: 29200. Average reward per game:  -0.019369 , Elapsed time  186.19  minutes.
# Iteration: 29300. Average reward per game:  -0.047064 , Elapsed time  186.87  minutes.
# Iteration: 29400. Average reward per game:  -0.067461 , Elapsed time  187.56  minutes.
# Iteration: 29500. Average reward per game:  -0.031851 , Elapsed time  188.24  minutes.
# Iteration: 29600. Average reward per game:  -0.070314 , Elapsed time  188.98  minutes.
# Iteration: 29700. Average reward per game:  -0.044873 , Elapsed time  189.75  minutes.
# Iteration: 29800. Average reward per game:  -0.011766 , Elapsed time  190.67  minutes.
# Iteration: 29900. Average reward per game:  -0.030689 , Elapsed time  191.43  minutes.
# Iteration: 30000. Average reward per game:  -0.020184 , Elapsed time  192.17  minutes.
# Iteration: 30100. Average reward per game:  -0.039107 , Elapsed time  193.0  minutes.
# Iteration: 30200. Average reward per game:  -0.028747 , Elapsed time  193.76  minutes.
# Iteration: 30300. Average reward per game:  -0.020724 , Elapsed time  194.58  minutes.
# Iteration: 30400. Average reward per game:  -0.043912 , Elapsed time  195.33  minutes.
# Iteration: 30500. Average reward per game:  -0.051465 , Elapsed time  196.03  minutes.
# Iteration: 30600. Average reward per game:  -0.021792 , Elapsed time  196.81  minutes.
# Iteration: 30700. Average reward per game:  -0.058616 , Elapsed time  197.5  minutes.
# Iteration: 30800. Average reward per game:  -0.025559 , Elapsed time  198.26  minutes.
# Iteration: 30900. Average reward per game:  -0.01801 , Elapsed time  199.04  minutes.
# Iteration: 31000. Average reward per game:  -0.041179 , Elapsed time  199.84  minutes.
# Iteration: 31100. Average reward per game:  -0.056194 , Elapsed time  200.67  minutes.
# Iteration: 31200. Average reward per game:  -0.029738 , Elapsed time  201.4  minutes.
# Iteration: 31300. Average reward per game:  -0.049648 , Elapsed time  202.11  minutes.
# Iteration: 31400. Average reward per game:  -0.08086 , Elapsed time  202.8  minutes.
# Iteration: 31500. Average reward per game:  -0.05756 , Elapsed time  203.45  minutes.
# Iteration: 31600. Average reward per game:  -0.021603 , Elapsed time  204.15  minutes.
# Iteration: 31700. Average reward per game:  -0.028823 , Elapsed time  204.91  minutes.
# Iteration: 31800. Average reward per game:  -0.031685 , Elapsed time  205.67  minutes.
# Iteration: 31900. Average reward per game:  -0.032335 , Elapsed time  206.42  minutes.
# Iteration: 32000. Average reward per game:  -0.022445 , Elapsed time  207.12  minutes.
# Iteration: 32100. Average reward per game:  -0.045064 , Elapsed time  207.79  minutes.
# Iteration: 32200. Average reward per game:  -0.053984 , Elapsed time  208.45  minutes.
# Iteration: 32300. Average reward per game:  -0.039146 , Elapsed time  209.14  minutes.
# Iteration: 32400. Average reward per game:  -0.026618 , Elapsed time  209.88  minutes.
# Iteration: 32500. Average reward per game:  -0.051186 , Elapsed time  210.61  minutes.
# Iteration: 32600. Average reward per game:  -0.037983 , Elapsed time  211.56  minutes.
# Iteration: 32700. Average reward per game:  -0.041186 , Elapsed time  212.39  minutes.
# Iteration: 32800. Average reward per game:  -0.025193 , Elapsed time  213.17  minutes.
# Iteration: 32900. Average reward per game:  -0.051337 , Elapsed time  213.98  minutes.
# Iteration: 33000. Average reward per game:  -0.03824 , Elapsed time  214.72  minutes.
# Iteration: 33100. Average reward per game:  -0.038565 , Elapsed time  215.5  minutes.
# Iteration: 33200. Average reward per game:  -0.021747 , Elapsed time  216.27  minutes.
# Iteration: 33300. Average reward per game:  -0.02447 , Elapsed time  217.07  minutes.
# Iteration: 33400. Average reward per game:  -0.030581 , Elapsed time  217.78  minutes.
# Iteration: 33500. Average reward per game:  -0.036264 , Elapsed time  218.48  minutes.
# Iteration: 33600. Average reward per game:  -0.042373 , Elapsed time  219.14  minutes.
# Iteration: 33700. Average reward per game:  -0.035335 , Elapsed time  219.83  minutes.
# Iteration: 33800. Average reward per game:  -0.034083 , Elapsed time  220.47  minutes.
# Iteration: 33900. Average reward per game:  -0.039256 , Elapsed time  221.05  minutes.
# Iteration: 34000. Average reward per game:  -0.030087 , Elapsed time  221.68  minutes.
# Iteration: 34100. Average reward per game:  -0.028471 , Elapsed time  222.29  minutes.
# Iteration: 34200. Average reward per game:  -0.04175 , Elapsed time  222.9  minutes.
# Iteration: 34300. Average reward per game:  -0.040477 , Elapsed time  223.51  minutes.
# Iteration: 34400. Average reward per game:  -0.046428 , Elapsed time  224.04  minutes.
# Iteration: 34500. Average reward per game:  -0.025758 , Elapsed time  224.65  minutes.
# Iteration: 34600. Average reward per game:  -0.035233 , Elapsed time  225.25  minutes.
# Iteration: 34700. Average reward per game:  -0.033681 , Elapsed time  225.86  minutes.
# Iteration: 34800. Average reward per game:  -0.032786 , Elapsed time  226.5  minutes.
# Iteration: 34900. Average reward per game:  -0.016629 , Elapsed time  227.12  minutes.
# Iteration: 35000. Average reward per game:  -0.02609 , Elapsed time  227.78  minutes.
# Iteration: 35100. Average reward per game:  -0.035571 , Elapsed time  228.34  minutes.
# Iteration: 35200. Average reward per game:  -0.027891 , Elapsed time  228.95  minutes.
# Iteration: 35300. Average reward per game:  -0.042475 , Elapsed time  229.55  minutes.
# Iteration: 35400. Average reward per game:  -0.018887 , Elapsed time  230.16  minutes.
# Iteration: 35500. Average reward per game:  -0.036513 , Elapsed time  230.75  minutes.
# Iteration: 35600. Average reward per game:  -0.060603 , Elapsed time  231.33  minutes.
# Iteration: 35700. Average reward per game:  -0.024351 , Elapsed time  231.97  minutes.
# Iteration: 35800. Average reward per game:  -0.044172 , Elapsed time  232.59  minutes.
# Iteration: 35900. Average reward per game:  -0.039925 , Elapsed time  233.22  minutes.
# Iteration: 36000. Average reward per game:  -0.048898 , Elapsed time  233.84  minutes.
# Iteration: 36100. Average reward per game:  -0.031583 , Elapsed time  234.43  minutes.
# Iteration: 36200. Average reward per game:  -0.038983 , Elapsed time  235.04  minutes.
# Iteration: 36300. Average reward per game:  -0.04156 , Elapsed time  235.67  minutes.
# Iteration: 36400. Average reward per game:  -0.039246 , Elapsed time  236.34  minutes.
# Iteration: 36500. Average reward per game:  -0.079008 , Elapsed time  237.01  minutes.
# Iteration: 36600. Average reward per game:  -0.031661 , Elapsed time  237.71  minutes.
# Iteration: 36700. Average reward per game:  -0.029943 , Elapsed time  238.36  minutes.
# Iteration: 36800. Average reward per game:  -0.025311 , Elapsed time  239.01  minutes.
# Iteration: 36900. Average reward per game:  -0.041026 , Elapsed time  239.73  minutes.
# Iteration: 37000. Average reward per game:  -0.030313 , Elapsed time  240.43  minutes.
# Iteration: 37100. Average reward per game:  -0.025084 , Elapsed time  241.13  minutes.
# Iteration: 37200. Average reward per game:  -0.04198 , Elapsed time  241.75  minutes.
# Iteration: 37300. Average reward per game:  -0.037306 , Elapsed time  242.42  minutes.
# Iteration: 37400. Average reward per game:  -0.032298 , Elapsed time  243.1  minutes.
# Iteration: 37500. Average reward per game:  -0.03449 , Elapsed time  243.73  minutes.
# Iteration: 37600. Average reward per game:  -0.025056 , Elapsed time  244.35  minutes.
# Iteration: 37700. Average reward per game:  -0.039099 , Elapsed time  244.95  minutes.
# Iteration: 37800. Average reward per game:  -0.052829 , Elapsed time  245.6  minutes.
# Iteration: 37900. Average reward per game:  -0.025316 , Elapsed time  246.28  minutes.
# Iteration: 38000. Average reward per game:  -0.063322 , Elapsed time  246.89  minutes.
# Iteration: 38100. Average reward per game:  -0.05176 , Elapsed time  247.52  minutes.
# Iteration: 38200. Average reward per game:  -0.062367 , Elapsed time  248.09  minutes.
# Iteration: 38300. Average reward per game:  -0.03945 , Elapsed time  248.7  minutes.
# Iteration: 38400. Average reward per game:  -0.053433 , Elapsed time  249.39  minutes.
# Iteration: 38500. Average reward per game:  -0.036522 , Elapsed time  250.05  minutes.
# Iteration: 38600. Average reward per game:  -0.027739 , Elapsed time  250.74  minutes.
# Iteration: 38700. Average reward per game:  -0.04708 , Elapsed time  251.4  minutes.
# Iteration: 38800. Average reward per game:  -0.058121 , Elapsed time  252.06  minutes.
# Iteration: 38900. Average reward per game:  -0.02603 , Elapsed time  252.72  minutes.
# Iteration: 39000. Average reward per game:  -0.048834 , Elapsed time  253.38  minutes.
# Iteration: 39100. Average reward per game:  -0.04799 , Elapsed time  254.01  minutes.
# Iteration: 39200. Average reward per game:  -0.025465 , Elapsed time  254.73  minutes.
# Iteration: 39300. Average reward per game:  -0.034654 , Elapsed time  255.43  minutes.
# Iteration: 39400. Average reward per game:  -0.030001 , Elapsed time  256.16  minutes.
# Iteration: 39500. Average reward per game:  -0.020731 , Elapsed time  256.81  minutes.
# Iteration: 39600. Average reward per game:  -0.050024 , Elapsed time  257.42  minutes.
# Iteration: 39700. Average reward per game:  -0.052173 , Elapsed time  258.02  minutes.
# Iteration: 39800. Average reward per game:  -0.040563 , Elapsed time  258.62  minutes.
# Iteration: 39900. Average reward per game:  -0.038133 , Elapsed time  259.24  minutes.
# Iteration: 40000. Average reward per game:  -0.037394 , Elapsed time  259.86  minutes.
# Iteration: 40100. Average reward per game:  -0.019762 , Elapsed time  260.47  minutes.
# Iteration: 40200. Average reward per game:  -0.051626 , Elapsed time  261.08  minutes.
# Iteration: 40300. Average reward per game:  -0.027294 , Elapsed time  261.64  minutes.
# Iteration: 40400. Average reward per game:  -0.055862 , Elapsed time  262.26  minutes.
# Iteration: 40500. Average reward per game:  -0.100291 , Elapsed time  341.11  minutes.
# Iteration: 40600. Average reward per game:  -0.048128 , Elapsed time  341.57  minutes.
# Iteration: 40700. Average reward per game:  -0.105672 , Elapsed time  342.01  minutes.
# Iteration: 40800. Average reward per game:  -0.034521 , Elapsed time  342.46  minutes.
# Iteration: 40900. Average reward per game:  -0.054753 , Elapsed time  342.97  minutes.
# Iteration: 41000. Average reward per game:  -0.031599 , Elapsed time  343.53  minutes.
# Iteration: 41100. Average reward per game:  -0.041166 , Elapsed time  344.1  minutes.
# Iteration: 41200. Average reward per game:  -0.027896 , Elapsed time  344.66  minutes.
# Iteration: 41300. Average reward per game:  -0.019753 , Elapsed time  345.22  minutes.
# Iteration: 41400. Average reward per game:  -0.043416 , Elapsed time  345.78  minutes.
# Iteration: 41500. Average reward per game:  -0.026652 , Elapsed time  346.34  minutes.
# Iteration: 41600. Average reward per game:  -0.057405 , Elapsed time  346.9  minutes.
# Iteration: 41700. Average reward per game:  -0.034446 , Elapsed time  347.46  minutes.
# Iteration: 41800. Average reward per game:  -0.018291 , Elapsed time  348.01  minutes.
# Iteration: 41900. Average reward per game:  -0.021554 , Elapsed time  348.6  minutes.
# Iteration: 42000. Average reward per game:  -0.068679 , Elapsed time  349.18  minutes.
# Iteration: 42100. Average reward per game:  -0.0772 , Elapsed time  349.75  minutes.
# Iteration: 42200. Average reward per game:  -0.066695 , Elapsed time  350.36  minutes.
# Iteration: 42300. Average reward per game:  -0.041411 , Elapsed time  350.98  minutes.
# Iteration: 42400. Average reward per game:  -0.050156 , Elapsed time  351.65  minutes.
# Iteration: 42500. Average reward per game:  -0.068054 , Elapsed time  352.18  minutes.
# Iteration: 42600. Average reward per game:  -0.039605 , Elapsed time  352.88  minutes.
# Iteration: 42700. Average reward per game:  -0.048151 , Elapsed time  353.43  minutes.
# Iteration: 42800. Average reward per game:  -0.017997 , Elapsed time  354.09  minutes.
# Iteration: 42900. Average reward per game:  -0.046662 , Elapsed time  354.65  minutes.
# Iteration: 43000. Average reward per game:  -0.015365 , Elapsed time  355.21  minutes.
# Iteration: 43100. Average reward per game:  -0.021292 , Elapsed time  355.94  minutes.
# Iteration: 43200. Average reward per game:  -0.022499 , Elapsed time  356.52  minutes.
# Iteration: 43300. Average reward per game:  -0.012045 , Elapsed time  357.05  minutes.
# Iteration: 43400. Average reward per game:  -0.056837 , Elapsed time  357.63  minutes.
# Iteration: 43500. Average reward per game:  -0.0931 , Elapsed time  358.36  minutes.
# Iteration: 43600. Average reward per game:  -0.044472 , Elapsed time  358.98  minutes.
# Iteration: 43700. Average reward per game:  -0.065758 , Elapsed time  359.55  minutes.
# Iteration: 43800. Average reward per game:  -0.036043 , Elapsed time  360.16  minutes.
# Iteration: 43900. Average reward per game:  -0.046505 , Elapsed time  360.78  minutes.
# Iteration: 44000. Average reward per game:  -0.024962 , Elapsed time  361.63  minutes.
# Iteration: 44100. Average reward per game:  -0.082899 , Elapsed time  362.21  minutes.
# Iteration: 44200. Average reward per game:  -0.073725 , Elapsed time  362.78  minutes.
# Iteration: 44300. Average reward per game:  -0.036898 , Elapsed time  363.63  minutes.
# Iteration: 44400. Average reward per game:  -0.050161 , Elapsed time  364.31  minutes.
# Iteration: 44500. Average reward per game:  -0.0387 , Elapsed time  365.01  minutes.
# Iteration: 44600. Average reward per game:  -0.04821 , Elapsed time  365.56  minutes.
# Iteration: 44700. Average reward per game:  -0.032753 , Elapsed time  366.33  minutes.
# Iteration: 44800. Average reward per game:  -0.041283 , Elapsed time  367.02  minutes.
# Iteration: 44900. Average reward per game:  -0.055062 , Elapsed time  367.75  minutes.
# Iteration: 45000. Average reward per game:  -0.035806 , Elapsed time  368.36  minutes.
# Iteration: 45100. Average reward per game:  -0.071048 , Elapsed time  368.98  minutes.
# Iteration: 45200. Average reward per game:  -0.057366 , Elapsed time  369.68  minutes.
# Iteration: 45300. Average reward per game:  -0.114047 , Elapsed time  370.24  minutes.
# Iteration: 45400. Average reward per game:  -0.090625 , Elapsed time  370.95  minutes.
# Iteration: 45500. Average reward per game:  -0.096581 , Elapsed time  371.6  minutes.
# Iteration: 45600. Average reward per game:  -0.071531 , Elapsed time  372.25  minutes.
# Iteration: 45700. Average reward per game:  -0.037304 , Elapsed time  372.95  minutes.
# Iteration: 45800. Average reward per game:  -0.090129 , Elapsed time  373.6  minutes.
# Iteration: 45900. Average reward per game:  -0.136819 , Elapsed time  374.21  minutes.
# Iteration: 46000. Average reward per game:  -0.072855 , Elapsed time  374.81  minutes.
# Iteration: 46100. Average reward per game:  -0.033689 , Elapsed time  375.35  minutes.
# Iteration: 46200. Average reward per game:  -0.084932 , Elapsed time  376.04  minutes.
# Iteration: 46300. Average reward per game:  -0.071038 , Elapsed time  376.82  minutes.
# Iteration: 46400. Average reward per game:  -0.026171 , Elapsed time  377.45  minutes.
# Iteration: 46500. Average reward per game:  -0.039757 , Elapsed time  378.11  minutes.
# Iteration: 46600. Average reward per game:  -0.039938 , Elapsed time  378.81  minutes.
# Iteration: 46700. Average reward per game:  -0.029517 , Elapsed time  379.47  minutes.
# Iteration: 46800. Average reward per game:  -0.041373 , Elapsed time  380.09  minutes.
# Iteration: 46900. Average reward per game:  -0.024876 , Elapsed time  380.77  minutes.
# Iteration: 47000. Average reward per game:  -0.022191 , Elapsed time  381.55  minutes.
# Iteration: 47100. Average reward per game:  -0.028028 , Elapsed time  382.14  minutes.
# Iteration: 47200. Average reward per game:  -0.027627 , Elapsed time  382.83  minutes.
# Iteration: 47300. Average reward per game:  -0.033925 , Elapsed time  383.48  minutes.
# Iteration: 47400. Average reward per game:  -0.03083 , Elapsed time  384.26  minutes.
# Iteration: 47500. Average reward per game:  -0.026932 , Elapsed time  384.87  minutes.
# Iteration: 47600. Average reward per game:  -0.045418 , Elapsed time  385.51  minutes.
# Iteration: 47700. Average reward per game:  -0.027461 , Elapsed time  386.22  minutes.
# Iteration: 47800. Average reward per game:  -0.034781 , Elapsed time  386.86  minutes.
# Iteration: 47900. Average reward per game:  -0.045352 , Elapsed time  387.64  minutes.
# Iteration: 48000. Average reward per game:  -0.026786 , Elapsed time  388.26  minutes.
# Iteration: 48100. Average reward per game:  -0.056374 , Elapsed time  388.96  minutes.
# Iteration: 48200. Average reward per game:  -0.041891 , Elapsed time  389.59  minutes.
# Iteration: 48300. Average reward per game:  -0.046436 , Elapsed time  390.37  minutes.
# Iteration: 48400. Average reward per game:  -0.102376 , Elapsed time  390.98  minutes.
# Iteration: 48500. Average reward per game:  -0.060551 , Elapsed time  391.68  minutes.
# Iteration: 48600. Average reward per game:  -0.033073 , Elapsed time  392.42  minutes.
# Iteration: 48700. Average reward per game:  -0.056248 , Elapsed time  393.03  minutes.
# Iteration: 48800. Average reward per game:  -0.039406 , Elapsed time  393.75  minutes.
# Iteration: 48900. Average reward per game:  -0.02877 , Elapsed time  394.42  minutes.
# Iteration: 49000. Average reward per game:  -0.039793 , Elapsed time  395.02  minutes.
# Iteration: 49100. Average reward per game:  -0.065985 , Elapsed time  395.7  minutes.
# Iteration: 49200. Average reward per game:  -0.04171 , Elapsed time  396.39  minutes.
# Iteration: 49300. Average reward per game:  -0.057654 , Elapsed time  397.01  minutes.
# Iteration: 49400. Average reward per game:  -0.070524 , Elapsed time  397.8  minutes.
# Iteration: 49500. Average reward per game:  -0.062563 , Elapsed time  398.38  minutes.
# Iteration: 49600. Average reward per game:  -0.098463 , Elapsed time  399.05  minutes.
# Iteration: 49700. Average reward per game:  -0.031398 , Elapsed time  399.76  minutes.
# Iteration: 49800. Average reward per game:  -0.040065 , Elapsed time  400.31  minutes.
# Iteration: 49900. Average reward per game:  -0.026305 , Elapsed time  400.94  minutes.
# Iteration: 50000. Average reward per game:  -0.053805 , Elapsed time  401.7  minutes.
# Iteration: 50100. Average reward per game:  -0.058966 , Elapsed time  402.32  minutes.
# Iteration: 50200. Average reward per game:  -0.050569 , Elapsed time  403.11  minutes.
# Iteration: 50300. Average reward per game:  -0.02886 , Elapsed time  403.71  minutes.
# Iteration: 50400. Average reward per game:  -0.019391 , Elapsed time  404.51  minutes.
# Iteration: 50500. Average reward per game:  -0.062635 , Elapsed time  405.06  minutes.
# Iteration: 50600. Average reward per game:  -0.08738 , Elapsed time  405.82  minutes.
# Iteration: 50700. Average reward per game:  -0.026383 , Elapsed time  406.57  minutes.
# Iteration: 50800. Average reward per game:  -0.0517 , Elapsed time  407.2  minutes.
# Iteration: 50900. Average reward per game:  -0.036327 , Elapsed time  407.98  minutes.
# Iteration: 51000. Average reward per game:  -0.010527 , Elapsed time  408.51  minutes.
# Iteration: 51100. Average reward per game:  -0.035052 , Elapsed time  409.15  minutes.
# Iteration: 51200. Average reward per game:  -0.043887 , Elapsed time  409.72  minutes.
# Iteration: 51300. Average reward per game:  -0.097215 , Elapsed time  410.51  minutes.
# Iteration: 51400. Average reward per game:  -0.050377 , Elapsed time  411.24  minutes.
# Iteration: 51500. Average reward per game:  -0.0336 , Elapsed time  411.92  minutes.
# Iteration: 51600. Average reward per game:  -0.042416 , Elapsed time  412.71  minutes.
# Iteration: 51700. Average reward per game:  -0.022515 , Elapsed time  413.46  minutes.
# Iteration: 51800. Average reward per game:  -0.010095 , Elapsed time  414.0  minutes.
# Iteration: 51900. Average reward per game:  -0.035741 , Elapsed time  414.77  minutes.
# Iteration: 52000. Average reward per game:  -0.014876 , Elapsed time  415.55  minutes.
# Iteration: 52100. Average reward per game:  -0.040283 , Elapsed time  416.17  minutes.
# Iteration: 52200. Average reward per game:  -0.027179 , Elapsed time  416.93  minutes.
# Iteration: 52300. Average reward per game:  -0.036207 , Elapsed time  417.6  minutes.
# Iteration: 52400. Average reward per game:  -0.02425 , Elapsed time  418.34  minutes.
# Iteration: 52500. Average reward per game:  -0.035952 , Elapsed time  418.98  minutes.
# Iteration: 52600. Average reward per game:  -0.060041 , Elapsed time  419.74  minutes.
# Iteration: 52700. Average reward per game:  -0.040476 , Elapsed time  420.38  minutes.
# Iteration: 52800. Average reward per game:  -0.058137 , Elapsed time  421.15  minutes.
# ...
# Iteration: 81800. Average reward per game:  -0.019156 , Elapsed time  638.14  minutes.
# Iteration: 81900. Average reward per game:  -0.0503 , Elapsed time  638.77  minutes.
# Iteration: 82000. Average reward per game:  -0.022179 , Elapsed time  639.51  minutes.
# Iteration: 82100. Average reward per game:  -0.017762 , Elapsed time  640.18  minutes.
# Iteration: 82200. Average reward per game:  -0.032752 , Elapsed time  640.76  minutes.
# Iteration: 82300. Average reward per game:  -0.01506 , Elapsed time  641.53  minutes.
# Iteration: 82400. Average reward per game:  -0.020548 , Elapsed time  642.35  minutes.
# Iteration: 82500. Average reward per game:  -0.057778 , Elapsed time  643.18  minutes.
# Iteration: 82600. Average reward per game:  -0.059799 , Elapsed time  644.03  minutes.
# Iteration: 82700. Average reward per game:  -0.054675 , Elapsed time  644.87  minutes.
# Iteration: 82800. Average reward per game:  -0.075246 , Elapsed time  645.72  minutes.
# Iteration: 82900. Average reward per game:  -0.040892 , Elapsed time  646.53  minutes.
# Iteration: 83000. Average reward per game:  -0.032324 , Elapsed time  647.32  minutes.
# Iteration: 83100. Average reward per game:  -0.050029 , Elapsed time  648.16  minutes.
# Iteration: 83200. Average reward per game:  -0.015554 , Elapsed time  648.95  minutes.
# Iteration: 83300. Average reward per game:  -0.025991 , Elapsed time  649.76  minutes.
# Iteration: 83400. Average reward per game:  -0.031442 , Elapsed time  650.6  minutes.
# Iteration: 83500. Average reward per game:  -0.055822 , Elapsed time  651.44  minutes.
# Iteration: 83600. Average reward per game:  -0.078861 , Elapsed time  652.29  minutes.
# Iteration: 83700. Average reward per game:  -0.046396 , Elapsed time  653.13  minutes.
# Iteration: 83800. Average reward per game:  -0.073855 , Elapsed time  653.95  minutes.
# Iteration: 83900. Average reward per game:  -0.027533 , Elapsed time  654.79  minutes.
# Iteration: 84000. Average reward per game:  -0.092031 , Elapsed time  655.63  minutes.
# Iteration: 84100. Average reward per game:  -0.088828 , Elapsed time  656.46  minutes.
# Iteration: 84200. Average reward per game:  -0.079535 , Elapsed time  657.32  minutes.
# Iteration: 84300. Average reward per game:  -0.074654 , Elapsed time  658.1  minutes.
# Iteration: 84400. Average reward per game:  -0.034341 , Elapsed time  658.89  minutes.
# Iteration: 84500. Average reward per game:  -0.079652 , Elapsed time  659.71  minutes.
# Iteration: 84600. Average reward per game:  -0.053852 , Elapsed time  660.54  minutes.
# Iteration: 84700. Average reward per game:  -0.063181 , Elapsed time  661.39  minutes.
# Iteration: 84800. Average reward per game:  -0.081064 , Elapsed time  662.23  minutes.
# Iteration: 84900. Average reward per game:  -0.120454 , Elapsed time  663.07  minutes.
# Iteration: 85000. Average reward per game:  -0.107409 , Elapsed time  663.91  minutes.
# Iteration: 85100. Average reward per game:  -0.128083 , Elapsed time  664.76  minutes.
# Iteration: 85200. Average reward per game:  -0.076501 , Elapsed time  665.65  minutes.
# Iteration: 85300. Average reward per game:  -0.080187 , Elapsed time  666.5  minutes.
# Iteration: 85400. Average reward per game:  -0.071551 , Elapsed time  667.33  minutes.
# Iteration: 85500. Average reward per game:  -0.055773 , Elapsed time  668.13  minutes.
# Iteration: 85600. Average reward per game:  -0.029646 , Elapsed time  668.9  minutes.
# Iteration: 85700. Average reward per game:  -0.050434 , Elapsed time  669.71  minutes.
# Iteration: 85800. Average reward per game:  -0.071108 , Elapsed time  670.57  minutes.
# Iteration: 85900. Average reward per game:  -0.096917 , Elapsed time  671.42  minutes.
# Iteration: 86000. Average reward per game:  -0.050823 , Elapsed time  672.23  minutes.
# Iteration: 86100. Average reward per game:  -0.061934 , Elapsed time  673.02  minutes.
# Iteration: 86200. Average reward per game:  -0.035728 , Elapsed time  673.64  minutes.
# Iteration: 86300. Average reward per game:  -0.05685 , Elapsed time  674.29  minutes.
# Iteration: 86400. Average reward per game:  -0.032108 , Elapsed time  675.02  minutes.
# Iteration: 86500. Average reward per game:  -0.108118 , Elapsed time  675.58  minutes.
# Iteration: 86600. Average reward per game:  -0.125906 , Elapsed time  676.32  minutes.
# Iteration: 86700. Average reward per game:  -0.109788 , Elapsed time  676.93  minutes.
# Iteration: 86800. Average reward per game:  -0.088775 , Elapsed time  677.62  minutes.
# Iteration: 86900. Average reward per game:  -0.089384 , Elapsed time  678.39  minutes.
# Iteration: 87000. Average reward per game:  -0.037074 , Elapsed time  679.11  minutes.
# Iteration: 87100. Average reward per game:  -0.075329 , Elapsed time  679.86  minutes.
# Iteration: 87200. Average reward per game:  -0.039901 , Elapsed time  680.72  minutes.
# Iteration: 87300. Average reward per game:  -0.059844 , Elapsed time  681.56  minutes.
# Iteration: 87400. Average reward per game:  -0.050564 , Elapsed time  682.41  minutes.
# Iteration: 87500. Average reward per game:  -0.079028 , Elapsed time  683.26  minutes.
# Iteration: 87600. Average reward per game:  -0.067956 , Elapsed time  684.11  minutes.
# Iteration: 87700. Average reward per game:  -0.033083 , Elapsed time  684.94  minutes.
# Iteration: 87800. Average reward per game:  -0.071724 , Elapsed time  685.78  minutes.
# Iteration: 87900. Average reward per game:  -0.074827 , Elapsed time  686.63  minutes.
# Iteration: 88000. Average reward per game:  -0.07413 , Elapsed time  687.47  minutes.
# Iteration: 88100. Average reward per game:  -0.116958 , Elapsed time  688.32  minutes.
# Iteration: 88200. Average reward per game:  -0.069084 , Elapsed time  689.16  minutes.
# Iteration: 88300. Average reward per game:  -0.10211 , Elapsed time  689.99  minutes.
# Iteration: 88400. Average reward per game:  -0.075831 , Elapsed time  690.83  minutes.
# Iteration: 88500. Average reward per game:  -0.090435 , Elapsed time  691.67  minutes.
# Iteration: 88600. Average reward per game:  -0.073775 , Elapsed time  692.52  minutes.
# Iteration: 88700. Average reward per game:  -0.036653 , Elapsed time  693.37  minutes.
# Iteration: 88800. Average reward per game:  -0.053339 , Elapsed time  694.21  minutes.
# Iteration: 88900. Average reward per game:  -0.058967 , Elapsed time  695.06  minutes.
# Iteration: 89000. Average reward per game:  -0.072329 , Elapsed time  695.91  minutes.
# Iteration: 89100. Average reward per game:  -0.059989 , Elapsed time  696.75  minutes.
# Iteration: 89200. Average reward per game:  -0.123259 , Elapsed time  697.61  minutes.
# Iteration: 89300. Average reward per game:  -0.125231 , Elapsed time  698.47  minutes.
# Iteration: 89400. Average reward per game:  -0.130185 , Elapsed time  699.27  minutes.
# Iteration: 89500. Average reward per game:  -0.141917 , Elapsed time  700.06  minutes.
# Iteration: 89600. Average reward per game:  -0.162905 , Elapsed time  700.68  minutes.
# Iteration: 89700. Average reward per game:  -0.123454 , Elapsed time  701.4  minutes.
# Iteration: 89800. Average reward per game:  -0.080189 , Elapsed time  702.08  minutes.
# Iteration: 89900. Average reward per game:  -0.049201 , Elapsed time  702.71  minutes.
# Iteration: 90000. Average reward per game:  -0.061861 , Elapsed time  703.33  minutes.
# Iteration: 90100. Average reward per game:  -0.132009 , Elapsed time  703.96  minutes.
# Iteration: 90200. Average reward per game:  -0.068227 , Elapsed time  704.62  minutes.
# Iteration: 90300. Average reward per game:  -0.074682 , Elapsed time  705.31  minutes.
# Iteration: 90400. Average reward per game:  -0.074929 , Elapsed time  705.93  minutes.
# Iteration: 90500. Average reward per game:  -0.05013 , Elapsed time  706.53  minutes.
# Iteration: 90600. Average reward per game:  -0.185518 , Elapsed time  707.19  minutes.
# Iteration: 90700. Average reward per game:  -0.125549 , Elapsed time  707.9  minutes.
# Iteration: 90800. Average reward per game:  -0.080115 , Elapsed time  708.56  minutes.
# Iteration: 90900. Average reward per game:  -0.120051 , Elapsed time  709.18  minutes.
# Iteration: 91000. Average reward per game:  -0.115913 , Elapsed time  709.87  minutes.
# Iteration: 91100. Average reward per game:  -0.197906 , Elapsed time  710.56  minutes.
# Iteration: 91200. Average reward per game:  -0.118705 , Elapsed time  711.16  minutes.
# Iteration: 91300. Average reward per game:  -0.1457 , Elapsed time  711.79  minutes.
# Iteration: 91400. Average reward per game:  -0.081855 , Elapsed time  712.49  minutes.
# Iteration: 91500. Average reward per game:  -0.076448 , Elapsed time  713.12  minutes.
# Iteration: 91600. Average reward per game:  -0.063166 , Elapsed time  713.91  minutes.
# Iteration: 91700. Average reward per game:  -0.063128 , Elapsed time  714.54  minutes.
# Iteration: 91800. Average reward per game:  -0.068927 , Elapsed time  715.19  minutes.
# Iteration: 91900. Average reward per game:  -0.075446 , Elapsed time  715.75  minutes.
# Iteration: 92000. Average reward per game:  -0.072203 , Elapsed time  716.53  minutes.
# Iteration: 92100. Average reward per game:  -0.084936 , Elapsed time  717.19  minutes.
# Iteration: 92200. Average reward per game:  -0.083233 , Elapsed time  717.77  minutes.
# Iteration: 92300. Average reward per game:  -0.099327 , Elapsed time  718.48  minutes.
# Iteration: 92400. Average reward per game:  -0.1044 , Elapsed time  719.1  minutes.
# Iteration: 92500. Average reward per game:  -0.074587 , Elapsed time  719.84  minutes.
# Iteration: 92600. Average reward per game:  -0.069464 , Elapsed time  720.4  minutes.
# Iteration: 92700. Average reward per game:  -0.085063 , Elapsed time  721.07  minutes.
# Iteration: 92800. Average reward per game:  -0.093902 , Elapsed time  721.71  minutes.
# Iteration: 92900. Average reward per game:  -0.065465 , Elapsed time  722.38  minutes.
# Iteration: 93000. Average reward per game:  -0.087724 , Elapsed time  723.11  minutes.
# Iteration: 93100. Average reward per game:  -0.042005 , Elapsed time  723.72  minutes.
# Iteration: 93200. Average reward per game:  -0.055632 , Elapsed time  724.5  minutes.
# Iteration: 93300. Average reward per game:  -0.087928 , Elapsed time  725.05  minutes.
# Iteration: 93400. Average reward per game:  -0.073613 , Elapsed time  725.84  minutes.
# Iteration: 93500. Average reward per game:  -0.054507 , Elapsed time  726.4  minutes.
# Iteration: 93600. Average reward per game:  -0.070946 , Elapsed time  727.17  minutes.
# Iteration: 93700. Average reward per game:  -0.042136 , Elapsed time  727.86  minutes.
# Iteration: 93800. Average reward per game:  -0.057402 , Elapsed time  728.59  minutes.
# Iteration: 93900. Average reward per game:  -0.05919 , Elapsed time  729.21  minutes.
# Iteration: 94000. Average reward per game:  -0.078159 , Elapsed time  729.83  minutes.
# Iteration: 94100. Average reward per game:  -0.0498 , Elapsed time  730.46  minutes.
# Iteration: 94200. Average reward per game:  -0.036588 , Elapsed time  731.13  minutes.
# Iteration: 94300. Average reward per game:  -0.047902 , Elapsed time  731.69  minutes.
# Iteration: 94400. Average reward per game:  -0.044298 , Elapsed time  732.41  minutes.
# Iteration: 94500. Average reward per game:  -0.067826 , Elapsed time  733.17  minutes.
# Iteration: 94600. Average reward per game:  -0.084312 , Elapsed time  733.82  minutes.
# Iteration: 94700. Average reward per game:  -0.070945 , Elapsed time  734.46  minutes.
# Iteration: 94800. Average reward per game:  -0.044433 , Elapsed time  735.2  minutes.
# Iteration: 94900. Average reward per game:  -0.068829 , Elapsed time  735.77  minutes.
# Iteration: 95000. Average reward per game:  -0.048148 , Elapsed time  736.57  minutes.
# Iteration: 95100. Average reward per game:  -0.071332 , Elapsed time  737.21  minutes.
# Iteration: 95200. Average reward per game:  -0.073314 , Elapsed time  737.98  minutes.
# Iteration: 95300. Average reward per game:  -0.051553 , Elapsed time  738.52  minutes.
# Iteration: 95400. Average reward per game:  -0.067687 , Elapsed time  739.23  minutes.
# Iteration: 95500. Average reward per game:  -0.053178 , Elapsed time  740.03  minutes.
# Iteration: 95600. Average reward per game:  -0.066103 , Elapsed time  740.79  minutes.
# Iteration: 95700. Average reward per game:  -0.045001 , Elapsed time  741.44  minutes.
# Iteration: 95800. Average reward per game:  -0.081009 , Elapsed time  742.04  minutes.
# Iteration: 95900. Average reward per game:  -0.04314 , Elapsed time  742.68  minutes.
# Iteration: 96000. Average reward per game:  -0.066597 , Elapsed time  743.44  minutes.
# Iteration: 96100. Average reward per game:  -0.054577 , Elapsed time  744.08  minutes.
# Iteration: 96200. Average reward per game:  -0.042928 , Elapsed time  744.7  minutes.
# Iteration: 96300. Average reward per game:  -0.042403 , Elapsed time  745.37  minutes.
# Iteration: 96400. Average reward per game:  -0.081033 , Elapsed time  746.07  minutes.
# Iteration: 96500. Average reward per game:  -0.094933 , Elapsed time  746.72  minutes.
# Iteration: 96600. Average reward per game:  -0.086399 , Elapsed time  747.45  minutes.
# Iteration: 96700. Average reward per game:  -0.101112 , Elapsed time  748.14  minutes.
# Iteration: 96800. Average reward per game:  -0.039711 , Elapsed time  748.87  minutes.
# Iteration: 96900. Average reward per game:  -0.047735 , Elapsed time  749.49  minutes.
# Iteration: 97000. Average reward per game:  -0.098818 , Elapsed time  750.18  minutes.
# Iteration: 97100. Average reward per game:  -0.0658 , Elapsed time  750.9  minutes.
# Iteration: 97200. Average reward per game:  -0.088465 , Elapsed time  751.57  minutes.
# Iteration: 97300. Average reward per game:  -0.073344 , Elapsed time  752.28  minutes.
# Iteration: 97400. Average reward per game:  -0.066191 , Elapsed time  752.89  minutes.
# Iteration: 97500. Average reward per game:  -0.113757 , Elapsed time  753.61  minutes.
# Iteration: 97600. Average reward per game:  -0.096112 , Elapsed time  754.31  minutes.
# Iteration: 97700. Average reward per game:  -0.155104 , Elapsed time  754.92  minutes.
# Iteration: 97800. Average reward per game:  -0.123971 , Elapsed time  755.57  minutes.
# Iteration: 97900. Average reward per game:  -0.113358 , Elapsed time  756.24  minutes.
# Iteration: 98000. Average reward per game:  -0.101294 , Elapsed time  756.96  minutes.
# Iteration: 98100. Average reward per game:  -0.079142 , Elapsed time  757.68  minutes.
# Iteration: 98200. Average reward per game:  -0.058569 , Elapsed time  758.27  minutes.
# Iteration: 98300. Average reward per game:  -0.051034 , Elapsed time  759.06  minutes.
# Iteration: 98400. Average reward per game:  -0.066663 , Elapsed time  759.64  minutes.
# Iteration: 98500. Average reward per game:  -0.053335 , Elapsed time  760.28  minutes.
# Iteration: 98600. Average reward per game:  -0.103526 , Elapsed time  760.93  minutes.
# Iteration: 98700. Average reward per game:  -0.069957 , Elapsed time  761.57  minutes.
# Iteration: 98800. Average reward per game:  -0.089746 , Elapsed time  762.2  minutes.
# Iteration: 98900. Average reward per game:  -0.108874 , Elapsed time  762.9  minutes.
# Iteration: 99000. Average reward per game:  -0.072533 , Elapsed time  763.45  minutes.
# Iteration: 99100. Average reward per game:  -0.090489 , Elapsed time  764.16  minutes.
# Iteration: 99200. Average reward per game:  -0.079965 , Elapsed time  764.95  minutes.
# Iteration: 99300. Average reward per game:  -0.049786 , Elapsed time  765.54  minutes.
# Iteration: 99400. Average reward per game:  -0.052902 , Elapsed time  766.27  minutes.
# Iteration: 99500. Average reward per game:  -0.076013 , Elapsed time  766.95  minutes.
# Iteration: 99600. Average reward per game:  -0.078494 , Elapsed time  767.6  minutes.
# Iteration: 99700. Average reward per game:  -0.072297 , Elapsed time  768.3  minutes.
# Iteration: 99800. Average reward per game:  -0.097253 , Elapsed time  768.73  minutes.
# Iteration: 99900. Average reward per game:  -0.053832 , Elapsed time  769.22  minutes.
# Iteration: 100000. Average reward per game:  -0.095887 , Elapsed time  769.7  minutes.
# Simulation finished. Elapsed time  769.71  minutes.

# %% [markdown]
# ## Visualizations

# %%
# Visualizing train simulation:

#episode =episodes
#simulation_id = 2
#step = 30

discrewards = pd.read_table(rewards_file, sep = ",")* 10 #we divided by the number of games per episode at running time

indices = [i for i in range(0,n_iterations,1)]

plt.plot(discrewards['iteration'][indices],discrewards['discreward'][indices], label = "Discounted rewards")
plt.title("Discounted rewards per episode during training")
plt.xlabel("Episode")
plt.ylabel("Discounted reward")

plt.savefig(simulation_directory + '/discounted-rewards-sim' + '{}'.format(simulation_id) + '.pdf')

plt.show()
plt.close()

# %% [markdown]
# # PG Testing

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 1

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 


with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
               
        env.close()
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation324/NN-models/pdenv_best_policy_net_pg.ckpt

# %% [markdown]
# ## Giff animation

# %%
test_anim = ut.create_system_animation(frames, n_episodes * episode_length)
plt.close()

HTML(test_anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## Visualization with matplotlib

# %%
from utils_pg import is_empty
from utils_pg import my_indicator

def visualize_simulation(states_file,
                        test_toy_system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list):
    test_states = pd.read_table(states_file, sep = ",")
    test_states.head()


    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, n)]
    lvl_colors = ["Orange", "Green","Orange"]

    #tanks = test_toy_system.tanks
    tanks_max_load = system.tank_max_loads
    level_percentages = system.load_level_percentages

    for i, color in enumerate(colors, start=1):    
        plt.subplot(2,3,i)
        states = test_states['stock{}'.format(i-1)]
        plt.plot(test_states['step'],states, label = "Shop {}".format(i-1), color = "Black")
        plt.title("Shop {}".format(i-1))

        plt.axhline(y= tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = "Red", linestyle = '--')
        for lvl_color, lvl in zip(lvl_colors, level_percentages[i-1]):
            plt.axhline(y= lvl * tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = lvl_color, 
                        linestyle = '--')
        plt.axhline(y= 0, xmin=0, xmax=episode_length, hold=None, color = "Red", linestyle = '--')


        percentages = level_percentages[i-1]           
        c = percentages[1]
        e = percentages[2]          
        d = ct.p0_GLOBAL*e+(1-ct.p0_GLOBAL)*c
        plt.axhline(y= d*tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = "lawngreen", 
                    linestyle = '-.')

        plt.axhline(y= np.mean(states), xmin=0, xmax=episode_length, hold=None, 
                    color = "blue", linestyle = '-.')
        plt.xticks(range(0,episode_length*n_episodes+1,5*n_episodes
                        ))
        
        #################### INFO LEVELS
        b = percentages[0]
        level_counts = np.zeros(5, dtype = np.int64)
        
        x_mins = np.array([0,b,c,e])*tanks_max_load[i-1]
        x_maxs = np.array([b,c,e,1])*tanks_max_load[i-1]

        for x in states:
            level_counts[0] = level_counts[0] + is_empty(x)
            for j in range(1,5):
                level_counts[j] = level_counts[j] + my_indicator(x_mins[j-1], x, x_maxs[j-1])
            
        level_counts_list.append(level_counts)
        ###################################################

    plt.subplot(2,3,6)
    plt.title("Legend")
    plt.axis('off')

    #plt.legend(bbox_to_anchor=(0.5 ,0.8), loc=2, borderaxespad=0.)
    plt.yticks([])
    plt.xticks([])

    patch1 = mpatches.Patch(color='red', label='Max/Min capacities', linestyle = '--', fill = False, linewidth = 2)
    patch2 = mpatches.Patch(color='orange', label='Max/Min levels', linestyle = '--', fill = False, linewidth = 2)
    patch3 = mpatches.Patch(color='green', label='Danger level', linestyle = '--', fill = False, linewidth = 2)
    patch4 = mpatches.Patch(color='lawngreen', label='Max reward level (M)', linestyle = '-.', fill = False, linewidth = 2)
    patch5 = mpatches.Patch(color='blue', label='Observed mean level', linestyle = '-.', fill = False, linewidth = 2)
    patch6 = mpatches.Patch(color='black', label='Current stock level', linestyle = '-', fill = False, linewidth = 2)


    plt.legend(handles=[patch1, patch2, patch3, patch4, patch5, patch6], loc = 'center')

    plt.tight_layout() 
    plt.savefig(simulation_directory + '/tank-levels-sim' + '{}'.format(simulation_id) + '.pdf')
    plt.show()
    plt.close()

# %%
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list)

# %% [markdown]
# ## Performance metrics

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 100

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 

####
test_visualization_steps = []
test_rewards_list = []
test_level_rewards_list = []
test_transport_rewards_list = []
test_trucks_sent_list = []
test_number_of_first_trucks_sent_list = []
test_number_of_second_trucks_sent_list = []
test_number_of_trucks_not_deliverying_list = []
####

with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            #####
            discounted_reward = 0 
            transport_rewards = 0
            level_rewards = 0
            number_of_trucks_sent = 0
            number_of_first_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_second_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_trucks_not_deliverying = 0                   
            #####         
         
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
            
                trucks_not_del = info["trucks_not_deliverying"]
                level_reward = info["level_rewards"]
                transport_reward = info["transport_rewards"]
                ### STORE STEP INFO
                discounted_reward = discounted_reward + (discount_rate**(step)) * reward
                transport_rewards = transport_rewards+transport_reward
                level_rewards = level_rewards + level_reward
                
                number_of_trucks_sent = number_of_trucks_sent + np.sum(vect_action == 5)
                index1 = vect_action[0]
                number_of_first_trucks_sent[index1] = number_of_first_trucks_sent[index1] + 1
                index2 = vect_action[1]
                number_of_second_trucks_sent[index2] = number_of_second_trucks_sent[index2] + 1
                number_of_trucks_not_deliverying =  number_of_trucks_not_deliverying + trucks_not_del
                
            test_rewards_list.append(discounted_reward);
            test_transport_rewards_list.append(transport_rewards);
            test_level_rewards_list.append(level_rewards);
            test_trucks_sent_list.append(episode_length * system.k - number_of_trucks_sent);
            test_number_of_first_trucks_sent_list.append(number_of_first_trucks_sent);
            test_number_of_second_trucks_sent_list.append(number_of_second_trucks_sent);
            test_number_of_trucks_not_deliverying_list.append(number_of_trucks_not_deliverying);                   
                
               
        env.close()
        
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list) 

print("Total discounted rewards","Level rewards", "Transport rewards")
print(sum(test_rewards_list)/n_episodes, sum(test_level_rewards_list)/n_episodes,sum(test_transport_rewards_list)/n_episodes )
print("Average trucks sent: ", sum(test_trucks_sent_list)/n_episodes)
    
#     if n_episodes == 1:
first_type = sum(test_number_of_first_trucks_sent_list)/n_episodes
print("Average 1st type Trucks sent to each shop:", first_type)
print("Average 1st type Trucks sent:", sum(first_type[0:n] ) )

second_type = sum(test_number_of_second_trucks_sent_list)/n_episodes
print("Average 2nd type Trucks sent to each shop:", second_type)
print("Average 2nd type Trucks sent:",  sum(second_type[0:n] ))

print("Average number of trucks not deliverying:", sum(test_number_of_trucks_not_deliverying_list)/n_episodes )

for i in range(n):
        print("Average level counts for shop {}:".format(i), test_level_counts_list[i]/n_episodes )

        
print("Average total level counts:", sum(test_level_counts_list)/n_episodes )
print("Percentage total level counts:", (sum(test_level_counts_list)/n_episodes)/(episode_length * n) * 100 )
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation324/NN-models/pdenv_best_policy_net_pg.ckpt
# Total discounted rewards Level rewards Transport rewards
# -703555.1107352626 -1055657.0293661414 33192.1584201
# Average trucks sent:  48.46
# Average 1st type Trucks sent to each shop: [ 7.01  1.65  4.53  2.07 14.74  0.  ]
# Average 1st type Trucks sent: 30.0
# Average 2nd type Trucks sent to each shop: [ 0.    0.    0.   18.46  0.   11.54]
# Average 2nd type Trucks sent: 18.46
# Average number of trucks not deliverying: 0.58
# Average level counts for shop 0: [ 0.25  0.11 10.73 18.91  0.  ]
# Average level counts for shop 1: [ 0.  0.  0. 30.  0.]
# Average level counts for shop 2: [ 0.18  0.34  2.77 26.71  0.  ]
# Average level counts for shop 3: [ 0.09  0.31  0.85 28.61  0.14]
# Average level counts for shop 4: [ 0.36  0.73  4.53 24.38  0.  ]
# Average total level counts: [  0.88   1.49  18.88 128.61   0.14]
# Percentage total level counts: [ 0.58666667  0.99333333 12.58666667 85.74        0.09333333]

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 1

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 

####
test_visualization_steps = []
test_rewards_list = []
test_level_rewards_list = []
test_transport_rewards_list = []
test_trucks_sent_list = []
test_number_of_first_trucks_sent_list = []
test_number_of_second_trucks_sent_list = []
test_number_of_trucks_not_deliverying_list = []
####

with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            #####
            discounted_reward = 0 
            transport_rewards = 0
            level_rewards = 0
            number_of_trucks_sent = 0
            number_of_first_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_second_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_trucks_not_deliverying = 0                   
            #####         
         
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
            
                trucks_not_del = info["trucks_not_deliverying"]
                level_reward = info["level_rewards"]
                transport_reward = info["transport_rewards"]
                ### STORE STEP INFO
                discounted_reward = discounted_reward + (discount_rate**(step)) * reward
                transport_rewards = transport_rewards+transport_reward
                level_rewards = level_rewards + level_reward
                
                number_of_trucks_sent = number_of_trucks_sent + np.sum(vect_action == 5)
                index1 = vect_action[0]
                number_of_first_trucks_sent[index1] = number_of_first_trucks_sent[index1] + 1
                index2 = vect_action[1]
                number_of_second_trucks_sent[index2] = number_of_second_trucks_sent[index2] + 1
                number_of_trucks_not_deliverying =  number_of_trucks_not_deliverying + trucks_not_del
                
            test_rewards_list.append(discounted_reward);
            test_transport_rewards_list.append(transport_rewards);
            test_level_rewards_list.append(level_rewards);
            test_trucks_sent_list.append(episode_length * system.k - number_of_trucks_sent);
            test_number_of_first_trucks_sent_list.append(number_of_first_trucks_sent);
            test_number_of_second_trucks_sent_list.append(number_of_second_trucks_sent);
            test_number_of_trucks_not_deliverying_list.append(number_of_trucks_not_deliverying);                   
                
               
        env.close()
        
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list) 

print("Total discounted rewards","Level rewards", "Transport rewards")
print(sum(test_rewards_list)/n_episodes, sum(test_level_rewards_list)/n_episodes,sum(test_transport_rewards_list)/n_episodes )
print("Average trucks sent: ", sum(test_trucks_sent_list)/n_episodes)
    
#     if n_episodes == 1:
first_type = sum(test_number_of_first_trucks_sent_list)/n_episodes
print("Average 1st type Trucks sent to each shop:", first_type)
print("Average 1st type Trucks sent:", sum(first_type[0:n] ) )

second_type = sum(test_number_of_second_trucks_sent_list)/n_episodes
print("Average 2nd type Trucks sent to each shop:", second_type)
print("Average 2nd type Trucks sent:",  sum(second_type[0:n] ))

print("Average number of trucks not deliverying:", sum(test_number_of_trucks_not_deliverying_list)/n_episodes )

for i in range(n):
        print("Average level counts for shop {}:".format(i), test_level_counts_list[i]/n_episodes )

        
print("Average total level counts:", sum(test_level_counts_list)/n_episodes )
print("Percentage total level counts:", (sum(test_level_counts_list)/n_episodes)/(episode_length * n) * 100 )
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation324/NN-models/pdenv_best_policy_net_pg.ckpt
# Total discounted rewards Level rewards Transport rewards
# -113586.07178781631 -1014028.2269203394 34223.405759999994
# Average trucks sent:  49.0
# Average 1st type Trucks sent to each shop: [ 6.  2.  5.  3. 14.  0.]
# Average 1st type Trucks sent: 30.0
# Average 2nd type Trucks sent to each shop: [ 0.  0.  0. 19.  0. 11.]
# Average 2nd type Trucks sent: 19.0
# Average number of trucks not deliverying: 0.0
# Average level counts for shop 0: [ 0.  0. 12. 18.  0.]
# Average level counts for shop 1: [ 0.  0.  0. 30.  0.]
# Average level counts for shop 2: [ 0.  1.  5. 24.  0.]
# Average level counts for shop 3: [ 0.  0.  1. 29.  0.]
# Average level counts for shop 4: [ 0.  1.  8. 21.  0.]
# Average total level counts: [  0.   2.  26. 122.   0.]
# Percentage total level counts: [ 0.          1.33333333 17.33333333 81.33333333  0.        ]
