# %%
""" 
The algorithm is tested on the PDSystemEnv  gym task 
and developed with Tensorflow

Author: Daniel Salgado Rojo
"""

import tensorflow as tf
import numpy as np
import gym
import gym_pdsystem
from gym import wrappers
#import tflearn
import argparse
import pprint as pp

#from ddpg.replay_buffer import ReplayBuffer

from datetime import datetime

import random

from gym_pdsystem.envs.pdsystem_env import PDSystemEnv
import gym_pdsystem.utils.utilsq as ut
import gym_pdsystem.utils.constants as ct
import gym_pdsystem.utils.functions as fnc


from matplotlib import animation, rc
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import HTML


import pandas as pd
import time

from functools import partial

import os

#TO OMMIT WARNINGS
import warnings
warnings.filterwarnings('ignore')

def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)
    
simulations_directory = './simulations'
if not os.path.exists(simulations_directory):
    os.makedirs(simulations_directory)
# Out:
# /home/dsalgador/anaconda3/envs/tensorflow/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # System's parmeters

# %%
# In order to change the parameters of the system, such as number of shops, trucks, etc, one must change
# the corresponding constants in the 'constants.py' file from the 'gym pd_system' package.

CASE = ct.CASE
STOCHASTIC = ct.STOCHASTIC 

###########################################################

TANK_MAX_LOADS = ct.TANK_MAX_LOADS
LEVEL_PERCENTAGES = ct.LEVEL_PERCENTAGES 
TRUCK_MAX_LOADS = ct.TRUCK_MAX_LOADS
GRAPH_WEIGHTS = ct.GRAPH_WEIGHTS 
DISCRETE = ct.DISCRETE

n = len(TANK_MAX_LOADS)
k = len(TRUCK_MAX_LOADS)

env = gym.make("PDSystemEnv-v0")
episode_length = 30
env._max_episode_steps = episode_length

###########################################################

print("System with k={} trucks and n={} shops. Episodes of {} days.".format(k,n,episode_length))
# Out:
# System with k=2 trucks and n=5 shops. Episodes of 30 days.

# %%
import utils_pg
from utils_pg import int_to_action
from utils_pg import action_to_int
from utils_pg import discount_rewards
from utils_pg import normalize_rewards

# %% [markdown]
# # Tensorflow graph (DNN) for MC Policy Gradient Algorithm

# %%
simulation_id = 317

# Create directories for the simulations' outputs

simulation_directory = './simulations/simulation{}'.format(simulation_id)
rewards_file = simulation_directory+'/discrewards'+ '/rewards-sim{}.csv'.format(simulation_id)
states_file = simulation_directory+'/vis'+ '/states-sim{}.csv'.format(simulation_id) # for testing
models_dir = simulation_directory + '/NN-models'

if not os.path.exists(simulation_directory):
    os.makedirs(simulation_directory)
    os.makedirs(models_dir)
    os.makedirs(simulation_directory + '/discrewards')
    os.makedirs(simulation_directory + '/vis')
    
else:
    raise Exception("The simulation id you tried to use has been already used before. Try to change it to a new one.")

# Output headers to file
with open(rewards_file,'w') as f:
     np.savetxt(f, [["iteration", "discreward"]], fmt="%s", delimiter=',')

# %%
seed = 42
reset_graph(seed)

################################
# TensorBoard summary directories
now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
root_logdir = "tf_logs"
logdir = "{}/run-{}/".format(root_logdir, now)   
################################

## DNN hyperparameters ################
learning_rate = 0.01 #0.01

hidden1_neurons = 100 #100
hidden2_neurons = 50 #50

# batch_normalization = True  
# batch_norm_momentum = 0.9
######################################



######################################
#### Training hyperparameters ########
######################################
# File names for the model

model_file = models_dir + "/pdenv_policy_net_pg.ckpt"#.format(learning_rate)
best_model_file = models_dir + "/pdenv_best_policy_net_pg.ckpt"#.format(learning_rate)
graph_file =  '{}.meta'.format(model_file)


# Simulation / Training parameters
n_games_per_update = 10
n_max_steps = episode_length
n_iterations = 10**5 #2*10**4
save_iterations = 100 # USEFUL WHEN USING EARLY STOPPING
discount_rate = 0.9

info_freq = 100 #100
round_time = 2
round_reward = 6
summary_freq = 20#int(info_freq/2), 10

# Early stopping
max_checks_without_progress = np.inf # 10,  one for each "info_freq" (in terms of iterations it would be
                                                            #max_checks_without_progress *  info_freq)
checks_without_progress = 0
best_reward = -np.infty


retrain = False
########################################



###### TENSORFLOW GRAPH #########
tf.set_random_seed(seed)
with tf.name_scope("dnn"):
        
            # 1. Parameters to determine the NN architecture

            n_inputs = env.observation_space.shape[1]
            n_hidden1 = hidden1_neurons; activation1 = tf.nn.sigmoid#tf.nn.elu
            n_hidden2 = hidden2_neurons; activation2 = tf.nn.sigmoid#tf.nn.elu
            n_outputs = env.action_space.shape[1]**env.action_space.shape[0]
            
            he_init = tf.contrib.layers.variance_scaling_initializer(seed = seed)

            X = tf.placeholder(tf.float32, shape = (None, n_inputs), name = "X")
            
                    
            hidden1 = tf.layers.dense(X, n_hidden1, activation = activation1,
                                     kernel_initializer = he_init)
            hidden2 = tf.layers.dense(hidden1, n_hidden2, activation = activation2,
                                     kernel_initializer = he_init)
            logits = tf.layers.dense(hidden2, n_outputs, name = "logits"
                                     ,kernel_initializer = he_init)
            
            outputs = tf.nn.softmax(logits)
                   
            
with tf.name_scope("action"):
            # 3. Select a random action (where to go) based on the estimated probabilities
            action = tf.multinomial(tf.log(outputs), num_samples = 1)
            test_action = tf.argmax(outputs, axis = 1)
  
            y = tf.reshape(action, [1])
            
with tf.name_scope("loss"):
            xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels = y,logits = logits)
            loss = tf.reduce_mean(xentropy, name = "loss")
            
tf.summary.scalar('average_cross_entropy', loss)


with tf.name_scope("train"):
            # Optimization Op
            optimizer = tf.train.AdamOptimizer(learning_rate)
            
            grads_and_vars = optimizer.compute_gradients(xentropy)
            gradients = [grad for grad, variable in grads_and_vars]
            gradient_placeholders = []
            grads_and_vars_feed = []
            for grad, variable in grads_and_vars:
                gradient_placeholder = tf.placeholder(tf.float32, shape=grad.get_shape())
                gradient_placeholders.append(gradient_placeholder)
                grads_and_vars_feed.append((gradient_placeholder, variable))
            training_op = optimizer.apply_gradients(grads_and_vars_feed)
                        
                                       
merged = tf.summary.merge_all()
init = tf.global_variables_initializer()
file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
        
saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From /home/dsalgador/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %% [markdown]
# # PG Training

# %%
with tf.Session() as sess:
    
    #train_writer = tf.summary.FileWriter(logdir + '/pgtrain', sess.graph)
    if retrain:
        saver.restore(sess, model_file)
        
    summary2 = tf.Summary()
    if not retrain:
        init.run()
    time_start = time.time()

    for iteration in range(n_iterations+1):
        print("\rIteration: {}".format(iteration), end="")
        all_rewards = []
        all_gradients = []
        for game in range(n_games_per_update):
            current_rewards = []
            current_gradients = []
            obs = env.reset()
            for step in range(n_max_steps):
                action_val, gradients_val = sess.run([action, gradients], feed_dict={X: obs.reshape(1, n_inputs)}) 
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                obs, reward, done, info = env.step(vect_action)
                current_rewards.append(reward)
                current_gradients.append(gradients_val)                
                
                if done:
                    break
            all_rewards.append(current_rewards)
            all_gradients.append(current_gradients)
            
        
        all_disc_rewards =  [discount_rewards(rewards, discount_rate) for rewards in all_rewards]
        all_disc_norm_rewards = normalize_rewards(all_disc_rewards)     

        feed_dict = {}
        for var_index, gradient_placeholder in enumerate(gradient_placeholders):
            mean_gradients = np.mean([reward * all_gradients[game_index][step][var_index]
                                      for game_index, rewards in enumerate(all_disc_norm_rewards)
                                          for step, reward in enumerate(rewards)], axis=0)
            feed_dict[gradient_placeholder] = mean_gradients
         
       
        #tf.summary.scalar('avg_rewards', avg_rewards)
        #train_writer.add_summary(avg_rewards, iteration)

        # Summary and info printings     ###################################################################
        if iteration % info_freq == 0 or iteration % summary_freq == 0:  
            
            #avg_rewards =np.array([np.mean(np.array(all_rewards)) / n_games_per_update])
            avg_rewards =np.mean(np.array(all_disc_rewards)) / n_games_per_update
#             print(avg_rewards)
            #avg_rewards_list.append(avg_rewards)
            if iteration % summary_freq == 0:
                summary2.value.add(tag='average_reward_per_game', simple_value = avg_rewards)
                file_writer.add_summary(summary2, iteration)

                feed_dict[X] = obs.reshape(1, n_inputs)
                summary = sess.run(merged, feed_dict= feed_dict)

                file_writer.add_summary(summary, iteration)
                
                  # Disc rewards, etc ####
       
                with open(rewards_file,'ab') as f:
                            np.savetxt(f, [np.array([iteration,  avg_rewards])], fmt=("%d",'%.10f'), delimiter=',') 

            if iteration % info_freq == 0:
                time_end = time.time()
                print(". Average reward per game: ",  round(avg_rewards, round_reward), 
                      ", Elapsed time ", round( (time_end-time_start)/60., round_time), " minutes.") 
                
                
        ###########################################################################      
                
        if avg_rewards > best_reward:
                    saver.save(sess, best_model_file)
                    print("Saved Model with average discounted rewards per game ", avg_rewards)
                    best_reward = avg_rewards
                    checks_without_progress = 0
        else:
                    checks_without_progress += 1
                    if checks_without_progress > max_checks_without_progress:
                        print("Early stopping!")
                        break
        ####################################################################################################
        if iteration % save_iterations == 0:
                 saver.save(sess, model_file)
        
        sess.run(training_op, feed_dict=feed_dict)
    
    #saver.save(sess, model_file + "final")
    file_writer.flush()
    file_writer.close()
                 
    time_end = time.time()
    print("Simulation finished. Elapsed time ", round( (time_end-time_start)/60., round_time), " minutes.")
# Out:
# Iteration: 0. Average reward per game:  -1.795928 , Elapsed time  0.0  minutes.
# Saved Model with average discounted rewards per game  -1.79592841800417
# Iteration: 20Saved Model with average discounted rewards per game  -1.0155018955863964
# Iteration: 40Saved Model with average discounted rewards per game  -0.7756953380530549
# Iteration: 60Saved Model with average discounted rewards per game  -0.6597726181143722
# Iteration: 80Saved Model with average discounted rewards per game  -0.48434586230213234
# Iteration: 100. Average reward per game:  -0.39888 , Elapsed time  0.44  minutes.
# Saved Model with average discounted rewards per game  -0.39887994566920165
# Iteration: 140Saved Model with average discounted rewards per game  -0.26311306084638797
# Iteration: 180Saved Model with average discounted rewards per game  -0.2334831013549437
# Iteration: 200. Average reward per game:  -0.280601 , Elapsed time  0.89  minutes.
# Iteration: 240Saved Model with average discounted rewards per game  -0.2226576256883158
# Iteration: 260Saved Model with average discounted rewards per game  -0.19943364650247208
# Iteration: 300. Average reward per game:  -0.178419 , Elapsed time  1.39  minutes.
# Saved Model with average discounted rewards per game  -0.1784190037681806
# Iteration: 320Saved Model with average discounted rewards per game  -0.17765578911141847
# Iteration: 400. Average reward per game:  -0.210364 , Elapsed time  1.98  minutes.
# Iteration: 500. Average reward per game:  -0.177951 , Elapsed time  2.7  minutes.
# Iteration: 520Saved Model with average discounted rewards per game  -0.16333614079265968
# Iteration: 540Saved Model with average discounted rewards per game  -0.16265820247658233
# Iteration: 600. Average reward per game:  -0.221876 , Elapsed time  3.38  minutes.
# Iteration: 700. Average reward per game:  -0.228567 , Elapsed time  4.07  minutes.
# Iteration: 800. Average reward per game:  -0.223605 , Elapsed time  4.76  minutes.
# Iteration: 900. Average reward per game:  -0.215487 , Elapsed time  5.34  minutes.
# Iteration: 920Saved Model with average discounted rewards per game  -0.15160973473116351
# Iteration: 1000. Average reward per game:  -0.169867 , Elapsed time  6.02  minutes.
# Iteration: 1040Saved Model with average discounted rewards per game  -0.1493143388503325
# Iteration: 1060Saved Model with average discounted rewards per game  -0.13952399688187028
# Iteration: 1100. Average reward per game:  -0.146951 , Elapsed time  6.82  minutes.
# Iteration: 1200. Average reward per game:  -0.145286 , Elapsed time  7.52  minutes.
# Iteration: 1280Saved Model with average discounted rewards per game  -0.12634525979872874
# Iteration: 1300. Average reward per game:  -0.176828 , Elapsed time  8.43  minutes.
# Iteration: 1400. Average reward per game:  -0.145406 , Elapsed time  9.37  minutes.
# Iteration: 1500. Average reward per game:  -0.218156 , Elapsed time  10.32  minutes.
# Iteration: 1600. Average reward per game:  -0.149171 , Elapsed time  11.26  minutes.
# Iteration: 1700. Average reward per game:  -0.17762 , Elapsed time  12.21  minutes.
# Iteration: 1800. Average reward per game:  -0.166125 , Elapsed time  13.15  minutes.
# Iteration: 1900. Average reward per game:  -0.20579 , Elapsed time  14.1  minutes.
# Iteration: 2000. Average reward per game:  -0.133152 , Elapsed time  15.06  minutes.
# Iteration: 2100. Average reward per game:  -0.162041 , Elapsed time  16.01  minutes.
# Iteration: 2200. Average reward per game:  -0.143655 , Elapsed time  16.95  minutes.
# Iteration: 2260Saved Model with average discounted rewards per game  -0.10526512423608221
# Iteration: 2300. Average reward per game:  -0.149761 , Elapsed time  17.89  minutes.
# Iteration: 2400. Average reward per game:  -0.168977 , Elapsed time  18.73  minutes.
# Iteration: 2500. Average reward per game:  -0.199134 , Elapsed time  19.46  minutes.
# Iteration: 2600. Average reward per game:  -0.166407 , Elapsed time  20.04  minutes.
# Iteration: 2700. Average reward per game:  -0.133997 , Elapsed time  20.83  minutes.
# Iteration: 2800. Average reward per game:  -0.133281 , Elapsed time  21.65  minutes.
# Iteration: 2900. Average reward per game:  -0.129758 , Elapsed time  22.46  minutes.
# Iteration: 3000. Average reward per game:  -0.120344 , Elapsed time  23.11  minutes.
# Iteration: 3100. Average reward per game:  -0.14699 , Elapsed time  23.92  minutes.
# Iteration: 3200. Average reward per game:  -0.140972 , Elapsed time  24.74  minutes.
# Iteration: 3300. Average reward per game:  -0.16104 , Elapsed time  25.54  minutes.
# Iteration: 3400. Average reward per game:  -0.167833 , Elapsed time  26.2  minutes.
# Iteration: 3500. Average reward per game:  -0.157804 , Elapsed time  27.02  minutes.
# Iteration: 3600. Average reward per game:  -0.155198 , Elapsed time  27.84  minutes.
# Iteration: 3700. Average reward per game:  -0.192635 , Elapsed time  28.48  minutes.
# Iteration: 3800. Average reward per game:  -0.137322 , Elapsed time  29.19  minutes.
# Iteration: 3900. Average reward per game:  -0.1589 , Elapsed time  29.93  minutes.
# Iteration: 4000. Average reward per game:  -0.154388 , Elapsed time  30.74  minutes.
# Iteration: 4100. Average reward per game:  -0.197676 , Elapsed time  31.43  minutes.
# Iteration: 4200. Average reward per game:  -0.154949 , Elapsed time  32.21  minutes.
# Iteration: 4300. Average reward per game:  -0.144583 , Elapsed time  33.03  minutes.
# Iteration: 4400. Average reward per game:  -0.126082 , Elapsed time  33.84  minutes.
# Iteration: 4500. Average reward per game:  -0.138949 , Elapsed time  34.59  minutes.
# Iteration: 4600. Average reward per game:  -0.15799 , Elapsed time  35.3  minutes.
# Iteration: 4700. Average reward per game:  -0.134467 , Elapsed time  36.11  minutes.
# Iteration: 4800. Average reward per game:  -0.140304 , Elapsed time  36.93  minutes.
# Iteration: 4900. Average reward per game:  -0.189772 , Elapsed time  37.75  minutes.
# Iteration: 5000. Average reward per game:  -0.152947 , Elapsed time  38.46  minutes.
# Iteration: 5100. Average reward per game:  -0.158613 , Elapsed time  39.22  minutes.
# Iteration: 5200. Average reward per game:  -0.12808 , Elapsed time  39.99  minutes.
# Iteration: 5300. Average reward per game:  -0.17183 , Elapsed time  40.68  minutes.
# Iteration: 5400. Average reward per game:  -0.19087 , Elapsed time  41.5  minutes.
# Iteration: 5500. Average reward per game:  -0.186664 , Elapsed time  42.31  minutes.
# Iteration: 5600. Average reward per game:  -0.161621 , Elapsed time  42.97  minutes.
# Iteration: 5700. Average reward per game:  -0.146619 , Elapsed time  43.68  minutes.
# Iteration: 5800. Average reward per game:  -0.154066 , Elapsed time  44.5  minutes.
# Iteration: 5900. Average reward per game:  -0.137303 , Elapsed time  45.32  minutes.
# Iteration: 6000. Average reward per game:  -0.202803 , Elapsed time  45.97  minutes.
# Iteration: 6100. Average reward per game:  -0.173071 , Elapsed time  46.79  minutes.
# Iteration: 6200. Average reward per game:  -0.377924 , Elapsed time  47.61  minutes.
# Iteration: 6300. Average reward per game:  -0.162453 , Elapsed time  48.42  minutes.
# Iteration: 6400. Average reward per game:  -0.151173 , Elapsed time  49.25  minutes.
# Iteration: 6500. Average reward per game:  -0.15173 , Elapsed time  49.88  minutes.
# Iteration: 6600. Average reward per game:  -0.186219 , Elapsed time  50.71  minutes.
# Iteration: 6700. Average reward per game:  -0.170394 , Elapsed time  51.53  minutes.
# Iteration: 6800. Average reward per game:  -0.209805 , Elapsed time  52.25  minutes.
# Iteration: 6900. Average reward per game:  -0.210034 , Elapsed time  52.97  minutes.
# Iteration: 7000. Average reward per game:  -0.249314 , Elapsed time  53.79  minutes.
# Iteration: 7100. Average reward per game:  -0.338513 , Elapsed time  54.61  minutes.
# Iteration: 7200. Average reward per game:  -0.157429 , Elapsed time  55.24  minutes.
# Iteration: 7300. Average reward per game:  -0.25728 , Elapsed time  56.06  minutes.
# Iteration: 7400. Average reward per game:  -0.193042 , Elapsed time  56.83  minutes.
# Iteration: 7500. Average reward per game:  -0.274953 , Elapsed time  57.53  minutes.
# Iteration: 7600. Average reward per game:  -0.156768 , Elapsed time  58.35  minutes.
# Iteration: 7700. Average reward per game:  -0.161218 , Elapsed time  59.11  minutes.
# Iteration: 7800. Average reward per game:  -0.174637 , Elapsed time  59.81  minutes.
# Iteration: 7900. Average reward per game:  -0.161884 , Elapsed time  60.63  minutes.
# Iteration: 8000. Average reward per game:  -0.169896 , Elapsed time  61.45  minutes.
# Iteration: 8100. Average reward per game:  -0.150612 , Elapsed time  62.13  minutes.
# Iteration: 8200. Average reward per game:  -0.151154 , Elapsed time  62.84  minutes.
# Iteration: 8300. Average reward per game:  -0.178998 , Elapsed time  63.65  minutes.
# Iteration: 8400. Average reward per game:  -0.136571 , Elapsed time  64.47  minutes.
# Iteration: 8500. Average reward per game:  -0.14015 , Elapsed time  65.29  minutes.
# Iteration: 8600. Average reward per game:  -0.159273 , Elapsed time  66.11  minutes.
# Iteration: 8700. Average reward per game:  -0.134021 , Elapsed time  66.92  minutes.
# Iteration: 8800. Average reward per game:  -0.165892 , Elapsed time  67.74  minutes.
# Iteration: 8900. Average reward per game:  -0.118333 , Elapsed time  68.4  minutes.
# Iteration: 9000. Average reward per game:  -0.157757 , Elapsed time  69.21  minutes.
# Iteration: 9100. Average reward per game:  -0.148341 , Elapsed time  69.98  minutes.
# Iteration: 9200. Average reward per game:  -0.126963 , Elapsed time  70.66  minutes.
# Iteration: 9300. Average reward per game:  -0.14583 , Elapsed time  71.31  minutes.
# Iteration: 9400. Average reward per game:  -0.151427 , Elapsed time  72.12  minutes.
# Iteration: 9500. Average reward per game:  -0.144004 , Elapsed time  72.73  minutes.
# Iteration: 9600. Average reward per game:  -0.135343 , Elapsed time  73.54  minutes.
# Iteration: 9700. Average reward per game:  -0.141966 , Elapsed time  74.19  minutes.
# Iteration: 9800. Average reward per game:  -0.132965 , Elapsed time  74.99  minutes.
# Iteration: 9900. Average reward per game:  -0.144006 , Elapsed time  75.61  minutes.
# Iteration: 10000. Average reward per game:  -0.124261 , Elapsed time  76.32  minutes.
# Iteration: 10100. Average reward per game:  -0.139917 , Elapsed time  76.98  minutes.
# Iteration: 10200. Average reward per game:  -0.121753 , Elapsed time  77.66  minutes.
# Iteration: 10300. Average reward per game:  -0.160543 , Elapsed time  78.31  minutes.
# Iteration: 10400. Average reward per game:  -0.218231 , Elapsed time  79.1  minutes.
# Iteration: 10500. Average reward per game:  -0.159593 , Elapsed time  79.84  minutes.
# Iteration: 10600. Average reward per game:  -0.208542 , Elapsed time  80.58  minutes.
# Iteration: 10700. Average reward per game:  -0.124508 , Elapsed time  81.43  minutes.
# Iteration: 10800. Average reward per game:  -0.157337 , Elapsed time  82.36  minutes.
# Iteration: 10900. Average reward per game:  -0.1299 , Elapsed time  83.26  minutes.
# Iteration: 11000. Average reward per game:  -0.151951 , Elapsed time  83.94  minutes.
# Iteration: 11100. Average reward per game:  -0.156962 , Elapsed time  84.82  minutes.
# Iteration: 11200. Average reward per game:  -0.16048 , Elapsed time  85.64  minutes.
# Iteration: 11300. Average reward per game:  -0.122186 , Elapsed time  86.37  minutes.
# Iteration: 11400. Average reward per game:  -0.126717 , Elapsed time  87.28  minutes.
# Iteration: 11500. Average reward per game:  -0.162126 , Elapsed time  88.14  minutes.
# Iteration: 11600. Average reward per game:  -0.133847 , Elapsed time  89.06  minutes.
# Iteration: 11700. Average reward per game:  -0.169702 , Elapsed time  89.99  minutes.
# Iteration: 11800. Average reward per game:  -0.151517 , Elapsed time  90.92  minutes.
# Iteration: 11900. Average reward per game:  -0.172552 , Elapsed time  91.86  minutes.
# Iteration: 12000. Average reward per game:  -0.241001 , Elapsed time  92.8  minutes.
# Iteration: 12100. Average reward per game:  -0.136962 , Elapsed time  93.74  minutes.
# Iteration: 12200. Average reward per game:  -0.155969 , Elapsed time  94.68  minutes.
# Iteration: 12300. Average reward per game:  -0.140774 , Elapsed time  95.62  minutes.
# Iteration: 12400. Average reward per game:  -0.163632 , Elapsed time  96.56  minutes.
# Iteration: 12500. Average reward per game:  -0.11519 , Elapsed time  97.51  minutes.
# Iteration: 12600. Average reward per game:  -0.145645 , Elapsed time  98.43  minutes.
# Iteration: 12700. Average reward per game:  -0.178192 , Elapsed time  99.36  minutes.
# Iteration: 12800. Average reward per game:  -0.284072 , Elapsed time  100.3  minutes.
# Iteration: 12900. Average reward per game:  -0.185841 , Elapsed time  101.24  minutes.
# Iteration: 13000. Average reward per game:  -0.129668 , Elapsed time  102.18  minutes.
# Iteration: 13100. Average reward per game:  -0.116647 , Elapsed time  103.12  minutes.
# Iteration: 13200. Average reward per game:  -0.108344 , Elapsed time  104.06  minutes.
# Iteration: 13300. Average reward per game:  -0.20918 , Elapsed time  105.04  minutes.
# Iteration: 13400. Average reward per game:  -0.17685 , Elapsed time  106.11  minutes.
# Iteration: 13500. Average reward per game:  -0.154769 , Elapsed time  107.29  minutes.
# Iteration: 13600. Average reward per game:  -0.14134 , Elapsed time  108.47  minutes.
# Iteration: 13700. Average reward per game:  -0.150095 , Elapsed time  109.53  minutes.
# Iteration: 13800. Average reward per game:  -0.206626 , Elapsed time  110.7  minutes.
# Iteration: 13900. Average reward per game:  -0.16353 , Elapsed time  111.81  minutes.
# Iteration: 14000. Average reward per game:  -0.172276 , Elapsed time  112.99  minutes.
# Iteration: 14100. Average reward per game:  -0.132184 , Elapsed time  114.14  minutes.
# Iteration: 14200. Average reward per game:  -0.177967 , Elapsed time  115.31  minutes.
# Iteration: 14300. Average reward per game:  -0.167328 , Elapsed time  116.48  minutes.
# Iteration: 14400. Average reward per game:  -0.148388 , Elapsed time  117.65  minutes.
# Iteration: 14500. Average reward per game:  -0.161131 , Elapsed time  118.82  minutes.
# Iteration: 14600. Average reward per game:  -0.15755 , Elapsed time  119.97  minutes.
# Iteration: 14700. Average reward per game:  -0.1295 , Elapsed time  121.04  minutes.
# Iteration: 14800. Average reward per game:  -0.134475 , Elapsed time  122.04  minutes.
# Iteration: 14900. Average reward per game:  -0.159651 , Elapsed time  122.99  minutes.
# Iteration: 15000. Average reward per game:  -0.173105 , Elapsed time  124.04  minutes.
# Iteration: 15100. Average reward per game:  -0.124594 , Elapsed time  125.15  minutes.
# Iteration: 15200. Average reward per game:  -0.166926 , Elapsed time  126.1  minutes.
# Iteration: 15300. Average reward per game:  -0.129545 , Elapsed time  127.05  minutes.
# Iteration: 15400. Average reward per game:  -0.185834 , Elapsed time  128.01  minutes.
# Iteration: 15500. Average reward per game:  -0.126169 , Elapsed time  129.04  minutes.
# Iteration: 15600. Average reward per game:  -0.298502 , Elapsed time  130.18  minutes.
# Iteration: 15700. Average reward per game:  -0.16213 , Elapsed time  131.35  minutes.
# Iteration: 15800. Average reward per game:  -0.147476 , Elapsed time  132.56  minutes.
# Iteration: 15900. Average reward per game:  -0.18359 , Elapsed time  133.76  minutes.
# Iteration: 16000. Average reward per game:  -0.203125 , Elapsed time  134.95  minutes.
# Iteration: 16100. Average reward per game:  -0.342256 , Elapsed time  136.15  minutes.
# Iteration: 16200. Average reward per game:  -0.170998 , Elapsed time  137.33  minutes.
# Iteration: 16300. Average reward per game:  -0.167446 , Elapsed time  138.44  minutes.
# Iteration: 16400. Average reward per game:  -0.145232 , Elapsed time  139.42  minutes.
# Iteration: 16500. Average reward per game:  -0.206434 , Elapsed time  140.39  minutes.
# Iteration: 16600. Average reward per game:  -0.150138 , Elapsed time  141.35  minutes.
# Iteration: 16700. Average reward per game:  -0.144662 , Elapsed time  142.3  minutes.
# Iteration: 16800. Average reward per game:  -0.178507 , Elapsed time  143.25  minutes.
# Iteration: 16900. Average reward per game:  -0.167448 , Elapsed time  144.21  minutes.
# Iteration: 17000. Average reward per game:  -0.144293 , Elapsed time  145.15  minutes.
# Iteration: 17100. Average reward per game:  -0.143176 , Elapsed time  146.08  minutes.
# Iteration: 17200. Average reward per game:  -0.174719 , Elapsed time  147.03  minutes.
# Iteration: 17300. Average reward per game:  -0.160231 , Elapsed time  147.97  minutes.
# Iteration: 17400. Average reward per game:  -0.187348 , Elapsed time  148.92  minutes.
# Iteration: 17500. Average reward per game:  -0.163221 , Elapsed time  149.86  minutes.
# Iteration: 17600. Average reward per game:  -0.190008 , Elapsed time  150.81  minutes.
# Iteration: 17700. Average reward per game:  -0.151131 , Elapsed time  151.76  minutes.
# Iteration: 17800. Average reward per game:  -0.163213 , Elapsed time  152.71  minutes.
# Iteration: 17900. Average reward per game:  -0.137665 , Elapsed time  153.65  minutes.
# Iteration: 18000. Average reward per game:  -0.217514 , Elapsed time  154.59  minutes.
# Iteration: 18100. Average reward per game:  -0.136278 , Elapsed time  155.53  minutes.
# Iteration: 18200. Average reward per game:  -0.140167 , Elapsed time  156.48  minutes.
# Iteration: 18300. Average reward per game:  -0.162052 , Elapsed time  157.42  minutes.
# Iteration: 18400. Average reward per game:  -0.146455 , Elapsed time  158.38  minutes.
# Iteration: 18500. Average reward per game:  -0.25164 , Elapsed time  159.32  minutes.
# Iteration: 18600. Average reward per game:  -0.169941 , Elapsed time  160.28  minutes.
# Iteration: 18700. Average reward per game:  -0.210394 , Elapsed time  161.22  minutes.
# Iteration: 18800. Average reward per game:  -0.203475 , Elapsed time  162.16  minutes.
# Iteration: 18900. Average reward per game:  -0.148553 , Elapsed time  163.11  minutes.
# Iteration: 19000. Average reward per game:  -0.153012 , Elapsed time  164.05  minutes.
# Iteration: 19100. Average reward per game:  -0.16594 , Elapsed time  165.0  minutes.
# Iteration: 19200. Average reward per game:  -0.224809 , Elapsed time  165.95  minutes.
# Iteration: 19300. Average reward per game:  -0.141919 , Elapsed time  166.9  minutes.
# Iteration: 19400. Average reward per game:  -0.139034 , Elapsed time  167.85  minutes.
# Iteration: 19500. Average reward per game:  -0.138831 , Elapsed time  168.78  minutes.
# Iteration: 19600. Average reward per game:  -0.190346 , Elapsed time  169.73  minutes.
# Iteration: 19680Saved Model with average discounted rewards per game  -0.07789818452559764
# Iteration: 19700. Average reward per game:  -0.107373 , Elapsed time  170.69  minutes.
# Iteration: 19720Saved Model with average discounted rewards per game  -0.07488667328770092
# Iteration: 19740Saved Model with average discounted rewards per game  -0.07354884847212223
# Iteration: 19760Saved Model with average discounted rewards per game  -0.06498794161236748
# Iteration: 19800. Average reward per game:  -0.107286 , Elapsed time  171.63  minutes.
# Iteration: 19820Saved Model with average discounted rewards per game  -0.06448402415422996
# Iteration: 19860Saved Model with average discounted rewards per game  -0.05350799663758573
# Iteration: 19900. Average reward per game:  -0.091732 , Elapsed time  172.58  minutes.
# Iteration: 20000. Average reward per game:  -0.089828 , Elapsed time  173.53  minutes.
# Iteration: 20100. Average reward per game:  -0.141117 , Elapsed time  174.48  minutes.
# Iteration: 20200. Average reward per game:  -0.104839 , Elapsed time  175.42  minutes.
# Iteration: 20300. Average reward per game:  -0.088623 , Elapsed time  176.36  minutes.
# Iteration: 20380Saved Model with average discounted rewards per game  -0.05078985863610108
# Iteration: 20400. Average reward per game:  -0.085848 , Elapsed time  177.31  minutes.
# Iteration: 20500. Average reward per game:  -0.061173 , Elapsed time  178.26  minutes.
# Iteration: 20600. Average reward per game:  -0.07833 , Elapsed time  179.21  minutes.
# Iteration: 20700. Average reward per game:  -0.065664 , Elapsed time  180.16  minutes.
# Iteration: 20800. Average reward per game:  -0.068682 , Elapsed time  181.11  minutes.
# Iteration: 20820Saved Model with average discounted rewards per game  -0.03996863763967413
# Iteration: 20900. Average reward per game:  -0.09748 , Elapsed time  182.06  minutes.
# Iteration: 21000. Average reward per game:  -0.064674 , Elapsed time  183.0  minutes.
# Iteration: 21100. Average reward per game:  -0.078941 , Elapsed time  183.96  minutes.
# Iteration: 21200. Average reward per game:  -0.183356 , Elapsed time  184.91  minutes.
# Iteration: 21300. Average reward per game:  -0.079374 , Elapsed time  185.86  minutes.
# Iteration: 21400. Average reward per game:  -0.083061 , Elapsed time  186.81  minutes.
# Iteration: 21500. Average reward per game:  -0.079945 , Elapsed time  187.76  minutes.
# Iteration: 21600. Average reward per game:  -0.142422 , Elapsed time  188.71  minutes.
# Iteration: 21640Saved Model with average discounted rewards per game  -0.03995357879362811
# Iteration: 21700. Average reward per game:  -0.098136 , Elapsed time  189.66  minutes.
# Iteration: 21800. Average reward per game:  -0.078196 , Elapsed time  190.61  minutes.
# Iteration: 21900. Average reward per game:  -0.066212 , Elapsed time  191.55  minutes.
# Iteration: 22000. Average reward per game:  -0.073112 , Elapsed time  192.5  minutes.
# Iteration: 22100. Average reward per game:  -0.085918 , Elapsed time  193.44  minutes.
# Iteration: 22200. Average reward per game:  -0.106955 , Elapsed time  194.39  minutes.
# Iteration: 22300. Average reward per game:  -0.097623 , Elapsed time  195.34  minutes.
# Iteration: 22400. Average reward per game:  -0.054261 , Elapsed time  196.29  minutes.
# Iteration: 22500. Average reward per game:  -0.099878 , Elapsed time  197.24  minutes.
# Iteration: 22600. Average reward per game:  -0.197952 , Elapsed time  198.2  minutes.
# Iteration: 22700. Average reward per game:  -0.083168 , Elapsed time  199.14  minutes.
# Iteration: 22800. Average reward per game:  -0.066693 , Elapsed time  200.1  minutes.
# Iteration: 22900. Average reward per game:  -0.107382 , Elapsed time  201.05  minutes.
# Iteration: 23000. Average reward per game:  -0.065696 , Elapsed time  201.99  minutes.
# Iteration: 23100. Average reward per game:  -0.139361 , Elapsed time  202.92  minutes.
# Iteration: 23200. Average reward per game:  -0.116694 , Elapsed time  203.87  minutes.
# Iteration: 23300. Average reward per game:  -0.115674 , Elapsed time  204.81  minutes.
# Iteration: 23400. Average reward per game:  -0.090927 , Elapsed time  205.75  minutes.
# Iteration: 23500. Average reward per game:  -0.113149 , Elapsed time  206.69  minutes.
# Iteration: 23600. Average reward per game:  -0.079264 , Elapsed time  207.64  minutes.
# Iteration: 23700. Average reward per game:  -0.071418 , Elapsed time  208.58  minutes.
# Iteration: 23800. Average reward per game:  -0.10578 , Elapsed time  209.52  minutes.
# Iteration: 23900. Average reward per game:  -0.108946 , Elapsed time  210.45  minutes.
# Iteration: 24000. Average reward per game:  -0.084747 , Elapsed time  211.39  minutes.
# Iteration: 24100. Average reward per game:  -0.058255 , Elapsed time  212.33  minutes.
# Iteration: 24200. Average reward per game:  -0.109048 , Elapsed time  213.28  minutes.
# Iteration: 24300. Average reward per game:  -0.084281 , Elapsed time  214.22  minutes.
# Iteration: 24400. Average reward per game:  -0.128385 , Elapsed time  215.16  minutes.
# Iteration: 24500. Average reward per game:  -0.055885 , Elapsed time  216.11  minutes.
# Iteration: 24600. Average reward per game:  -0.084037 , Elapsed time  217.05  minutes.
# Iteration: 24700. Average reward per game:  -0.086761 , Elapsed time  217.99  minutes.
# Iteration: 24800. Average reward per game:  -0.06352 , Elapsed time  218.93  minutes.
# Iteration: 24900. Average reward per game:  -0.151713 , Elapsed time  219.87  minutes.
# Iteration: 25000. Average reward per game:  -0.080405 , Elapsed time  220.81  minutes.
# Iteration: 25100. Average reward per game:  -0.193363 , Elapsed time  221.74  minutes.
# Iteration: 25200. Average reward per game:  -0.057071 , Elapsed time  222.69  minutes.
# Iteration: 25300. Average reward per game:  -0.11813 , Elapsed time  223.64  minutes.
# Iteration: 25400. Average reward per game:  -0.084176 , Elapsed time  224.58  minutes.
# Iteration: 25500. Average reward per game:  -0.119076 , Elapsed time  225.53  minutes.
# Iteration: 25600. Average reward per game:  -0.161895 , Elapsed time  226.47  minutes.
# Iteration: 25700. Average reward per game:  -0.111866 , Elapsed time  227.41  minutes.
# Iteration: 25800. Average reward per game:  -0.077422 , Elapsed time  228.36  minutes.
# Iteration: 25900. Average reward per game:  -0.063552 , Elapsed time  229.31  minutes.
# Iteration: 26000. Average reward per game:  -0.065596 , Elapsed time  230.31  minutes.
# Iteration: 26100. Average reward per game:  -0.080547 , Elapsed time  231.28  minutes.
# Iteration: 26200. Average reward per game:  -0.129659 , Elapsed time  232.23  minutes.
# Iteration: 26300. Average reward per game:  -0.135891 , Elapsed time  233.19  minutes.
# Iteration: 26400. Average reward per game:  -0.048107 , Elapsed time  234.15  minutes.
# Iteration: 26500. Average reward per game:  -0.127624 , Elapsed time  235.09  minutes.
# Iteration: 26600. Average reward per game:  -0.094161 , Elapsed time  236.05  minutes.
# Iteration: 26700. Average reward per game:  -0.084923 , Elapsed time  237.0  minutes.
# Iteration: 26800. Average reward per game:  -0.117361 , Elapsed time  237.96  minutes.
# Iteration: 26900. Average reward per game:  -0.042566 , Elapsed time  238.92  minutes.
# Iteration: 27000. Average reward per game:  -0.108058 , Elapsed time  239.87  minutes.
# Iteration: 27100. Average reward per game:  -0.079541 , Elapsed time  240.82  minutes.
# Iteration: 27200. Average reward per game:  -0.075016 , Elapsed time  241.78  minutes.
# Iteration: 27300. Average reward per game:  -0.099521 , Elapsed time  242.74  minutes.
# Iteration: 27400. Average reward per game:  -0.060554 , Elapsed time  243.68  minutes.
# Iteration: 27500. Average reward per game:  -0.109701 , Elapsed time  244.63  minutes.
# Iteration: 27600. Average reward per game:  -0.052288 , Elapsed time  245.59  minutes.
# Iteration: 27700. Average reward per game:  -0.051884 , Elapsed time  246.54  minutes.
# Iteration: 27800. Average reward per game:  -0.176727 , Elapsed time  247.49  minutes.
# Iteration: 27900. Average reward per game:  -0.07123 , Elapsed time  248.45  minutes.
# Iteration: 28000. Average reward per game:  -0.09767 , Elapsed time  249.41  minutes.
# Iteration: 28100. Average reward per game:  -0.12795 , Elapsed time  250.36  minutes.
# Iteration: 28200. Average reward per game:  -0.06077 , Elapsed time  251.32  minutes.
# Iteration: 28300. Average reward per game:  -0.082519 , Elapsed time  252.28  minutes.
# Iteration: 28400. Average reward per game:  -0.084446 , Elapsed time  253.24  minutes.
# Iteration: 28500. Average reward per game:  -0.081107 , Elapsed time  254.19  minutes.
# Iteration: 28600. Average reward per game:  -0.084419 , Elapsed time  255.15  minutes.
# Iteration: 28700. Average reward per game:  -0.051811 , Elapsed time  256.1  minutes.
# Iteration: 28800. Average reward per game:  -0.050135 , Elapsed time  257.06  minutes.
# Iteration: 28900. Average reward per game:  -0.086697 , Elapsed time  258.01  minutes.
# Iteration: 29000. Average reward per game:  -0.053229 , Elapsed time  258.97  minutes.
# Iteration: 29100. Average reward per game:  -0.073482 , Elapsed time  259.93  minutes.
# Iteration: 29140Saved Model with average discounted rewards per game  -0.038849695375041085
# Iteration: 29200. Average reward per game:  -0.066886 , Elapsed time  260.89  minutes.
# Iteration: 29300. Average reward per game:  -0.094216 , Elapsed time  261.85  minutes.
# Iteration: 29400. Average reward per game:  -0.062053 , Elapsed time  262.8  minutes.
# Iteration: 29500. Average reward per game:  -0.049701 , Elapsed time  263.76  minutes.
# Iteration: 29600. Average reward per game:  -0.074262 , Elapsed time  264.72  minutes.
# Iteration: 29700. Average reward per game:  -0.082471 , Elapsed time  265.67  minutes.
# Iteration: 29800. Average reward per game:  -0.074844 , Elapsed time  266.62  minutes.
# Iteration: 29900. Average reward per game:  -0.082153 , Elapsed time  267.58  minutes.
# Iteration: 30000. Average reward per game:  -0.101163 , Elapsed time  268.53  minutes.
# Iteration: 30100. Average reward per game:  -0.067597 , Elapsed time  269.49  minutes.
# Iteration: 30200. Average reward per game:  -0.075276 , Elapsed time  270.45  minutes.
# Iteration: 30300. Average reward per game:  -0.095572 , Elapsed time  271.41  minutes.
# Iteration: 30400. Average reward per game:  -0.101394 , Elapsed time  272.36  minutes.
# Iteration: 30500. Average reward per game:  -0.049878 , Elapsed time  273.32  minutes.
# Iteration: 30600. Average reward per game:  -0.096832 , Elapsed time  274.27  minutes.
# Iteration: 30700. Average reward per game:  -0.0949 , Elapsed time  275.23  minutes.
# Iteration: 30800. Average reward per game:  -0.073546 , Elapsed time  276.18  minutes.
# Iteration: 30900. Average reward per game:  -0.093417 , Elapsed time  277.14  minutes.
# Iteration: 31000. Average reward per game:  -0.12333 , Elapsed time  278.08  minutes.
# Iteration: 31100. Average reward per game:  -0.083888 , Elapsed time  279.04  minutes.
# Iteration: 31200. Average reward per game:  -0.060369 , Elapsed time  280.0  minutes.
# Iteration: 31300. Average reward per game:  -0.059429 , Elapsed time  280.96  minutes.
# Iteration: 31400. Average reward per game:  -0.070616 , Elapsed time  281.91  minutes.
# Iteration: 31500. Average reward per game:  -0.079812 , Elapsed time  282.87  minutes.
# Iteration: 31600. Average reward per game:  -0.089395 , Elapsed time  283.82  minutes.
# Iteration: 31700. Average reward per game:  -0.118481 , Elapsed time  284.78  minutes.
# Iteration: 31800. Average reward per game:  -0.090498 , Elapsed time  285.74  minutes.
# Iteration: 31900. Average reward per game:  -0.090269 , Elapsed time  286.71  minutes.
# Iteration: 32000. Average reward per game:  -0.085096 , Elapsed time  287.67  minutes.
# Iteration: 32100. Average reward per game:  -0.108769 , Elapsed time  288.62  minutes.
# Iteration: 32200. Average reward per game:  -0.059106 , Elapsed time  289.58  minutes.
# Iteration: 32300. Average reward per game:  -0.079175 , Elapsed time  290.54  minutes.
# Iteration: 32400. Average reward per game:  -0.073275 , Elapsed time  291.52  minutes.
# Iteration: 32500. Average reward per game:  -0.091489 , Elapsed time  292.46  minutes.
# Iteration: 32600. Average reward per game:  -0.051941 , Elapsed time  293.41  minutes.
# Iteration: 32700. Average reward per game:  -0.084374 , Elapsed time  294.36  minutes.
# Iteration: 32800. Average reward per game:  -0.081182 , Elapsed time  295.32  minutes.
# Iteration: 32900. Average reward per game:  -0.041457 , Elapsed time  296.27  minutes.
# Iteration: 33000. Average reward per game:  -0.076964 , Elapsed time  297.23  minutes.
# Iteration: 33100. Average reward per game:  -0.05642 , Elapsed time  298.18  minutes.
# Iteration: 33200. Average reward per game:  -0.073457 , Elapsed time  299.14  minutes.
# Iteration: 33300. Average reward per game:  -0.056945 , Elapsed time  300.09  minutes.
# Iteration: 33400. Average reward per game:  -0.088568 , Elapsed time  301.04  minutes.
# Iteration: 33500. Average reward per game:  -0.111239 , Elapsed time  301.99  minutes.
# Iteration: 33600. Average reward per game:  -0.051176 , Elapsed time  302.94  minutes.
# Iteration: 33700. Average reward per game:  -0.061459 , Elapsed time  303.91  minutes.
# Iteration: 33780Saved Model with average discounted rewards per game  -0.035734646418200726
# Iteration: 33800. Average reward per game:  -0.034536 , Elapsed time  304.86  minutes.
# Saved Model with average discounted rewards per game  -0.03453604901235273
# Iteration: 33880Saved Model with average discounted rewards per game  -0.03369277605318005
# Iteration: 33900. Average reward per game:  -0.068088 , Elapsed time  305.82  minutes.
# Iteration: 34000. Average reward per game:  -0.042996 , Elapsed time  306.78  minutes.
# Iteration: 34100. Average reward per game:  -0.104519 , Elapsed time  307.74  minutes.
# Iteration: 34200. Average reward per game:  -0.074787 , Elapsed time  308.66  minutes.
# Iteration: 34300. Average reward per game:  -0.145863 , Elapsed time  309.5  minutes.
# Iteration: 34400. Average reward per game:  -0.104125 , Elapsed time  310.35  minutes.
# Iteration: 34500. Average reward per game:  -0.043171 , Elapsed time  311.19  minutes.
# Iteration: 34600. Average reward per game:  -0.086928 , Elapsed time  312.01  minutes.
# Iteration: 34700. Average reward per game:  -0.090167 , Elapsed time  312.68  minutes.
# Iteration: 34800. Average reward per game:  -0.057535 , Elapsed time  313.52  minutes.
# Iteration: 34900. Average reward per game:  -0.0727 , Elapsed time  314.36  minutes.
# Iteration: 35000. Average reward per game:  -0.062511 , Elapsed time  315.19  minutes.
# Iteration: 35100. Average reward per game:  -0.220623 , Elapsed time  316.08  minutes.
# Iteration: 35200. Average reward per game:  -0.078974 , Elapsed time  316.93  minutes.
# Iteration: 35300. Average reward per game:  -0.068751 , Elapsed time  317.77  minutes.
# Iteration: 35400. Average reward per game:  -0.043708 , Elapsed time  318.61  minutes.
# Iteration: 35500. Average reward per game:  -0.092532 , Elapsed time  319.45  minutes.
# Iteration: 35600. Average reward per game:  -0.172422 , Elapsed time  320.29  minutes.
# Iteration: 35700. Average reward per game:  -0.096866 , Elapsed time  321.13  minutes.
# Iteration: 35800. Average reward per game:  -0.07837 , Elapsed time  321.96  minutes.
# Iteration: 35900. Average reward per game:  -0.072494 , Elapsed time  322.67  minutes.
# Iteration: 36000. Average reward per game:  -0.056877 , Elapsed time  323.48  minutes.
# Iteration: 36100. Average reward per game:  -0.097468 , Elapsed time  324.32  minutes.
# Iteration: 36200. Average reward per game:  -0.061877 , Elapsed time  325.17  minutes.
# Iteration: 36300. Average reward per game:  -0.074905 , Elapsed time  326.01  minutes.
# Iteration: 36400. Average reward per game:  -0.081702 , Elapsed time  326.79  minutes.
# Iteration: 36500. Average reward per game:  -0.055963 , Elapsed time  327.53  minutes.
# Iteration: 36600. Average reward per game:  -0.066131 , Elapsed time  328.21  minutes.
# Iteration: 36700. Average reward per game:  -0.0552 , Elapsed time  329.05  minutes.
# Iteration: 36800. Average reward per game:  -0.153634 , Elapsed time  329.9  minutes.
# Iteration: 36900. Average reward per game:  -0.147142 , Elapsed time  330.72  minutes.
# Iteration: 37000. Average reward per game:  -0.155198 , Elapsed time  331.41  minutes.
# Iteration: 37100. Average reward per game:  -0.152751 , Elapsed time  332.26  minutes.
# Iteration: 37200. Average reward per game:  -0.117902 , Elapsed time  333.09  minutes.
# Iteration: 37300. Average reward per game:  -0.111748 , Elapsed time  333.76  minutes.
# Iteration: 37400. Average reward per game:  -0.087684 , Elapsed time  334.6  minutes.
# Iteration: 37500. Average reward per game:  -0.068915 , Elapsed time  335.45  minutes.
# Iteration: 37600. Average reward per game:  -0.090742 , Elapsed time  336.13  minutes.
# Iteration: 37700. Average reward per game:  -0.054164 , Elapsed time  336.98  minutes.
# Iteration: 37800. Average reward per game:  -0.112881 , Elapsed time  337.82  minutes.
# Iteration: 37900. Average reward per game:  -0.093667 , Elapsed time  338.66  minutes.
# Iteration: 38000. Average reward per game:  -0.108604 , Elapsed time  339.49  minutes.
# Iteration: 38100. Average reward per game:  -0.100157 , Elapsed time  340.34  minutes.
# Iteration: 38200. Average reward per game:  -0.102785 , Elapsed time  341.17  minutes.
# Iteration: 38300. Average reward per game:  -0.091871 , Elapsed time  341.84  minutes.
# Iteration: 38400. Average reward per game:  -0.077261 , Elapsed time  342.69  minutes.
# Iteration: 38500. Average reward per game:  -0.095232 , Elapsed time  343.52  minutes.
# Iteration: 38600. Average reward per game:  -0.053732 , Elapsed time  344.21  minutes.
# Iteration: 38700. Average reward per game:  -0.061463 , Elapsed time  345.04  minutes.
# Iteration: 38800. Average reward per game:  -0.0503 , Elapsed time  345.89  minutes.
# Iteration: 38900. Average reward per game:  -0.07637 , Elapsed time  346.73  minutes.
# Iteration: 39000. Average reward per game:  -0.07851 , Elapsed time  347.57  minutes.
# Iteration: 39100. Average reward per game:  -0.097259 , Elapsed time  348.41  minutes.
# Iteration: 39200. Average reward per game:  -0.08956 , Elapsed time  349.08  minutes.
# Iteration: 39300. Average reward per game:  -0.052349 , Elapsed time  349.92  minutes.
# Iteration: 39340Saved Model with average discounted rewards per game  -0.028162642280256812
# Iteration: 39400. Average reward per game:  -0.082904 , Elapsed time  350.77  minutes.
# Iteration: 39500. Average reward per game:  -0.072836 , Elapsed time  351.62  minutes.
# Iteration: 39600. Average reward per game:  -0.098363 , Elapsed time  352.46  minutes.
# Iteration: 39700. Average reward per game:  -0.095068 , Elapsed time  353.29  minutes.
# Iteration: 39800. Average reward per game:  -0.060618 , Elapsed time  353.98  minutes.
# Iteration: 39900. Average reward per game:  -0.086273 , Elapsed time  354.82  minutes.
# Iteration: 40000. Average reward per game:  -0.095314 , Elapsed time  355.67  minutes.
# Iteration: 40100. Average reward per game:  -0.070522 , Elapsed time  356.52  minutes.
# Iteration: 40200. Average reward per game:  -0.071509 , Elapsed time  357.19  minutes.
# Iteration: 40300. Average reward per game:  -0.060317 , Elapsed time  357.95  minutes.
# Iteration: 40400. Average reward per game:  -0.064164 , Elapsed time  358.69  minutes.
# Iteration: 40500. Average reward per game:  -0.032039 , Elapsed time  359.54  minutes.
# Iteration: 40600. Average reward per game:  -0.056285 , Elapsed time  360.39  minutes.
# Iteration: 40700. Average reward per game:  -0.062938 , Elapsed time  361.24  minutes.
# Iteration: 40800. Average reward per game:  -0.055227 , Elapsed time  362.09  minutes.
# Iteration: 40900. Average reward per game:  -0.084827 , Elapsed time  362.93  minutes.
# Iteration: 41000. Average reward per game:  -0.054923 , Elapsed time  363.78  minutes.
# Iteration: 41100. Average reward per game:  -0.096792 , Elapsed time  364.63  minutes.
# Iteration: 41200. Average reward per game:  -0.074801 , Elapsed time  365.4  minutes.
# Iteration: 41300. Average reward per game:  -0.084374 , Elapsed time  366.16  minutes.
# Iteration: 41400. Average reward per game:  -0.077755 , Elapsed time  367.01  minutes.
# Iteration: 41500. Average reward per game:  -0.064954 , Elapsed time  367.86  minutes.
# Iteration: 41600. Average reward per game:  -0.101016 , Elapsed time  368.7  minutes.
# Iteration: 41700. Average reward per game:  -0.094662 , Elapsed time  369.55  minutes.
# Iteration: 41800. Average reward per game:  -0.065981 , Elapsed time  370.4  minutes.
# Iteration: 41900. Average reward per game:  -0.157019 , Elapsed time  371.07  minutes.
# Iteration: 42000. Average reward per game:  -0.097593 , Elapsed time  371.91  minutes.
# Iteration: 42100. Average reward per game:  -0.052726 , Elapsed time  372.76  minutes.
# Iteration: 42200. Average reward per game:  -0.103451 , Elapsed time  373.61  minutes.
# Iteration: 42300. Average reward per game:  -0.057223 , Elapsed time  374.45  minutes.
# Iteration: 42400. Average reward per game:  -0.129788 , Elapsed time  375.29  minutes.
# Iteration: 42500. Average reward per game:  -0.082308 , Elapsed time  375.97  minutes.
# Iteration: 42600. Average reward per game:  -0.076883 , Elapsed time  376.81  minutes.
# Iteration: 42700. Average reward per game:  -0.057676 , Elapsed time  377.65  minutes.
# Iteration: 42800. Average reward per game:  -0.055378 , Elapsed time  378.49  minutes.
# Iteration: 42900. Average reward per game:  -0.076863 , Elapsed time  379.34  minutes.
# Iteration: 43000. Average reward per game:  -0.063144 , Elapsed time  380.0  minutes.
# Iteration: 43100. Average reward per game:  -0.070887 , Elapsed time  380.84  minutes.
# Iteration: 43200. Average reward per game:  -0.074304 , Elapsed time  381.62  minutes.
# Iteration: 43300. Average reward per game:  -0.047392 , Elapsed time  382.37  minutes.
# Iteration: 43400. Average reward per game:  -0.07845 , Elapsed time  383.22  minutes.
# Iteration: 43500. Average reward per game:  -0.069808 , Elapsed time  384.01  minutes.
# Iteration: 43600. Average reward per game:  -0.072177 , Elapsed time  384.75  minutes.
# Iteration: 43700. Average reward per game:  -0.107929 , Elapsed time  385.59  minutes.
# Iteration: 43800. Average reward per game:  -0.067085 , Elapsed time  386.34  minutes.
# Iteration: 43900. Average reward per game:  -0.055872 , Elapsed time  387.12  minutes.
# Iteration: 44000. Average reward per game:  -0.05838 , Elapsed time  387.81  minutes.
# Iteration: 44100. Average reward per game:  -0.080276 , Elapsed time  388.59  minutes.
# Iteration: 44200. Average reward per game:  -0.108336 , Elapsed time  389.44  minutes.
# Iteration: 44300. Average reward per game:  -0.081665 , Elapsed time  390.29  minutes.
# Iteration: 44400. Average reward per game:  -0.056625 , Elapsed time  391.14  minutes.
# Iteration: 44500. Average reward per game:  -0.096084 , Elapsed time  391.85  minutes.
# Iteration: 44600. Average reward per game:  -0.07476 , Elapsed time  392.65  minutes.
# Iteration: 44700. Average reward per game:  -0.040027 , Elapsed time  393.45  minutes.
# Iteration: 44800. Average reward per game:  -0.051956 , Elapsed time  394.17  minutes.
# Iteration: 44900. Average reward per game:  -0.068474 , Elapsed time  395.01  minutes.
# Iteration: 45000. Average reward per game:  -0.077861 , Elapsed time  395.86  minutes.
# Iteration: 45100. Average reward per game:  -0.061992 , Elapsed time  396.55  minutes.
# Iteration: 45200. Average reward per game:  -0.037485 , Elapsed time  397.38  minutes.
# Iteration: 45300. Average reward per game:  -0.067474 , Elapsed time  398.22  minutes.
# Iteration: 45400. Average reward per game:  -0.195689 , Elapsed time  398.94  minutes.
# Iteration: 45500. Average reward per game:  -0.166191 , Elapsed time  399.74  minutes.
# Iteration: 45600. Average reward per game:  -0.071608 , Elapsed time  400.59  minutes.
# Iteration: 45700. Average reward per game:  -0.04142 , Elapsed time  401.43  minutes.
# Iteration: 45800. Average reward per game:  -0.084396 , Elapsed time  402.22  minutes.
# Iteration: 45900. Average reward per game:  -0.1612 , Elapsed time  402.97  minutes.
# Iteration: 46000. Average reward per game:  -0.136455 , Elapsed time  403.81  minutes.
# Iteration: 46100. Average reward per game:  -0.086471 , Elapsed time  404.46  minutes.
# Iteration: 46200. Average reward per game:  -0.071559 , Elapsed time  405.3  minutes.
# Iteration: 46300. Average reward per game:  -0.112281 , Elapsed time  406.14  minutes.
# Iteration: 46400. Average reward per game:  -0.08656 , Elapsed time  406.82  minutes.
# Iteration: 46500. Average reward per game:  -0.071474 , Elapsed time  407.5  minutes.
# Iteration: 46600. Average reward per game:  -0.056877 , Elapsed time  408.29  minutes.
# Iteration: 46700. Average reward per game:  -0.073498 , Elapsed time  409.03  minutes.
# Iteration: 46800. Average reward per game:  -0.058457 , Elapsed time  409.72  minutes.
# Iteration: 46900. Average reward per game:  -0.065447 , Elapsed time  410.57  minutes.
# Iteration: 47000. Average reward per game:  -0.06702 , Elapsed time  411.42  minutes.
# Iteration: 47100. Average reward per game:  -0.08884 , Elapsed time  412.27  minutes.
# Iteration: 47200. Average reward per game:  -0.075669 , Elapsed time  412.96  minutes.
# Iteration: 47300. Average reward per game:  -0.081101 , Elapsed time  413.81  minutes.
# Iteration: 47400. Average reward per game:  -0.122144 , Elapsed time  414.58  minutes.
# Iteration: 47500. Average reward per game:  -0.04889 , Elapsed time  415.34  minutes.
# Iteration: 47600. Average reward per game:  -0.102617 , Elapsed time  416.01  minutes.
# Iteration: 47700. Average reward per game:  -0.092194 , Elapsed time  416.86  minutes.
# Iteration: 47800. Average reward per game:  -0.09635 , Elapsed time  417.54  minutes.
# Iteration: 47900. Average reward per game:  -0.101096 , Elapsed time  418.37  minutes.
# Iteration: 48000. Average reward per game:  -0.210272 , Elapsed time  419.21  minutes.
# Iteration: 48100. Average reward per game:  -0.122362 , Elapsed time  419.9  minutes.
# Iteration: 48200. Average reward per game:  -0.095353 , Elapsed time  420.75  minutes.
# Iteration: 48300. Average reward per game:  -0.05659 , Elapsed time  421.38  minutes.
# Iteration: 48400. Average reward per game:  -0.088072 , Elapsed time  422.22  minutes.
# Iteration: 48500. Average reward per game:  -0.040579 , Elapsed time  423.04  minutes.
# Iteration: 48600. Average reward per game:  -0.065104 , Elapsed time  423.75  minutes.
# Iteration: 48700. Average reward per game:  -0.082195 , Elapsed time  424.6  minutes.
# Iteration: 48800. Average reward per game:  -0.127012 , Elapsed time  425.42  minutes.
# Iteration: 48900. Average reward per game:  -0.167494 , Elapsed time  426.12  minutes.
# Iteration: 49000. Average reward per game:  -0.092525 , Elapsed time  426.96  minutes.
# Iteration: 49100. Average reward per game:  -0.059016 , Elapsed time  427.8  minutes.
# Iteration: 49200. Average reward per game:  -0.048943 , Elapsed time  428.49  minutes.
# Iteration: 49300. Average reward per game:  -0.058662 , Elapsed time  429.33  minutes.
# Iteration: 49400. Average reward per game:  -0.071994 , Elapsed time  429.98  minutes.
# Iteration: 49500. Average reward per game:  -0.081074 , Elapsed time  430.81  minutes.
# Iteration: 49600. Average reward per game:  -0.079987 , Elapsed time  431.5  minutes.
# Iteration: 49700. Average reward per game:  -0.055053 , Elapsed time  432.29  minutes.
# Iteration: 49800. Average reward per game:  -0.067181 , Elapsed time  433.03  minutes.
# Iteration: 49900. Average reward per game:  -0.060043 , Elapsed time  433.88  minutes.
# Iteration: 50000. Average reward per game:  -0.08346 , Elapsed time  434.7  minutes.
# Iteration: 50100. Average reward per game:  -0.081065 , Elapsed time  435.35  minutes.
# Iteration: 50200. Average reward per game:  -0.040778 , Elapsed time  436.2  minutes.
# Iteration: 50300. Average reward per game:  -0.098488 , Elapsed time  437.05  minutes.
# Iteration: 50400. Average reward per game:  -0.096105 , Elapsed time  437.77  minutes.
# Iteration: 50500. Average reward per game:  -0.085441 , Elapsed time  438.58  minutes.
# Iteration: 50600. Average reward per game:  -0.137716 , Elapsed time  439.25  minutes.
# Iteration: 50700. Average reward per game:  -0.103747 , Elapsed time  440.1  minutes.
# Iteration: 50800. Average reward per game:  -0.068115 , Elapsed time  440.94  minutes.
# Iteration: 50900. Average reward per game:  -0.144896 , Elapsed time  441.79  minutes.
# Iteration: 51000. Average reward per game:  -0.083734 , Elapsed time  442.49  minutes.
# Iteration: 51100. Average reward per game:  -0.061974 , Elapsed time  443.33  minutes.
# Iteration: 51200. Average reward per game:  -0.079573 , Elapsed time  444.16  minutes.
# Iteration: 51300. Average reward per game:  -0.062643 , Elapsed time  444.84  minutes.
# Iteration: 51400. Average reward per game:  -0.066314 , Elapsed time  445.59  minutes.
# Iteration: 51500. Average reward per game:  -0.099082 , Elapsed time  446.37  minutes.
# Iteration: 51600. Average reward per game:  -0.053107 , Elapsed time  447.04  minutes.
# Iteration: 51700. Average reward per game:  -0.053133 , Elapsed time  447.89  minutes.
# Iteration: 51800. Average reward per game:  -0.045719 , Elapsed time  448.53  minutes.
# Iteration: 51900. Average reward per game:  -0.063537 , Elapsed time  449.37  minutes.
# Iteration: 52000. Average reward per game:  -0.067017 , Elapsed time  450.05  minutes.
# Iteration: 52100. Average reward per game:  -0.104415 , Elapsed time  450.72  minutes.
# ...
# Iteration: 81800. Average reward per game:  -0.072475 , Elapsed time  676.58  minutes.
# Iteration: 81900. Average reward per game:  -0.078938 , Elapsed time  677.25  minutes.
# Iteration: 82000. Average reward per game:  -0.062545 , Elapsed time  678.09  minutes.
# Iteration: 82100. Average reward per game:  -0.068153 , Elapsed time  678.82  minutes.
# Iteration: 82200. Average reward per game:  -0.062049 , Elapsed time  679.63  minutes.
# Iteration: 82300. Average reward per game:  -0.105151 , Elapsed time  680.29  minutes.
# Iteration: 82400. Average reward per game:  -0.146069 , Elapsed time  681.08  minutes.
# Iteration: 82500. Average reward per game:  -0.059842 , Elapsed time  681.86  minutes.
# Iteration: 82600. Average reward per game:  -0.08644 , Elapsed time  682.6  minutes.
# Iteration: 82700. Average reward per game:  -0.049971 , Elapsed time  683.37  minutes.
# Iteration: 82800. Average reward per game:  -0.081911 , Elapsed time  684.11  minutes.
# Iteration: 82900. Average reward per game:  -0.050603 , Elapsed time  684.78  minutes.
# Iteration: 83000. Average reward per game:  -0.079425 , Elapsed time  685.62  minutes.
# Iteration: 83100. Average reward per game:  -0.081648 , Elapsed time  686.47  minutes.
# Iteration: 83200. Average reward per game:  -0.062708 , Elapsed time  687.22  minutes.
# Iteration: 83300. Average reward per game:  -0.079197 , Elapsed time  688.01  minutes.
# Iteration: 83400. Average reward per game:  -0.080836 , Elapsed time  688.86  minutes.
# Iteration: 83500. Average reward per game:  -0.104644 , Elapsed time  689.54  minutes.
# Iteration: 83600. Average reward per game:  -0.078915 , Elapsed time  714.17  minutes.
# Iteration: 83700. Average reward per game:  -0.036481 , Elapsed time  714.72  minutes.
# Iteration: 83800. Average reward per game:  -0.068866 , Elapsed time  715.36  minutes.
# Iteration: 83900. Average reward per game:  -0.069021 , Elapsed time  715.98  minutes.
# Iteration: 84000. Average reward per game:  -0.039437 , Elapsed time  716.6  minutes.
# Iteration: 84100. Average reward per game:  -0.057626 , Elapsed time  717.22  minutes.
# Iteration: 84200. Average reward per game:  -0.154593 , Elapsed time  717.83  minutes.
# Iteration: 84300. Average reward per game:  -0.060363 , Elapsed time  718.45  minutes.
# Iteration: 84400. Average reward per game:  -0.040997 , Elapsed time  719.07  minutes.
# Iteration: 84500. Average reward per game:  -0.078059 , Elapsed time  719.69  minutes.
# Iteration: 84600. Average reward per game:  -0.058911 , Elapsed time  720.31  minutes.
# Iteration: 84700. Average reward per game:  -0.073496 , Elapsed time  720.94  minutes.
# Iteration: 84800. Average reward per game:  -0.060183 , Elapsed time  721.62  minutes.
# Iteration: 84900. Average reward per game:  -0.074832 , Elapsed time  722.3  minutes.
# Iteration: 85000. Average reward per game:  -0.051419 , Elapsed time  722.97  minutes.
# Iteration: 85100. Average reward per game:  -0.080404 , Elapsed time  723.66  minutes.
# Iteration: 85200. Average reward per game:  -0.209281 , Elapsed time  724.29  minutes.
# Iteration: 85300. Average reward per game:  -0.226146 , Elapsed time  724.96  minutes.
# Iteration: 85400. Average reward per game:  -0.26786 , Elapsed time  725.66  minutes.
# Iteration: 85500. Average reward per game:  -0.260643 , Elapsed time  726.35  minutes.
# Iteration: 85600. Average reward per game:  -0.330646 , Elapsed time  727.03  minutes.
# Iteration: 85700. Average reward per game:  -0.261414 , Elapsed time  727.68  minutes.
# Iteration: 85800. Average reward per game:  -0.189996 , Elapsed time  728.38  minutes.
# Iteration: 85900. Average reward per game:  -0.133613 , Elapsed time  729.12  minutes.
# Iteration: 86000. Average reward per game:  -0.101862 , Elapsed time  729.77  minutes.
# Iteration: 86100. Average reward per game:  -0.118771 , Elapsed time  730.44  minutes.
# Iteration: 86200. Average reward per game:  -0.080302 , Elapsed time  731.1  minutes.
# Iteration: 86300. Average reward per game:  -0.084176 , Elapsed time  731.86  minutes.
# Iteration: 86400. Average reward per game:  -0.103716 , Elapsed time  732.54  minutes.
# Iteration: 86500. Average reward per game:  -0.058637 , Elapsed time  733.36  minutes.
# Iteration: 86600. Average reward per game:  -0.048212 , Elapsed time  734.23  minutes.
# Iteration: 86700. Average reward per game:  -0.050482 , Elapsed time  734.92  minutes.
# Iteration: 86800. Average reward per game:  -0.05846 , Elapsed time  735.69  minutes.
# Iteration: 86900. Average reward per game:  -0.056239 , Elapsed time  736.48  minutes.
# Iteration: 87000. Average reward per game:  -0.096575 , Elapsed time  737.35  minutes.
# Iteration: 87100. Average reward per game:  -0.104205 , Elapsed time  738.02  minutes.
# Iteration: 87200. Average reward per game:  -0.049095 , Elapsed time  739.04  minutes.
# Iteration: 87300. Average reward per game:  -0.050945 , Elapsed time  740.14  minutes.
# Iteration: 87400. Average reward per game:  -0.094182 , Elapsed time  741.26  minutes.
# Iteration: 87500. Average reward per game:  -0.11463 , Elapsed time  742.32  minutes.
# Iteration: 87600. Average reward per game:  -0.095846 , Elapsed time  743.28  minutes.
# Iteration: 87700. Average reward per game:  -0.048148 , Elapsed time  744.12  minutes.
# Iteration: 87800. Average reward per game:  -0.061372 , Elapsed time  745.15  minutes.
# Iteration: 87900. Average reward per game:  -0.100995 , Elapsed time  746.14  minutes.
# Iteration: 88000. Average reward per game:  -0.107525 , Elapsed time  747.11  minutes.
# Iteration: 88100. Average reward per game:  -0.071023 , Elapsed time  748.11  minutes.
# Iteration: 88200. Average reward per game:  -0.122415 , Elapsed time  748.9  minutes.
# Iteration: 88300. Average reward per game:  -0.156522 , Elapsed time  749.91  minutes.
# Iteration: 88400. Average reward per game:  -0.141255 , Elapsed time  750.97  minutes.
# Iteration: 88500. Average reward per game:  -0.096483 , Elapsed time  751.87  minutes.
# Iteration: 88600. Average reward per game:  -0.182085 , Elapsed time  752.94  minutes.
# Iteration: 88700. Average reward per game:  -0.184913 , Elapsed time  754.11  minutes.
# Iteration: 88800. Average reward per game:  -0.155536 , Elapsed time  755.37  minutes.
# Iteration: 88900. Average reward per game:  -0.087607 , Elapsed time  756.57  minutes.
# Iteration: 89000. Average reward per game:  -0.132467 , Elapsed time  757.69  minutes.
# Iteration: 89100. Average reward per game:  -0.068675 , Elapsed time  758.81  minutes.
# Iteration: 89200. Average reward per game:  -0.09424 , Elapsed time  759.94  minutes.
# Iteration: 89300. Average reward per game:  -0.094123 , Elapsed time  761.09  minutes.
# Iteration: 89400. Average reward per game:  -0.179125 , Elapsed time  762.25  minutes.
# Iteration: 89500. Average reward per game:  -0.163063 , Elapsed time  763.38  minutes.
# Iteration: 89600. Average reward per game:  -0.096135 , Elapsed time  764.49  minutes.
# Iteration: 89700. Average reward per game:  -0.164125 , Elapsed time  765.47  minutes.
# Iteration: 89800. Average reward per game:  -0.07828 , Elapsed time  766.45  minutes.
# Iteration: 89900. Average reward per game:  -0.057892 , Elapsed time  767.53  minutes.
# Iteration: 90000. Average reward per game:  -0.076004 , Elapsed time  768.66  minutes.
# Iteration: 90100. Average reward per game:  -0.084905 , Elapsed time  769.75  minutes.
# Iteration: 90200. Average reward per game:  -0.05242 , Elapsed time  770.94  minutes.
# Iteration: 90300. Average reward per game:  -0.075241 , Elapsed time  772.17  minutes.
# Iteration: 90400. Average reward per game:  -0.056775 , Elapsed time  773.31  minutes.
# Iteration: 90500. Average reward per game:  -0.060695 , Elapsed time  774.42  minutes.
# Iteration: 90600. Average reward per game:  -0.084223 , Elapsed time  775.54  minutes.
# Iteration: 90700. Average reward per game:  -0.055171 , Elapsed time  776.68  minutes.
# Iteration: 90800. Average reward per game:  -0.139615 , Elapsed time  777.81  minutes.
# Iteration: 90900. Average reward per game:  -0.103706 , Elapsed time  778.97  minutes.
# Iteration: 91000. Average reward per game:  -0.090593 , Elapsed time  780.11  minutes.
# Iteration: 91100. Average reward per game:  -0.088203 , Elapsed time  781.24  minutes.
# Iteration: 91200. Average reward per game:  -0.062109 , Elapsed time  782.37  minutes.
# Iteration: 91300. Average reward per game:  -0.047544 , Elapsed time  783.53  minutes.
# Iteration: 91400. Average reward per game:  -0.031863 , Elapsed time  784.66  minutes.
# Iteration: 91500. Average reward per game:  -0.062192 , Elapsed time  785.81  minutes.
# Iteration: 91600. Average reward per game:  -0.0934 , Elapsed time  786.94  minutes.
# Iteration: 91700. Average reward per game:  -0.097451 , Elapsed time  788.08  minutes.
# Iteration: 91800. Average reward per game:  -0.049277 , Elapsed time  789.2  minutes.
# Iteration: 91900. Average reward per game:  -0.042392 , Elapsed time  790.33  minutes.
# Iteration: 92000. Average reward per game:  -0.086256 , Elapsed time  791.43  minutes.
# Iteration: 92100. Average reward per game:  -0.069442 , Elapsed time  792.37  minutes.
# Iteration: 92200. Average reward per game:  -0.050786 , Elapsed time  793.33  minutes.
# Iteration: 92300. Average reward per game:  -0.065717 , Elapsed time  794.3  minutes.
# Iteration: 92400. Average reward per game:  -0.049608 , Elapsed time  795.27  minutes.
# Iteration: 92500. Average reward per game:  -0.057607 , Elapsed time  796.24  minutes.
# Iteration: 92600. Average reward per game:  -0.043599 , Elapsed time  797.19  minutes.
# Iteration: 92700. Average reward per game:  -0.081222 , Elapsed time  798.15  minutes.
# Iteration: 92800. Average reward per game:  -0.04351 , Elapsed time  799.11  minutes.
# Iteration: 92900. Average reward per game:  -0.061324 , Elapsed time  800.1  minutes.
# Iteration: 93000. Average reward per game:  -0.083722 , Elapsed time  801.13  minutes.
# Iteration: 93100. Average reward per game:  -0.065955 , Elapsed time  802.09  minutes.
# Iteration: 93200. Average reward per game:  -0.073703 , Elapsed time  803.1  minutes.
# Iteration: 93300. Average reward per game:  -0.053261 , Elapsed time  804.07  minutes.
# Iteration: 93400. Average reward per game:  -0.032979 , Elapsed time  805.04  minutes.
# Iteration: 93500. Average reward per game:  -0.071581 , Elapsed time  806.02  minutes.
# Iteration: 93600. Average reward per game:  -0.080994 , Elapsed time  806.97  minutes.
# Iteration: 93700. Average reward per game:  -0.081023 , Elapsed time  807.93  minutes.
# Iteration: 93800. Average reward per game:  -0.03781 , Elapsed time  808.89  minutes.
# Iteration: 93900. Average reward per game:  -0.060482 , Elapsed time  809.86  minutes.
# Iteration: 94000. Average reward per game:  -0.048035 , Elapsed time  810.82  minutes.
# Iteration: 94100. Average reward per game:  -0.045455 , Elapsed time  811.79  minutes.
# Iteration: 94200. Average reward per game:  -0.075902 , Elapsed time  812.74  minutes.
# Iteration: 94300. Average reward per game:  -0.035206 , Elapsed time  813.71  minutes.
# Iteration: 94400. Average reward per game:  -0.069031 , Elapsed time  814.66  minutes.
# Iteration: 94500. Average reward per game:  -0.082231 , Elapsed time  815.62  minutes.
# Iteration: 94600. Average reward per game:  -0.096936 , Elapsed time  816.6  minutes.
# Iteration: 94700. Average reward per game:  -0.14878 , Elapsed time  817.56  minutes.
# Iteration: 94800. Average reward per game:  -0.126877 , Elapsed time  818.57  minutes.
# Iteration: 94900. Average reward per game:  -0.125201 , Elapsed time  819.53  minutes.
# Iteration: 95000. Average reward per game:  -0.121142 , Elapsed time  820.48  minutes.
# Iteration: 95100. Average reward per game:  -0.104074 , Elapsed time  821.48  minutes.
# Iteration: 95200. Average reward per game:  -0.080599 , Elapsed time  822.5  minutes.
# Iteration: 95300. Average reward per game:  -0.070911 , Elapsed time  823.49  minutes.
# Iteration: 95400. Average reward per game:  -0.082722 , Elapsed time  824.62  minutes.
# Iteration: 95500. Average reward per game:  -0.079674 , Elapsed time  825.7  minutes.
# Iteration: 95600. Average reward per game:  -0.062739 , Elapsed time  826.74  minutes.
# Iteration: 95700. Average reward per game:  -0.113226 , Elapsed time  827.72  minutes.
# Iteration: 95800. Average reward per game:  -0.115186 , Elapsed time  828.7  minutes.
# Iteration: 95900. Average reward per game:  -0.085084 , Elapsed time  829.66  minutes.
# Iteration: 96000. Average reward per game:  -0.104231 , Elapsed time  830.62  minutes.
# Iteration: 96100. Average reward per game:  -0.094346 , Elapsed time  831.63  minutes.
# Iteration: 96200. Average reward per game:  -0.120528 , Elapsed time  832.6  minutes.
# Iteration: 96300. Average reward per game:  -0.080825 , Elapsed time  833.56  minutes.
# Iteration: 96400. Average reward per game:  -0.05248 , Elapsed time  834.54  minutes.
# Iteration: 96500. Average reward per game:  -0.059391 , Elapsed time  835.52  minutes.
# Iteration: 96600. Average reward per game:  -0.039828 , Elapsed time  836.49  minutes.
# Iteration: 96700. Average reward per game:  -0.101814 , Elapsed time  837.49  minutes.
# Iteration: 96800. Average reward per game:  -0.042521 , Elapsed time  838.46  minutes.
# Iteration: 96900. Average reward per game:  -0.061396 , Elapsed time  839.42  minutes.
# Iteration: 97000. Average reward per game:  -0.119409 , Elapsed time  840.4  minutes.
# Iteration: 97100. Average reward per game:  -0.053849 , Elapsed time  841.36  minutes.
# Iteration: 97200. Average reward per game:  -0.108802 , Elapsed time  842.44  minutes.
# Iteration: 97300. Average reward per game:  -0.103549 , Elapsed time  843.47  minutes.
# Iteration: 97400. Average reward per game:  -0.071343 , Elapsed time  844.48  minutes.
# Iteration: 97500. Average reward per game:  -0.041081 , Elapsed time  845.43  minutes.
# Iteration: 97600. Average reward per game:  -0.053815 , Elapsed time  846.38  minutes.
# Iteration: 97700. Average reward per game:  -0.081114 , Elapsed time  847.36  minutes.
# Iteration: 97800. Average reward per game:  -0.11116 , Elapsed time  848.32  minutes.
# Iteration: 97900. Average reward per game:  -0.06484 , Elapsed time  849.27  minutes.
# Iteration: 98000. Average reward per game:  -0.105629 , Elapsed time  850.23  minutes.
# Iteration: 98100. Average reward per game:  -0.10039 , Elapsed time  851.2  minutes.
# Iteration: 98200. Average reward per game:  -0.050549 , Elapsed time  852.26  minutes.
# Iteration: 98300. Average reward per game:  -0.06686 , Elapsed time  853.28  minutes.
# Iteration: 98400. Average reward per game:  -0.049955 , Elapsed time  854.32  minutes.
# Iteration: 98500. Average reward per game:  -0.044451 , Elapsed time  855.32  minutes.
# Iteration: 98600. Average reward per game:  -0.125856 , Elapsed time  856.45  minutes.
# Iteration: 98700. Average reward per game:  -0.070172 , Elapsed time  857.46  minutes.
# Iteration: 98800. Average reward per game:  -0.06117 , Elapsed time  858.48  minutes.
# Iteration: 98900. Average reward per game:  -0.047671 , Elapsed time  859.54  minutes.
# Iteration: 99000. Average reward per game:  -0.0445 , Elapsed time  860.67  minutes.
# Iteration: 99100. Average reward per game:  -0.067073 , Elapsed time  861.73  minutes.
# Iteration: 99200. Average reward per game:  -0.047439 , Elapsed time  862.76  minutes.
# Iteration: 99300. Average reward per game:  -0.112217 , Elapsed time  863.76  minutes.
# Iteration: 99400. Average reward per game:  -0.042797 , Elapsed time  864.87  minutes.
# Iteration: 99500. Average reward per game:  -0.049551 , Elapsed time  866.0  minutes.
# Iteration: 99600. Average reward per game:  -0.079461 , Elapsed time  867.09  minutes.
# Iteration: 99700. Average reward per game:  -0.033226 , Elapsed time  868.08  minutes.
# Iteration: 99800. Average reward per game:  -0.041625 , Elapsed time  869.14  minutes.
# Iteration: 99900. Average reward per game:  -0.083106 , Elapsed time  870.2  minutes.
# Iteration: 100000. Average reward per game:  -0.085307 , Elapsed time  871.21  minutes.
# Simulation finished. Elapsed time  871.22  minutes.

# %% [markdown]
# ## Visualizations

# %%
# Visualizing train simulation:

#episode =episodes
#simulation_id = 2
#step = 30

discrewards = pd.read_table(rewards_file, sep = ",")

indices = [i for i in range(0,n_iterations,1)]

plt.plot(discrewards['iteration'][indices],discrewards['discreward'][indices], label = "Discounted rewards")
plt.title("Discounted rewards per episode during training")
plt.xlabel("Episode")
plt.ylabel("Discounted reward")
plt.savefig(simulation_directory + '/discounted-rewards-sim' + '{}'.format(simulation_id) + '.pdf')

plt.show()
plt.close()

# %% [markdown]
# # PG Testing

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 1

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 


with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
               
        env.close()
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation317/NN-models/pdenv_best_policy_net_pg.ckpt

# %% [markdown]
# ## Giff animation

# %%
test_anim = ut.create_system_animation(frames, n_episodes * episode_length)
plt.close()

HTML(test_anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## Visualization with matplotlib

# %%
from utils_pg import is_empty
from utils_pg import my_indicator

def visualize_simulation(states_file,
                        test_toy_system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list):
    test_states = pd.read_table(states_file, sep = ",")
    test_states.head()


    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, n)]
    lvl_colors = ["Orange", "Green","Orange"]

    #tanks = test_toy_system.tanks
    tanks_max_load = system.tank_max_loads
    level_percentages = system.load_level_percentages

    for i, color in enumerate(colors, start=1):    
        plt.subplot(2,3,i)
        states = test_states['stock{}'.format(i-1)]
        plt.plot(test_states['step'],states, label = "Shop {}".format(i-1), color = "Black")
        plt.title("Shop {}".format(i-1))

        plt.axhline(y= tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = "Red", linestyle = '--')
        for lvl_color, lvl in zip(lvl_colors, level_percentages[i-1]):
            plt.axhline(y= lvl * tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = lvl_color, 
                        linestyle = '--')
        plt.axhline(y= 0, xmin=0, xmax=episode_length, hold=None, color = "Red", linestyle = '--')


        percentages = level_percentages[i-1]           
        c = percentages[1]
        e = percentages[2]          
        d = ct.p0_GLOBAL*e+(1-ct.p0_GLOBAL)*c
        plt.axhline(y= d*tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = "lawngreen", 
                    linestyle = '-.')

        plt.axhline(y= np.mean(states), xmin=0, xmax=episode_length, hold=None, 
                    color = "blue", linestyle = '-.')
        plt.xticks(range(0,episode_length*n_episodes+1,5*n_episodes
                        ))
        
        #################### INFO LEVELS
        b = percentages[0]
        level_counts = np.zeros(5, dtype = np.int64)
        
        x_mins = np.array([0,b,c,e])*tanks_max_load[i-1]
        x_maxs = np.array([b,c,e,1])*tanks_max_load[i-1]

        for x in states:
            level_counts[0] = level_counts[0] + is_empty(x)
            for j in range(1,5):
                level_counts[j] = level_counts[j] + my_indicator(x_mins[j-1], x, x_maxs[j-1])
            
        level_counts_list.append(level_counts)
        ###################################################

    plt.subplot(2,3,6)
    plt.title("Legend")
    plt.axis('off')

    #plt.legend(bbox_to_anchor=(0.5 ,0.8), loc=2, borderaxespad=0.)
    plt.yticks([])
    plt.xticks([])

    patch1 = mpatches.Patch(color='red', label='Max/Min capacities', linestyle = '--', fill = False, linewidth = 2)
    patch2 = mpatches.Patch(color='orange', label='Max/Min levels', linestyle = '--', fill = False, linewidth = 2)
    patch3 = mpatches.Patch(color='green', label='Danger level', linestyle = '--', fill = False, linewidth = 2)
    patch4 = mpatches.Patch(color='lawngreen', label='Max reward level (M)', linestyle = '-.', fill = False, linewidth = 2)
    patch5 = mpatches.Patch(color='blue', label='Observed mean level', linestyle = '-.', fill = False, linewidth = 2)
    patch6 = mpatches.Patch(color='black', label='Current stock level', linestyle = '-', fill = False, linewidth = 2)


    plt.legend(handles=[patch1, patch2, patch3, patch4, patch5, patch6], loc = 'center')

    plt.tight_layout() 
    plt.savefig(simulation_directory + '/tank-levels-sim' + '{}'.format(simulation_id) + '.pdf')
    plt.show()
    plt.close()

# %%
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list)

# %% [markdown]
# ## Performance metrics

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 1

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 

####
test_visualization_steps = []
test_rewards_list = []
test_level_rewards_list = []
test_transport_rewards_list = []
test_trucks_sent_list = []
test_number_of_first_trucks_sent_list = []
test_number_of_second_trucks_sent_list = []
test_number_of_trucks_not_deliverying_list = []
####

with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            #####
            discounted_reward = 0 
            transport_rewards = 0
            level_rewards = 0
            number_of_trucks_sent = 0
            number_of_first_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_second_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_trucks_not_deliverying = 0                   
            #####         
         
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
            
                trucks_not_del = info["trucks_not_deliverying"]
                level_reward = info["level_rewards"]
                transport_reward = info["transport_rewards"]
                ### STORE STEP INFO
                discounted_reward = discounted_reward + (discount_rate**(step)) * reward
                transport_rewards = transport_rewards+transport_reward
                level_rewards = level_rewards + level_reward
                
                number_of_trucks_sent = number_of_trucks_sent + np.sum(vect_action == 5)
                index1 = vect_action[0]
                number_of_first_trucks_sent[index1] = number_of_first_trucks_sent[index1] + 1
                index2 = vect_action[1]
                number_of_second_trucks_sent[index2] = number_of_second_trucks_sent[index2] + 1
                number_of_trucks_not_deliverying =  number_of_trucks_not_deliverying + trucks_not_del
                
            test_rewards_list.append(discounted_reward);
            test_transport_rewards_list.append(transport_rewards);
            test_level_rewards_list.append(level_rewards);
            test_trucks_sent_list.append(episode_length * system.k - number_of_trucks_sent);
            test_number_of_first_trucks_sent_list.append(number_of_first_trucks_sent);
            test_number_of_second_trucks_sent_list.append(number_of_second_trucks_sent);
            test_number_of_trucks_not_deliverying_list.append(number_of_trucks_not_deliverying);                   
                
               
        env.close()
        
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list) 

print("Total discounted rewards","Level rewards", "Transport rewards")
print(sum(test_rewards_list)/n_episodes, sum(test_level_rewards_list)/n_episodes,sum(test_transport_rewards_list)/n_episodes )
print("Average trucks sent: ", sum(test_trucks_sent_list)/n_episodes)
    
#     if n_episodes == 1:
print("Average 1st type Trucks sent to each shop:", sum(test_number_of_first_trucks_sent_list)/n_episodes )
print("Average 2nd type Trucks sent to each shop:", sum(test_number_of_second_trucks_sent_list)/n_episodes )
print("Average number of trucks not deliverying:", sum(test_number_of_trucks_not_deliverying_list)/n_episodes )

for i in range(n):
        print("Average level counts for shop {}:".format(i), test_level_counts_list[i]/n_episodes )

        
print("Average total level counts:", sum(test_level_counts_list)/n_episodes )
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation317/NN-models/pdenv_best_policy_net_pg.ckpt
# Total discounted rewards Level rewards Transport rewards
# -0.3692650873906208 -2.022525498801799 0.03317559254999998
# Average trucks sent:  42.0
# Average 1st type Trucks sent to each shop: [ 6.  0.  5.  0.  6. 13.]
# Average 2nd type Trucks sent to each shop: [ 0.  1.  0. 19.  5.  5.]
# Average number of trucks not deliverying: 0.0
# Average level counts for shop 0: [ 1.  0. 11. 18.  0.]
# Average level counts for shop 1: [ 0.  0.  0. 30.  0.]
# Average level counts for shop 2: [ 1.  1.  5. 23.  0.]
# Average level counts for shop 3: [ 0.  1.  6. 23.  0.]
# Average level counts for shop 4: [ 0.  2. 12. 16.  0.]
# Average total level counts: [  2.   4.  34. 110.   0.]
