# %%
""" 
The algorithm is tested on the PDSystemEnv  gym task 
and developed with Tensorflow

Author: Daniel Salgado Rojo
"""

import tensorflow as tf
import numpy as np
import gym
import gym_pdsystem
from gym import wrappers
#import tflearn
import argparse
import pprint as pp

#from ddpg.replay_buffer import ReplayBuffer

from datetime import datetime

import random

from gym_pdsystem.envs.pdsystem_env import PDSystemEnv
import gym_pdsystem.utils.utilsq as ut
import gym_pdsystem.utils.constants as ct
import gym_pdsystem.utils.functions as fnc


from matplotlib import animation, rc
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import HTML


import pandas as pd
import time

from functools import partial

import os

#TO OMMIT WARNINGS
import warnings
warnings.filterwarnings('ignore')

def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)
    
simulations_directory = './simulations'
if not os.path.exists(simulations_directory):
    os.makedirs(simulations_directory)
# Out:
# /home/dsalgador/anaconda3/envs/tensorflow/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # System's parmeters

# %%
# In order to change the parameters of the system, such as number of shops, trucks, etc, one must change
# the corresponding constants in the 'constants.py' file from the 'gym pd_system' package.

CASE = ct.CASE
STOCHASTIC = ct.STOCHASTIC 

###########################################################

TANK_MAX_LOADS = ct.TANK_MAX_LOADS
LEVEL_PERCENTAGES = ct.LEVEL_PERCENTAGES 
TRUCK_MAX_LOADS = ct.TRUCK_MAX_LOADS
GRAPH_WEIGHTS = ct.GRAPH_WEIGHTS 
DISCRETE = ct.DISCRETE

n = len(TANK_MAX_LOADS)
k = len(TRUCK_MAX_LOADS)

env = gym.make("PDSystemEnv-v0")
episode_length = 30
env._max_episode_steps = episode_length

###########################################################

print("System with k={} trucks and n={} shops. Episodes of {} days.".format(k,n,episode_length))
# Out:
# System with k=2 trucks and n=5 shops. Episodes of 30 days.

# %%
import utils_pg
from utils_pg import int_to_action
from utils_pg import action_to_int
from utils_pg import discount_rewards
from utils_pg import normalize_rewards

# %% [markdown]
# # Tensorflow graph (DNN) for MC Policy Gradient Algorithm

# %%
simulation_id = 328

# Create directories for the simulations' outputs

simulation_directory = './simulations/simulation{}'.format(simulation_id)
rewards_file = simulation_directory+'/discrewards'+ '/rewards-sim{}.csv'.format(simulation_id)
states_file = simulation_directory+'/vis'+ '/states-sim{}.csv'.format(simulation_id) # for testing
models_dir = simulation_directory + '/NN-models'

if not os.path.exists(simulation_directory):
    os.makedirs(simulation_directory)
    os.makedirs(models_dir)
    os.makedirs(simulation_directory + '/discrewards')
    os.makedirs(simulation_directory + '/vis')
    
else:
    raise Exception("The simulation id you tried to use has been already used before. Try to change it to a new one.")

# Output headers to file
with open(rewards_file,'w') as f:
     np.savetxt(f, [["iteration", "discreward"]], fmt="%s", delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-b6cb68e7f3ea> in <module>()
#      15
#      16 else:
# ---> 17     raise Exception("The simulation id you tried to use has been already used before. Try to change it to a new one.")
#      18
#      19 # Output headers to file
#
# Exception: The simulation id you tried to use has been already used before. Try to change it to a new one.

# %%
seed = 42
reset_graph(seed)

################################
# TensorBoard summary directories
now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
root_logdir = "tf_logs"
logdir = "{}/run-{}/".format(root_logdir, now)   
################################

## DNN hyperparameters ################
learning_rate = 0.01 #0.01

hidden1_neurons = 100 #100
hidden2_neurons = 50 #50

# batch_normalization = True  
# batch_norm_momentum = 0.9
######################################



######################################
#### Training hyperparameters ########
######################################
# File names for the model

model_file = models_dir + "/pdenv_policy_net_pg.ckpt"#.format(learning_rate)
best_model_file = models_dir + "/pdenv_best_policy_net_pg.ckpt"#.format(learning_rate)
graph_file =  '{}.meta'.format(model_file)


# Simulation / Training parameters
n_games_per_update = 10
n_max_steps = episode_length
n_iterations = 10**5 #2*10**4
save_iterations = 100 # USEFUL WHEN USING EARLY STOPPING
discount_rate = 0.9

info_freq = 100 #100
round_time = 2
round_reward = 6
summary_freq = 20#int(info_freq/2), 10

# Early stopping
max_checks_without_progress = np.inf # 10,  one for each "info_freq" (in terms of iterations it would be
                                                            #max_checks_without_progress *  info_freq)
checks_without_progress = 0
best_reward = -np.infty


retrain = False
########################################



###### TENSORFLOW GRAPH #########
tf.set_random_seed(seed)
with tf.name_scope("dnn"):
        
            # 1. Parameters to determine the NN architecture

            n_inputs = env.observation_space.shape[1]
            n_hidden1 = hidden1_neurons; activation1 = tf.nn.sigmoid#tf.nn.elu
            n_hidden2 = hidden2_neurons; activation2 = tf.nn.sigmoid#tf.nn.elu
            n_outputs = env.action_space.shape[1]**env.action_space.shape[0]
            
            he_init = tf.contrib.layers.variance_scaling_initializer(seed = seed)

            X = tf.placeholder(tf.float32, shape = (None, n_inputs), name = "X")
            
                    
            hidden1 = tf.layers.dense(X, n_hidden1, activation = activation1,
                                     kernel_initializer = he_init)
            hidden2 = tf.layers.dense(hidden1, n_hidden2, activation = activation2,
                                     kernel_initializer = he_init)
            logits = tf.layers.dense(hidden2, n_outputs, name = "logits"
                                     ,kernel_initializer = he_init)
            
            outputs = tf.nn.softmax(logits)
                   
            
with tf.name_scope("action"):
            # 3. Select a random action (where to go) based on the estimated probabilities
            action = tf.multinomial(tf.log(outputs), num_samples = 1)
            test_action = tf.argmax(outputs, axis = 1)
  
            y = tf.reshape(action, [1])
            
with tf.name_scope("loss"):
            xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels = y,logits = logits)
            loss = tf.reduce_mean(xentropy, name = "loss")
            
tf.summary.scalar('average_cross_entropy', loss)


with tf.name_scope("train"):
            # Optimization Op
            optimizer = tf.train.AdamOptimizer(learning_rate)
            
            grads_and_vars = optimizer.compute_gradients(xentropy)
            gradients = [grad for grad, variable in grads_and_vars]
            gradient_placeholders = []
            grads_and_vars_feed = []
            for grad, variable in grads_and_vars:
                gradient_placeholder = tf.placeholder(tf.float32, shape=grad.get_shape())
                gradient_placeholders.append(gradient_placeholder)
                grads_and_vars_feed.append((gradient_placeholder, variable))
            training_op = optimizer.apply_gradients(grads_and_vars_feed)
                        
                                       
merged = tf.summary.merge_all()
init = tf.global_variables_initializer()
file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
        
saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From /home/dsalgador/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %% [markdown]
# # PG Training

# %%
# with tf.Session() as sess:
    
#     #train_writer = tf.summary.FileWriter(logdir + '/pgtrain', sess.graph)
#     if retrain:
#         saver.restore(sess, model_file)
        
#     summary2 = tf.Summary()
#     if not retrain:
#         init.run()
#     time_start = time.time()

#     for iteration in range(n_iterations+1):
#         print("\rIteration: {}".format(iteration), end="")
#         all_rewards = []
#         all_gradients = []
#         for game in range(n_games_per_update):
#             current_rewards = []
#             current_gradients = []
#             obs = env.reset()
#             for step in range(n_max_steps):
#                 action_val, gradients_val = sess.run([action, gradients], feed_dict={X: obs.reshape(1, n_inputs)}) 
#                 #print(action_val)
#                 vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
#                 #print(vect_action)
#                 obs, reward, done, info = env.step(vect_action)
#                 current_rewards.append(reward)
#                 current_gradients.append(gradients_val)                
                
#                 if done:
#                     break
#             all_rewards.append(current_rewards)
#             all_gradients.append(current_gradients)
            
        
#         all_disc_rewards =  [discount_rewards(rewards, discount_rate) for rewards in all_rewards]
#         all_disc_norm_rewards = normalize_rewards(all_disc_rewards)     

#         feed_dict = {}
#         for var_index, gradient_placeholder in enumerate(gradient_placeholders):
#             mean_gradients = np.mean([reward * all_gradients[game_index][step][var_index]
#                                       for game_index, rewards in enumerate(all_disc_norm_rewards)
#                                           for step, reward in enumerate(rewards)], axis=0)
#             feed_dict[gradient_placeholder] = mean_gradients
         
       
#         #tf.summary.scalar('avg_rewards', avg_rewards)
#         #train_writer.add_summary(avg_rewards, iteration)

#         # Summary and info printings     ###################################################################
#         if iteration % info_freq == 0 or iteration % summary_freq == 0:  
            
#             #avg_rewards =np.array([np.mean(np.array(all_rewards)) / n_games_per_update])
#             avg_rewards =np.mean(np.array(all_disc_rewards)) / n_games_per_update
# #             print(avg_rewards)
#             #avg_rewards_list.append(avg_rewards)
#             if iteration % summary_freq == 0:
#                 summary2.value.add(tag='average_reward_per_game', simple_value = avg_rewards)
#                 file_writer.add_summary(summary2, iteration)

#                 feed_dict[X] = obs.reshape(1, n_inputs)
#                 summary = sess.run(merged, feed_dict= feed_dict)

#                 file_writer.add_summary(summary, iteration)
                
#                   # Disc rewards, etc ####
       
#                 with open(rewards_file,'ab') as f:
#                             np.savetxt(f, [np.array([iteration,  avg_rewards])], fmt=("%d",'%.10f'), delimiter=',') 

#             if iteration % info_freq == 0:
#                 time_end = time.time()
#                 print(". Average reward per game: ",  round(avg_rewards, round_reward), 
#                       ", Elapsed time ", round( (time_end-time_start)/60., round_time), " minutes.") 
                
                
#         ###########################################################################      
                
#         if avg_rewards > best_reward:
#                     saver.save(sess, best_model_file)
#                     print("Saved Model with average discounted rewards per game ", avg_rewards)
#                     best_reward = avg_rewards
#                     checks_without_progress = 0
#         else:
#                     checks_without_progress += 1
#                     if checks_without_progress > max_checks_without_progress:
#                         print("Early stopping!")
#                         break
#         ####################################################################################################
#         if iteration % save_iterations == 0:
#                  saver.save(sess, model_file)
        
#         sess.run(training_op, feed_dict=feed_dict)
    
#     #saver.save(sess, model_file + "final")
#     file_writer.flush()
#     file_writer.close()
                 
#     time_end = time.time()
#     print("Simulation finished. Elapsed time ", round( (time_end-time_start)/60., round_time), " minutes.")
# Out:
# Iteration: 0. Average reward per game:  -2.645645 , Elapsed time  0.01  minutes.
# Saved Model with average discounted rewards per game  -2.6456452887451247
# Iteration: 20Saved Model with average discounted rewards per game  -2.2839853249297866
# Iteration: 40Saved Model with average discounted rewards per game  -1.9983795414958672
# Iteration: 60Saved Model with average discounted rewards per game  -1.8642512330856778
# Iteration: 80Saved Model with average discounted rewards per game  -1.4487982439741374
# Iteration: 100. Average reward per game:  -1.335491 , Elapsed time  0.73  minutes.
# Saved Model with average discounted rewards per game  -1.3354905133546686
# Iteration: 120Saved Model with average discounted rewards per game  -1.1961704761478507
# Iteration: 140Saved Model with average discounted rewards per game  -1.1354027036990064
# Iteration: 160Saved Model with average discounted rewards per game  -1.0507270330712937
# Iteration: 200. Average reward per game:  -1.12283 , Elapsed time  1.56  minutes.
# Iteration: 260Saved Model with average discounted rewards per game  -1.0492127874325878
# Iteration: 280Saved Model with average discounted rewards per game  -1.0347072411411333
# Iteration: 300. Average reward per game:  -1.168957 , Elapsed time  2.27  minutes.
# Iteration: 380Saved Model with average discounted rewards per game  -1.0300071788050063
# Iteration: 400. Average reward per game:  -1.027175 , Elapsed time  2.95  minutes.
# Saved Model with average discounted rewards per game  -1.0271754627556413
# Iteration: 500. Average reward per game:  -1.151787 , Elapsed time  3.75  minutes.
# Iteration: 600. Average reward per game:  -1.20208 , Elapsed time  4.68  minutes.
# Iteration: 700. Average reward per game:  -1.092952 , Elapsed time  5.67  minutes.
# Iteration: 800. Average reward per game:  -1.127427 , Elapsed time  6.71  minutes.
# Iteration: 820Saved Model with average discounted rewards per game  -1.0231829552701113
# Iteration: 900. Average reward per game:  -1.022252 , Elapsed time  7.78  minutes.
# Saved Model with average discounted rewards per game  -1.0222521032368943
# Iteration: 1000. Average reward per game:  -1.049266 , Elapsed time  8.91  minutes.
# Iteration: 1080Saved Model with average discounted rewards per game  -1.01576733728406
# Iteration: 1100. Average reward per game:  -1.108219 , Elapsed time  9.98  minutes.
# Iteration: 1200. Average reward per game:  -1.185002 , Elapsed time  11.1  minutes.
# Iteration: 1300. Average reward per game:  -1.074311 , Elapsed time  12.22  minutes.
# Iteration: 1400. Average reward per game:  -1.148911 , Elapsed time  13.34  minutes.
# Iteration: 1500. Average reward per game:  -1.07467 , Elapsed time  14.46  minutes.
# Iteration: 1600. Average reward per game:  -1.06337 , Elapsed time  15.59  minutes.
# Iteration: 1700. Average reward per game:  -1.098244 , Elapsed time  16.71  minutes.
# Iteration: 1800. Average reward per game:  -1.163101 , Elapsed time  17.83  minutes.
# Iteration: 1900. Average reward per game:  -1.162053 , Elapsed time  18.92  minutes.
# Iteration: 2000. Average reward per game:  -1.209092 , Elapsed time  20.0  minutes.
# Iteration: 2100. Average reward per game:  -1.172155 , Elapsed time  21.07  minutes.
# Iteration: 2200. Average reward per game:  -1.385743 , Elapsed time  22.23  minutes.
# Iteration: 2300. Average reward per game:  -1.15929 , Elapsed time  23.37  minutes.
# Iteration: 2400. Average reward per game:  -1.225898 , Elapsed time  24.5  minutes.
# Iteration: 2500. Average reward per game:  -1.160952 , Elapsed time  25.64  minutes.
# Iteration: 2600. Average reward per game:  -1.170234 , Elapsed time  26.77  minutes.
# Iteration: 2700. Average reward per game:  -1.149415 , Elapsed time  27.9  minutes.
# Iteration: 2800. Average reward per game:  -1.124196 , Elapsed time  29.03  minutes.
# Iteration: 2900. Average reward per game:  -1.232336 , Elapsed time  30.15  minutes.
# Iteration: 3000. Average reward per game:  -1.175007 , Elapsed time  31.28  minutes.
# Iteration: 3100. Average reward per game:  -1.104296 , Elapsed time  32.38  minutes.
# Iteration: 3200. Average reward per game:  -1.207625 , Elapsed time  33.51  minutes.
# Iteration: 3300. Average reward per game:  -1.181685 , Elapsed time  34.63  minutes.
# Iteration: 3400. Average reward per game:  -1.134262 , Elapsed time  35.76  minutes.
# Iteration: 3500. Average reward per game:  -1.143858 , Elapsed time  36.9  minutes.
# Iteration: 3600. Average reward per game:  -1.138696 , Elapsed time  38.02  minutes.
# Iteration: 3700. Average reward per game:  -1.157003 , Elapsed time  39.16  minutes.
# Iteration: 3800. Average reward per game:  -1.19998 , Elapsed time  40.29  minutes.
# Iteration: 3900. Average reward per game:  -1.167391 , Elapsed time  41.43  minutes.
# Iteration: 4000. Average reward per game:  -1.087997 , Elapsed time  42.57  minutes.
# Iteration: 4100. Average reward per game:  -1.159164 , Elapsed time  43.71  minutes.
# Iteration: 4200. Average reward per game:  -1.204967 , Elapsed time  44.85  minutes.
# Iteration: 4300. Average reward per game:  -1.198187 , Elapsed time  46.01  minutes.
# Iteration: 4400. Average reward per game:  -1.234893 , Elapsed time  47.16  minutes.
# Iteration: 4500. Average reward per game:  -1.100406 , Elapsed time  48.31  minutes.
# Iteration: 4600. Average reward per game:  -1.212792 , Elapsed time  49.66  minutes.
# Iteration: 4700. Average reward per game:  -1.224647 , Elapsed time  50.95  minutes.
# Iteration: 4800. Average reward per game:  -1.21059 , Elapsed time  52.28  minutes.
# Iteration: 4900. Average reward per game:  -1.195717 , Elapsed time  53.71  minutes.
# Iteration: 5000. Average reward per game:  -1.229192 , Elapsed time  55.1  minutes.
# Iteration: 5100. Average reward per game:  -1.220792 , Elapsed time  56.45  minutes.
# Iteration: 5200. Average reward per game:  -1.182674 , Elapsed time  57.75  minutes.
# Iteration: 5300. Average reward per game:  -1.118483 , Elapsed time  59.02  minutes.
# Iteration: 5400. Average reward per game:  -1.135721 , Elapsed time  60.33  minutes.
# Iteration: 5500. Average reward per game:  -1.118749 , Elapsed time  61.62  minutes.
# Iteration: 5600. Average reward per game:  -1.15263 , Elapsed time  62.87  minutes.
# Iteration: 5700. Average reward per game:  -1.17543 , Elapsed time  64.13  minutes.
# Iteration: 5800. Average reward per game:  -1.134195 , Elapsed time  65.4  minutes.
# Iteration: 5900. Average reward per game:  -1.162827 , Elapsed time  66.69  minutes.
# Iteration: 6000. Average reward per game:  -1.177443 , Elapsed time  67.99  minutes.
# Iteration: 6100. Average reward per game:  -1.168306 , Elapsed time  69.26  minutes.
# Iteration: 6200. Average reward per game:  -1.279055 , Elapsed time  70.54  minutes.
# Iteration: 6300. Average reward per game:  -1.083613 , Elapsed time  71.81  minutes.
# Iteration: 6400. Average reward per game:  -1.095118 , Elapsed time  72.99  minutes.
# Iteration: 6500. Average reward per game:  -1.162171 , Elapsed time  74.37  minutes.
# Iteration: 6600. Average reward per game:  -1.121839 , Elapsed time  75.68  minutes.
# Iteration: 6700. Average reward per game:  -1.147577 , Elapsed time  76.87  minutes.
# Iteration: 6800. Average reward per game:  -1.264529 , Elapsed time  78.05  minutes.
# Iteration: 6900. Average reward per game:  -1.078328 , Elapsed time  79.23  minutes.
# Iteration: 7000. Average reward per game:  -1.102708 , Elapsed time  80.39  minutes.
# Iteration: 7100. Average reward per game:  -1.151834 , Elapsed time  81.57  minutes.
# Iteration: 7200. Average reward per game:  -1.206214 , Elapsed time  82.74  minutes.
# Iteration: 7300. Average reward per game:  -1.137728 , Elapsed time  83.91  minutes.
# Iteration: 7400. Average reward per game:  -1.203774 , Elapsed time  85.07  minutes.
# Iteration: 7500. Average reward per game:  -1.140718 , Elapsed time  86.27  minutes.
# Iteration: 7600. Average reward per game:  -1.201109 , Elapsed time  87.44  minutes.
# Iteration: 7700. Average reward per game:  -1.121507 , Elapsed time  88.6  minutes.
# Iteration: 7800. Average reward per game:  -1.123863 , Elapsed time  89.86  minutes.
# Iteration: 7900. Average reward per game:  -1.12693 , Elapsed time  91.18  minutes.
# Iteration: 8000. Average reward per game:  -1.179001 , Elapsed time  92.51  minutes.
# Iteration: 8100. Average reward per game:  -1.150698 , Elapsed time  93.93  minutes.
# Iteration: 8200. Average reward per game:  -1.12664 , Elapsed time  95.16  minutes.
# Iteration: 8300. Average reward per game:  -1.121121 , Elapsed time  96.34  minutes.
# Iteration: 8400. Average reward per game:  -1.132725 , Elapsed time  97.5  minutes.
# Iteration: 8500. Average reward per game:  -1.073716 , Elapsed time  98.66  minutes.
# Iteration: 8600. Average reward per game:  -1.126989 , Elapsed time  99.81  minutes.
# Iteration: 8700. Average reward per game:  -1.095932 , Elapsed time  100.97  minutes.
# Iteration: 8800. Average reward per game:  -1.046105 , Elapsed time  102.13  minutes.
# Iteration: 8900. Average reward per game:  -1.075916 , Elapsed time  103.29  minutes.
# Iteration: 9000. Average reward per game:  -1.086612 , Elapsed time  104.44  minutes.
# Iteration: 9100. Average reward per game:  -1.044234 , Elapsed time  105.59  minutes.
# Iteration: 9200. Average reward per game:  -1.098751 , Elapsed time  106.75  minutes.
# Iteration: 9300. Average reward per game:  -1.032489 , Elapsed time  107.9  minutes.
# Iteration: 9400. Average reward per game:  -1.111052 , Elapsed time  109.05  minutes.
# Iteration: 9500. Average reward per game:  -1.063065 , Elapsed time  110.19  minutes.
# Iteration: 9600. Average reward per game:  -1.033645 , Elapsed time  111.34  minutes.
# Iteration: 9700. Average reward per game:  -1.105651 , Elapsed time  112.5  minutes.
# Iteration: 9800. Average reward per game:  -1.099114 , Elapsed time  113.66  minutes.
# Iteration: 9900. Average reward per game:  -1.014777 , Elapsed time  114.81  minutes.
# Saved Model with average discounted rewards per game  -1.014776829594525
# Iteration: 9960Saved Model with average discounted rewards per game  -1.0130774714033994
# Iteration: 10000. Average reward per game:  -1.015745 , Elapsed time  115.97  minutes.
# Iteration: 10100. Average reward per game:  -1.10771 , Elapsed time  117.12  minutes.
# Iteration: 10200. Average reward per game:  -1.076987 , Elapsed time  118.28  minutes.
# Iteration: 10300. Average reward per game:  -1.104091 , Elapsed time  119.5  minutes.
# Iteration: 10400. Average reward per game:  -1.049698 , Elapsed time  120.65  minutes.
# Iteration: 10500. Average reward per game:  -1.051446 , Elapsed time  121.81  minutes.
# Iteration: 10600. Average reward per game:  -1.046483 , Elapsed time  122.95  minutes.
# Iteration: 10680Saved Model with average discounted rewards per game  -1.0059878782988847
# Iteration: 10700. Average reward per game:  -1.030782 , Elapsed time  124.11  minutes.
# Iteration: 10800. Average reward per game:  -1.112563 , Elapsed time  125.25  minutes.
# Iteration: 10900. Average reward per game:  -1.11613 , Elapsed time  126.42  minutes.
# Iteration: 11000. Average reward per game:  -1.140813 , Elapsed time  127.58  minutes.
# Iteration: 11100. Average reward per game:  -1.104561 , Elapsed time  128.74  minutes.
# Iteration: 11200. Average reward per game:  -1.102349 , Elapsed time  129.89  minutes.
# Iteration: 11300. Average reward per game:  -1.078957 , Elapsed time  131.06  minutes.
# Iteration: 11400. Average reward per game:  -1.088033 , Elapsed time  132.23  minutes.
# Iteration: 11500. Average reward per game:  -1.018505 , Elapsed time  133.39  minutes.
# Iteration: 11600. Average reward per game:  -1.144093 , Elapsed time  134.55  minutes.
# Iteration: 11700. Average reward per game:  -1.028387 , Elapsed time  135.71  minutes.
# Iteration: 11800. Average reward per game:  -1.042542 , Elapsed time  136.87  minutes.
# Iteration: 11860Saved Model with average discounted rewards per game  -0.9639651473492432
# Iteration: 11900. Average reward per game:  -1.051169 , Elapsed time  138.03  minutes.
# Iteration: 12000. Average reward per game:  -1.048242 , Elapsed time  139.18  minutes.
# Iteration: 12100. Average reward per game:  -0.988914 , Elapsed time  140.35  minutes.
# Iteration: 12200. Average reward per game:  -1.026283 , Elapsed time  141.51  minutes.
# Iteration: 12300. Average reward per game:  -1.052 , Elapsed time  142.68  minutes.
# Iteration: 12400. Average reward per game:  -1.100815 , Elapsed time  143.85  minutes.
# Iteration: 12500. Average reward per game:  -1.081412 , Elapsed time  145.0  minutes.
# Iteration: 12600. Average reward per game:  -1.030651 , Elapsed time  146.16  minutes.
# Iteration: 12700. Average reward per game:  -1.026328 , Elapsed time  147.33  minutes.
# Iteration: 12800. Average reward per game:  -1.072274 , Elapsed time  148.57  minutes.
# Iteration: 12900. Average reward per game:  -1.036322 , Elapsed time  149.75  minutes.
# Iteration: 13000. Average reward per game:  -1.0217 , Elapsed time  150.92  minutes.
# Iteration: 13100. Average reward per game:  -1.108755 , Elapsed time  152.08  minutes.
# Iteration: 13200. Average reward per game:  -0.988632 , Elapsed time  153.26  minutes.
# Iteration: 13300. Average reward per game:  -0.969707 , Elapsed time  154.44  minutes.
# Iteration: 13400. Average reward per game:  -1.029303 , Elapsed time  155.61  minutes.
# Iteration: 13500. Average reward per game:  -1.104729 , Elapsed time  156.8  minutes.
# Iteration: 13600. Average reward per game:  -1.033095 , Elapsed time  157.99  minutes.
# Iteration: 13700. Average reward per game:  -1.041609 , Elapsed time  159.16  minutes.
# Iteration: 13800. Average reward per game:  -0.995216 , Elapsed time  160.34  minutes.
# Iteration: 13900. Average reward per game:  -1.08246 , Elapsed time  161.51  minutes.
# Iteration: 14000. Average reward per game:  -0.984342 , Elapsed time  162.68  minutes.
# Iteration: 14100. Average reward per game:  -1.058948 , Elapsed time  163.86  minutes.
# Iteration: 14200. Average reward per game:  -1.169494 , Elapsed time  165.04  minutes.
# Iteration: 14300. Average reward per game:  -1.041039 , Elapsed time  166.22  minutes.
# Iteration: 14400. Average reward per game:  -1.085197 , Elapsed time  167.4  minutes.
# Iteration: 14500. Average reward per game:  -1.058741 , Elapsed time  168.57  minutes.
# Iteration: 14600. Average reward per game:  -1.000714 , Elapsed time  169.75  minutes.
# Iteration: 14700. Average reward per game:  -1.000416 , Elapsed time  170.94  minutes.
# Iteration: 14800. Average reward per game:  -1.135502 , Elapsed time  172.1  minutes.
# Iteration: 14860Saved Model with average discounted rewards per game  -0.9520528891275921
# Iteration: 14900. Average reward per game:  -1.059779 , Elapsed time  173.31  minutes.
# Iteration: 15000. Average reward per game:  -1.048837 , Elapsed time  174.49  minutes.
# Iteration: 15100. Average reward per game:  -1.048134 , Elapsed time  175.67  minutes.
# Iteration: 15200. Average reward per game:  -1.0279 , Elapsed time  176.85  minutes.
# Iteration: 15300. Average reward per game:  -0.998296 , Elapsed time  178.02  minutes.
# Iteration: 15400. Average reward per game:  -1.0689 , Elapsed time  179.21  minutes.
# Iteration: 15500. Average reward per game:  -1.018266 , Elapsed time  180.38  minutes.
# Iteration: 15600. Average reward per game:  -1.117974 , Elapsed time  181.57  minutes.
# Iteration: 15700. Average reward per game:  -1.088897 , Elapsed time  182.73  minutes.
# Iteration: 15800. Average reward per game:  -1.019311 , Elapsed time  183.91  minutes.
# Iteration: 15900. Average reward per game:  -1.064233 , Elapsed time  185.09  minutes.
# Iteration: 16000. Average reward per game:  -1.059854 , Elapsed time  186.24  minutes.
# Iteration: 16100. Average reward per game:  -1.035296 , Elapsed time  187.42  minutes.
# Iteration: 16200. Average reward per game:  -1.124002 , Elapsed time  188.61  minutes.
# Iteration: 16300. Average reward per game:  -1.059332 , Elapsed time  189.78  minutes.
# Iteration: 16400. Average reward per game:  -1.051753 , Elapsed time  190.96  minutes.
# Iteration: 16500. Average reward per game:  -1.107529 , Elapsed time  192.13  minutes.
# Iteration: 16600. Average reward per game:  -1.019133 , Elapsed time  193.33  minutes.
# Iteration: 16700. Average reward per game:  -1.021451 , Elapsed time  194.5  minutes.
# Iteration: 16800. Average reward per game:  -1.049232 , Elapsed time  195.68  minutes.
# Iteration: 16860Saved Model with average discounted rewards per game  -0.9383727121913662
# Iteration: 16900. Average reward per game:  -1.028313 , Elapsed time  196.85  minutes.
# Iteration: 17000. Average reward per game:  -0.955726 , Elapsed time  198.02  minutes.
# Iteration: 17040Saved Model with average discounted rewards per game  -0.9285582319964847
# Iteration: 17060Saved Model with average discounted rewards per game  -0.8268825811416042
# Iteration: 17100. Average reward per game:  -0.957838 , Elapsed time  199.21  minutes.
# Iteration: 17200. Average reward per game:  -0.98093 , Elapsed time  200.4  minutes.
# Iteration: 17300. Average reward per game:  -0.889325 , Elapsed time  201.58  minutes.
# Iteration: 17400. Average reward per game:  -0.969036 , Elapsed time  202.76  minutes.
# Iteration: 17500. Average reward per game:  -0.994951 , Elapsed time  203.95  minutes.
# Iteration: 17600. Average reward per game:  -0.946169 , Elapsed time  205.14  minutes.
# Iteration: 17700. Average reward per game:  -0.948656 , Elapsed time  206.32  minutes.
# Iteration: 17800. Average reward per game:  -0.915485 , Elapsed time  207.51  minutes.
# Iteration: 17900. Average reward per game:  -0.920633 , Elapsed time  208.7  minutes.
# Iteration: 18000. Average reward per game:  -0.923215 , Elapsed time  209.87  minutes.
# Iteration: 18100. Average reward per game:  -0.996 , Elapsed time  211.05  minutes.
# Iteration: 18200. Average reward per game:  -0.958397 , Elapsed time  212.23  minutes.
# Iteration: 18300. Average reward per game:  -0.930081 , Elapsed time  213.42  minutes.
# Iteration: 18400. Average reward per game:  -0.942445 , Elapsed time  214.58  minutes.
# Iteration: 18500. Average reward per game:  -0.954963 , Elapsed time  215.75  minutes.
# Iteration: 18600. Average reward per game:  -0.951819 , Elapsed time  217.01  minutes.
# Iteration: 18700. Average reward per game:  -0.944614 , Elapsed time  218.4  minutes.
# Iteration: 18800. Average reward per game:  -0.926193 , Elapsed time  219.76  minutes.
# Iteration: 18900. Average reward per game:  -0.958973 , Elapsed time  220.93  minutes.
# Iteration: 19000. Average reward per game:  -0.88031 , Elapsed time  222.09  minutes.
# Iteration: 19100. Average reward per game:  -0.940182 , Elapsed time  223.24  minutes.
# Iteration: 19200. Average reward per game:  -0.963297 , Elapsed time  224.4  minutes.
# Iteration: 19300. Average reward per game:  -0.957274 , Elapsed time  225.53  minutes.
# Iteration: 19400. Average reward per game:  -0.906239 , Elapsed time  226.68  minutes.
# Iteration: 19500. Average reward per game:  -0.926535 , Elapsed time  227.84  minutes.
# Iteration: 19580Saved Model with average discounted rewards per game  -0.806895060452548
# Iteration: 19600. Average reward per game:  -0.871503 , Elapsed time  229.0  minutes.
# Iteration: 19700. Average reward per game:  -0.989949 , Elapsed time  230.15  minutes.
# Iteration: 19800. Average reward per game:  -0.93195 , Elapsed time  231.29  minutes.
# Iteration: 19900. Average reward per game:  -0.890469 , Elapsed time  232.45  minutes.
# Iteration: 20000. Average reward per game:  -0.872538 , Elapsed time  233.73  minutes.
# Iteration: 20100. Average reward per game:  -0.888862 , Elapsed time  234.89  minutes.
# Iteration: 20200. Average reward per game:  -0.928325 , Elapsed time  236.11  minutes.
# Iteration: 20300. Average reward per game:  -0.971766 , Elapsed time  237.47  minutes.
# Iteration: 20400. Average reward per game:  -0.931939 , Elapsed time  238.81  minutes.
# Iteration: 20500. Average reward per game:  -0.937109 , Elapsed time  240.18  minutes.
# Iteration: 20600. Average reward per game:  -0.934177 , Elapsed time  241.52  minutes.
# Iteration: 20700. Average reward per game:  -0.93727 , Elapsed time  242.82  minutes.
# Iteration: 20800. Average reward per game:  -0.926889 , Elapsed time  244.0  minutes.
# Iteration: 20900. Average reward per game:  -0.919357 , Elapsed time  245.34  minutes.
# Iteration: 21000. Average reward per game:  -0.866425 , Elapsed time  246.52  minutes.
# Iteration: 21100. Average reward per game:  -0.950897 , Elapsed time  247.84  minutes.
# Iteration: 21200. Average reward per game:  -0.916527 , Elapsed time  249.2  minutes.
# Iteration: 21300. Average reward per game:  -1.014348 , Elapsed time  250.51  minutes.
# Iteration: 21400. Average reward per game:  -0.913087 , Elapsed time  251.67  minutes.
# Iteration: 21500. Average reward per game:  -0.960632 , Elapsed time  252.99  minutes.
# Iteration: 21600. Average reward per game:  -0.86965 , Elapsed time  254.36  minutes.
# Iteration: 21700. Average reward per game:  -0.948088 , Elapsed time  255.73  minutes.
# Iteration: 21800. Average reward per game:  -0.972132 , Elapsed time  257.04  minutes.
# Iteration: 21900. Average reward per game:  -0.929497 , Elapsed time  258.2  minutes.
# Iteration: 22000. Average reward per game:  -0.964884 , Elapsed time  259.56  minutes.
# Iteration: 22100. Average reward per game:  -0.909319 , Elapsed time  260.87  minutes.
# Iteration: 22200. Average reward per game:  -0.894979 , Elapsed time  262.26  minutes.
# Iteration: 22300. Average reward per game:  -0.922951 , Elapsed time  263.63  minutes.
# Iteration: 22400. Average reward per game:  -0.956159 , Elapsed time  264.89  minutes.
# Iteration: 22500. Average reward per game:  -0.968128 , Elapsed time  266.06  minutes.
# Iteration: 22600. Average reward per game:  -0.989847 , Elapsed time  267.22  minutes.
# Iteration: 22700. Average reward per game:  -0.90133 , Elapsed time  268.38  minutes.
# Iteration: 22800. Average reward per game:  -0.872359 , Elapsed time  269.55  minutes.
# Iteration: 22900. Average reward per game:  -0.962464 , Elapsed time  270.71  minutes.
# Iteration: 23000. Average reward per game:  -0.998371 , Elapsed time  271.87  minutes.
# Iteration: 23100. Average reward per game:  -0.961794 , Elapsed time  273.04  minutes.
# Iteration: 23200. Average reward per game:  -1.009266 , Elapsed time  274.18  minutes.
# Iteration: 23300. Average reward per game:  -0.958674 , Elapsed time  275.35  minutes.
# Iteration: 23400. Average reward per game:  -0.889201 , Elapsed time  276.53  minutes.
# Iteration: 23500. Average reward per game:  -0.886083 , Elapsed time  277.71  minutes.
# Iteration: 23600. Average reward per game:  -0.925937 , Elapsed time  278.88  minutes.
# Iteration: 23700. Average reward per game:  -0.996065 , Elapsed time  280.05  minutes.
# Iteration: 23800. Average reward per game:  -0.945617 , Elapsed time  281.22  minutes.
# Iteration: 23900. Average reward per game:  -0.973925 , Elapsed time  282.4  minutes.
# Iteration: 24000. Average reward per game:  -0.864878 , Elapsed time  283.57  minutes.
# Iteration: 24100. Average reward per game:  -0.872866 , Elapsed time  284.74  minutes.
# Iteration: 24200. Average reward per game:  -0.963851 , Elapsed time  285.9  minutes.
# Iteration: 24300. Average reward per game:  -0.906777 , Elapsed time  287.06  minutes.
# Iteration: 24400. Average reward per game:  -0.863798 , Elapsed time  288.23  minutes.
# Iteration: 24500. Average reward per game:  -0.82893 , Elapsed time  289.39  minutes.
# Iteration: 24600. Average reward per game:  -0.931136 , Elapsed time  290.55  minutes.
# Iteration: 24700. Average reward per game:  -0.977526 , Elapsed time  291.72  minutes.
# Iteration: 24800. Average reward per game:  -0.908082 , Elapsed time  292.89  minutes.
# Iteration: 24900. Average reward per game:  -0.857416 , Elapsed time  294.05  minutes.
# Iteration: 25000. Average reward per game:  -0.893236 , Elapsed time  295.22  minutes.
# Iteration: 25100. Average reward per game:  -0.907152 , Elapsed time  296.39  minutes.
# Iteration: 25200. Average reward per game:  -1.020738 , Elapsed time  297.56  minutes.
# Iteration: 25300. Average reward per game:  -0.942311 , Elapsed time  298.72  minutes.
# Iteration: 25400. Average reward per game:  -0.966134 , Elapsed time  299.88  minutes.
# Iteration: 25500. Average reward per game:  -1.002391 , Elapsed time  301.06  minutes.
# Iteration: 25600. Average reward per game:  -0.916423 , Elapsed time  302.22  minutes.
# Iteration: 25700. Average reward per game:  -0.90491 , Elapsed time  303.38  minutes.
# Iteration: 25800. Average reward per game:  -0.963549 , Elapsed time  304.54  minutes.
# Iteration: 25900. Average reward per game:  -0.961974 , Elapsed time  305.69  minutes.
# Iteration: 26000. Average reward per game:  -0.963802 , Elapsed time  306.88  minutes.
# Iteration: 26100. Average reward per game:  -0.987863 , Elapsed time  308.03  minutes.
# Iteration: 26200. Average reward per game:  -0.88167 , Elapsed time  309.19  minutes.
# Iteration: 26300. Average reward per game:  -1.04281 , Elapsed time  310.36  minutes.
# Iteration: 26400. Average reward per game:  -0.975703 , Elapsed time  311.52  minutes.
# Iteration: 26500. Average reward per game:  -0.940368 , Elapsed time  312.69  minutes.
# Iteration: 26600. Average reward per game:  -0.997436 , Elapsed time  313.86  minutes.
# Iteration: 26700. Average reward per game:  -0.892697 , Elapsed time  315.03  minutes.
# Iteration: 26800. Average reward per game:  -0.986316 , Elapsed time  316.2  minutes.
# Iteration: 26900. Average reward per game:  -0.906071 , Elapsed time  317.37  minutes.
# Iteration: 27000. Average reward per game:  -0.925247 , Elapsed time  318.54  minutes.
# Iteration: 27100. Average reward per game:  -0.939835 , Elapsed time  319.72  minutes.
# Iteration: 27200. Average reward per game:  -0.838838 , Elapsed time  320.89  minutes.
# Iteration: 27300. Average reward per game:  -0.934579 , Elapsed time  322.06  minutes.
# Iteration: 27400. Average reward per game:  -0.911402 , Elapsed time  323.23  minutes.
# Iteration: 27500. Average reward per game:  -0.880787 , Elapsed time  324.41  minutes.
# Iteration: 27600. Average reward per game:  -0.874009 , Elapsed time  325.53  minutes.
# Iteration: 27700. Average reward per game:  -0.938724 , Elapsed time  326.68  minutes.
# Iteration: 27800. Average reward per game:  -0.92213 , Elapsed time  327.85  minutes.
# Iteration: 27900. Average reward per game:  -0.884331 , Elapsed time  329.01  minutes.
# Iteration: 28000. Average reward per game:  -0.960916 , Elapsed time  330.18  minutes.
# Iteration: 28100. Average reward per game:  -0.936248 , Elapsed time  331.36  minutes.
# Iteration: 28200. Average reward per game:  -0.89779 , Elapsed time  332.52  minutes.
# Iteration: 28300. Average reward per game:  -1.038429 , Elapsed time  333.66  minutes.
# Iteration: 28400. Average reward per game:  -0.94976 , Elapsed time  334.83  minutes.
# Iteration: 28500. Average reward per game:  -0.939384 , Elapsed time  335.99  minutes.
# Iteration: 28600. Average reward per game:  -0.876989 , Elapsed time  337.18  minutes.
# Iteration: 28700. Average reward per game:  -0.885191 , Elapsed time  338.35  minutes.
# Iteration: 28800. Average reward per game:  -0.877973 , Elapsed time  339.51  minutes.
# Iteration: 28900. Average reward per game:  -1.031889 , Elapsed time  340.67  minutes.
# Iteration: 29000. Average reward per game:  -0.936068 , Elapsed time  341.85  minutes.
# Iteration: 29100. Average reward per game:  -0.940123 , Elapsed time  343.02  minutes.
# Iteration: 29200. Average reward per game:  -0.979216 , Elapsed time  344.18  minutes.
# Iteration: 29300. Average reward per game:  -0.970146 , Elapsed time  345.35  minutes.
# Iteration: 29400. Average reward per game:  -0.898457 , Elapsed time  346.53  minutes.
# Iteration: 29500. Average reward per game:  -0.921314 , Elapsed time  347.69  minutes.
# Iteration: 29600. Average reward per game:  -0.918135 , Elapsed time  348.86  minutes.
# Iteration: 29700. Average reward per game:  -0.904271 , Elapsed time  350.04  minutes.
# Iteration: 29800. Average reward per game:  -1.033937 , Elapsed time  351.2  minutes.
# Iteration: 29900. Average reward per game:  -0.923727 , Elapsed time  352.35  minutes.
# Iteration: 30000. Average reward per game:  -1.062831 , Elapsed time  353.5  minutes.
# Iteration: 30100. Average reward per game:  -0.913943 , Elapsed time  354.66  minutes.
# Iteration: 30200. Average reward per game:  -0.864915 , Elapsed time  355.83  minutes.
# Iteration: 30300. Average reward per game:  -0.85754 , Elapsed time  357.0  minutes.
# Iteration: 30400. Average reward per game:  -0.906824 , Elapsed time  358.15  minutes.
# Iteration: 30500. Average reward per game:  -0.905532 , Elapsed time  359.32  minutes.
# Iteration: 30600. Average reward per game:  -0.901699 , Elapsed time  360.49  minutes.
# Iteration: 30700. Average reward per game:  -0.912749 , Elapsed time  361.64  minutes.
# Iteration: 30800. Average reward per game:  -0.880626 , Elapsed time  362.81  minutes.
# Iteration: 30900. Average reward per game:  -0.873393 , Elapsed time  363.97  minutes.
# Iteration: 31000. Average reward per game:  -0.933263 , Elapsed time  365.14  minutes.
# Iteration: 31100. Average reward per game:  -0.876633 , Elapsed time  366.31  minutes.
# Iteration: 31200. Average reward per game:  -0.997625 , Elapsed time  367.49  minutes.
# Iteration: 31300. Average reward per game:  -0.950421 , Elapsed time  368.67  minutes.
# Iteration: 31400. Average reward per game:  -1.053637 , Elapsed time  369.81  minutes.
# Iteration: 31500. Average reward per game:  -0.963666 , Elapsed time  370.99  minutes.
# Iteration: 31600. Average reward per game:  -0.958666 , Elapsed time  372.15  minutes.
# Iteration: 31700. Average reward per game:  -0.922792 , Elapsed time  373.33  minutes.
# Iteration: 31800. Average reward per game:  -0.880504 , Elapsed time  374.49  minutes.
# Iteration: 31900. Average reward per game:  -0.860261 , Elapsed time  375.66  minutes.
# Iteration: 32000. Average reward per game:  -0.953211 , Elapsed time  376.83  minutes.
# Iteration: 32100. Average reward per game:  -0.871903 , Elapsed time  378.01  minutes.
# Iteration: 32200. Average reward per game:  -0.937255 , Elapsed time  379.18  minutes.
# Iteration: 32300. Average reward per game:  -0.956515 , Elapsed time  380.35  minutes.
# Iteration: 32400. Average reward per game:  -0.950181 , Elapsed time  381.52  minutes.
# Iteration: 32500. Average reward per game:  -0.967592 , Elapsed time  382.71  minutes.
# Iteration: 32600. Average reward per game:  -0.95925 , Elapsed time  383.89  minutes.
# Iteration: 32700. Average reward per game:  -0.95612 , Elapsed time  385.06  minutes.
# Iteration: 32800. Average reward per game:  -0.932441 , Elapsed time  386.26  minutes.
# Iteration: 32900. Average reward per game:  -0.971132 , Elapsed time  387.39  minutes.
# Iteration: 33000. Average reward per game:  -0.976087 , Elapsed time  388.56  minutes.
# Iteration: 33100. Average reward per game:  -0.86864 , Elapsed time  389.74  minutes.
# Iteration: 33200. Average reward per game:  -0.940212 , Elapsed time  390.91  minutes.
# Iteration: 33300. Average reward per game:  -1.014295 , Elapsed time  392.07  minutes.
# Iteration: 33400. Average reward per game:  -0.990857 , Elapsed time  393.24  minutes.
# Iteration: 33500. Average reward per game:  -0.99062 , Elapsed time  394.41  minutes.
# Iteration: 33600. Average reward per game:  -0.948223 , Elapsed time  395.57  minutes.
# Iteration: 33700. Average reward per game:  -0.943162 , Elapsed time  396.76  minutes.
# Iteration: 33800. Average reward per game:  -0.910296 , Elapsed time  397.97  minutes.
# Iteration: 33900. Average reward per game:  -0.932227 , Elapsed time  399.29  minutes.
# Iteration: 34000. Average reward per game:  -0.967313 , Elapsed time  400.5  minutes.
# Iteration: 34100. Average reward per game:  -0.894864 , Elapsed time  401.72  minutes.
# Iteration: 34200. Average reward per game:  -0.997014 , Elapsed time  403.14  minutes.
# Iteration: 34300. Average reward per game:  -0.918961 , Elapsed time  404.49  minutes.
# Iteration: 34400. Average reward per game:  -0.955857 , Elapsed time  405.87  minutes.
# Iteration: 34500. Average reward per game:  -0.945682 , Elapsed time  407.19  minutes.
# Iteration: 34600. Average reward per game:  -1.000027 , Elapsed time  408.52  minutes.
# Iteration: 34700. Average reward per game:  -0.997998 , Elapsed time  409.9  minutes.
# Iteration: 34800. Average reward per game:  -0.9626 , Elapsed time  411.21  minutes.
# Iteration: 34900. Average reward per game:  -0.877 , Elapsed time  412.47  minutes.
# Iteration: 35000. Average reward per game:  -0.893897 , Elapsed time  413.71  minutes.
# Iteration: 35100. Average reward per game:  -0.972972 , Elapsed time  414.97  minutes.
# Iteration: 35200. Average reward per game:  -0.961169 , Elapsed time  416.21  minutes.
# Iteration: 35300. Average reward per game:  -1.035889 , Elapsed time  417.47  minutes.
# Iteration: 35400. Average reward per game:  -0.925815 , Elapsed time  418.89  minutes.
# Iteration: 35500. Average reward per game:  -0.911991 , Elapsed time  420.23  minutes.
# Iteration: 35600. Average reward per game:  -1.021972 , Elapsed time  421.61  minutes.
# Iteration: 35700. Average reward per game:  -0.914953 , Elapsed time  422.97  minutes.
# Iteration: 35800. Average reward per game:  -0.935615 , Elapsed time  424.33  minutes.
# Iteration: 35900. Average reward per game:  -0.943668 , Elapsed time  425.73  minutes.
# Iteration: 36000. Average reward per game:  -0.972388 , Elapsed time  427.09  minutes.
# Iteration: 36100. Average reward per game:  -0.896812 , Elapsed time  428.49  minutes.
# Iteration: 36200. Average reward per game:  -0.973309 , Elapsed time  429.86  minutes.
# Iteration: 36300. Average reward per game:  -0.989139 , Elapsed time  431.21  minutes.
# Iteration: 36400. Average reward per game:  -0.929079 , Elapsed time  432.54  minutes.
# Iteration: 36500. Average reward per game:  -0.939568 , Elapsed time  433.81  minutes.
# Iteration: 36600. Average reward per game:  -0.962668 , Elapsed time  435.19  minutes.
# Iteration: 36700. Average reward per game:  -0.952215 , Elapsed time  436.5  minutes.
# Iteration: 36800. Average reward per game:  -0.87366 , Elapsed time  437.89  minutes.
# Iteration: 36900. Average reward per game:  -0.927675 , Elapsed time  439.23  minutes.
# Iteration: 37000. Average reward per game:  -0.95943 , Elapsed time  440.47  minutes.
# Iteration: 37100. Average reward per game:  -0.929773 , Elapsed time  441.71  minutes.
# Iteration: 37200. Average reward per game:  -0.94543 , Elapsed time  442.95  minutes.
# Iteration: 37300. Average reward per game:  -0.964951 , Elapsed time  444.19  minutes.
# Iteration: 37400. Average reward per game:  -0.970485 , Elapsed time  445.43  minutes.
# Iteration: 37500. Average reward per game:  -0.913646 , Elapsed time  446.68  minutes.
# Iteration: 37600. Average reward per game:  -0.901636 , Elapsed time  447.91  minutes.
# Iteration: 37700. Average reward per game:  -0.995733 , Elapsed time  449.16  minutes.
# Iteration: 37800. Average reward per game:  -0.863147 , Elapsed time  450.39  minutes.
# Iteration: 37900. Average reward per game:  -0.887091 , Elapsed time  451.61  minutes.
# Iteration: 38000. Average reward per game:  -1.103325 , Elapsed time  452.84  minutes.
# Iteration: 38100. Average reward per game:  -0.903256 , Elapsed time  454.06  minutes.
# Iteration: 38200. Average reward per game:  -0.883038 , Elapsed time  455.28  minutes.
# Iteration: 38300. Average reward per game:  -0.910501 , Elapsed time  456.52  minutes.
# Iteration: 38400. Average reward per game:  -0.903506 , Elapsed time  457.75  minutes.
# Iteration: 38500. Average reward per game:  -0.894111 , Elapsed time  458.99  minutes.
# Iteration: 38600. Average reward per game:  -0.891759 , Elapsed time  460.22  minutes.
# Iteration: 38700. Average reward per game:  -0.853361 , Elapsed time  461.45  minutes.
# Iteration: 38800. Average reward per game:  -0.955319 , Elapsed time  462.68  minutes.
# Iteration: 38900. Average reward per game:  -0.995675 , Elapsed time  463.91  minutes.
# Iteration: 39000. Average reward per game:  -0.912141 , Elapsed time  465.15  minutes.
# Iteration: 39100. Average reward per game:  -0.918543 , Elapsed time  466.36  minutes.
# Iteration: 39200. Average reward per game:  -0.91435 , Elapsed time  467.59  minutes.
# Iteration: 39300. Average reward per game:  -0.921928 , Elapsed time  468.81  minutes.
# Iteration: 39400. Average reward per game:  -0.898132 , Elapsed time  470.05  minutes.
# Iteration: 39500. Average reward per game:  -0.956504 , Elapsed time  471.28  minutes.
# Iteration: 39600. Average reward per game:  -0.977498 , Elapsed time  472.51  minutes.
# Iteration: 39700. Average reward per game:  -0.946328 , Elapsed time  473.72  minutes.
# Iteration: 39800. Average reward per game:  -0.952728 , Elapsed time  474.96  minutes.
# Iteration: 39900. Average reward per game:  -1.002641 , Elapsed time  476.18  minutes.
# Iteration: 40000. Average reward per game:  -1.01619 , Elapsed time  477.41  minutes.
# Iteration: 40100. Average reward per game:  -0.957319 , Elapsed time  478.64  minutes.
# Iteration: 40200. Average reward per game:  -1.081419 , Elapsed time  479.88  minutes.
# Iteration: 40300. Average reward per game:  -1.071161 , Elapsed time  481.1  minutes.
# Iteration: 40400. Average reward per game:  -0.965757 , Elapsed time  482.32  minutes.
# Iteration: 40500. Average reward per game:  -0.957112 , Elapsed time  483.55  minutes.
# Iteration: 40600. Average reward per game:  -0.986557 , Elapsed time  484.78  minutes.
# Iteration: 40700. Average reward per game:  -0.84823 , Elapsed time  486.0  minutes.
# Iteration: 40800. Average reward per game:  -0.939329 , Elapsed time  487.24  minutes.
# Iteration: 40900. Average reward per game:  -0.877489 , Elapsed time  488.47  minutes.
# Iteration: 41000. Average reward per game:  -0.952814 , Elapsed time  489.72  minutes.
# Iteration: 41100. Average reward per game:  -0.972858 , Elapsed time  490.95  minutes.
# Iteration: 41200. Average reward per game:  -0.943 , Elapsed time  492.18  minutes.
# Iteration: 41300. Average reward per game:  -0.91031 , Elapsed time  493.41  minutes.
# Iteration: 41400. Average reward per game:  -0.897875 , Elapsed time  494.62  minutes.
# Iteration: 41500. Average reward per game:  -0.965121 , Elapsed time  495.87  minutes.
# Iteration: 41600. Average reward per game:  -0.981419 , Elapsed time  497.1  minutes.
# Iteration: 41700. Average reward per game:  -0.918481 , Elapsed time  498.33  minutes.
# Iteration: 41800. Average reward per game:  -0.963401 , Elapsed time  499.55  minutes.
# Iteration: 41900. Average reward per game:  -0.91723 , Elapsed time  500.79  minutes.
# Iteration: 42000. Average reward per game:  -0.952281 , Elapsed time  502.03  minutes.
# Iteration: 42100. Average reward per game:  -0.948589 , Elapsed time  503.26  minutes.
# Iteration: 42200. Average reward per game:  -0.903059 , Elapsed time  504.5  minutes.
# Iteration: 42300. Average reward per game:  -0.965669 , Elapsed time  505.73  minutes.
# Iteration: 42400. Average reward per game:  -0.859098 , Elapsed time  506.96  minutes.
# Iteration: 42500. Average reward per game:  -0.851238 , Elapsed time  508.19  minutes.
# Iteration: 42600. Average reward per game:  -0.876063 , Elapsed time  509.41  minutes.
# Iteration: 42700. Average reward per game:  -0.931046 , Elapsed time  510.64  minutes.
# Iteration: 42800. Average reward per game:  -0.938606 , Elapsed time  511.88  minutes.
# Iteration: 42900. Average reward per game:  -0.892975 , Elapsed time  513.1  minutes.
# Iteration: 43000. Average reward per game:  -0.91667 , Elapsed time  514.33  minutes.
# Iteration: 43100. Average reward per game:  -0.963396 , Elapsed time  515.54  minutes.
# Iteration: 43200. Average reward per game:  -1.01444 , Elapsed time  516.78  minutes.
# Iteration: 43300. Average reward per game:  -0.917816 , Elapsed time  518.03  minutes.
# Iteration: 43400. Average reward per game:  -0.874408 , Elapsed time  519.29  minutes.
# Iteration: 43500. Average reward per game:  -0.926953 , Elapsed time  520.63  minutes.
# Iteration: 43600. Average reward per game:  -0.916326 , Elapsed time  521.98  minutes.
# Iteration: 43700. Average reward per game:  -0.925885 , Elapsed time  523.37  minutes.
# Iteration: 43800. Average reward per game:  -0.984105 , Elapsed time  524.66  minutes.
# Iteration: 43900. Average reward per game:  -0.879737 , Elapsed time  525.92  minutes.
# Iteration: 44000. Average reward per game:  -0.95446 , Elapsed time  527.15  minutes.
# Iteration: 44100. Average reward per game:  -0.845575 , Elapsed time  528.39  minutes.
# Iteration: 44200. Average reward per game:  -0.903226 , Elapsed time  529.62  minutes.
# Iteration: 44300. Average reward per game:  -0.943579 , Elapsed time  530.86  minutes.
# Iteration: 44400. Average reward per game:  -0.880681 , Elapsed time  532.08  minutes.
# Iteration: 44500. Average reward per game:  -0.984303 , Elapsed time  533.32  minutes.
# Iteration: 44600. Average reward per game:  -0.93261 , Elapsed time  534.58  minutes.
# Iteration: 44700. Average reward per game:  -0.903765 , Elapsed time  535.8  minutes.
# Iteration: 44800. Average reward per game:  -0.976966 , Elapsed time  537.04  minutes.
# Iteration: 44900. Average reward per game:  -0.840239 , Elapsed time  538.27  minutes.
# Iteration: 45000. Average reward per game:  -0.950833 , Elapsed time  539.5  minutes.
# Iteration: 45100. Average reward per game:  -1.003106 , Elapsed time  540.75  minutes.
# Iteration: 45200. Average reward per game:  -0.905508 , Elapsed time  541.99  minutes.
# Iteration: 45300. Average reward per game:  -0.940893 , Elapsed time  543.29  minutes.
# Iteration: 45400. Average reward per game:  -0.933203 , Elapsed time  544.67  minutes.
# Iteration: 45500. Average reward per game:  -0.909049 , Elapsed time  546.08  minutes.
# Iteration: 45600. Average reward per game:  -0.903239 , Elapsed time  547.32  minutes.
# Iteration: 45700. Average reward per game:  -0.931734 , Elapsed time  548.56  minutes.
# Iteration: 45800. Average reward per game:  -0.886495 , Elapsed time  549.8  minutes.
# Iteration: 45900. Average reward per game:  -0.939493 , Elapsed time  551.04  minutes.
# Iteration: 46000. Average reward per game:  -0.929713 , Elapsed time  552.3  minutes.
# Iteration: 46100. Average reward per game:  -0.974072 , Elapsed time  553.55  minutes.
# Iteration: 46200. Average reward per game:  -0.900943 , Elapsed time  554.79  minutes.
# Iteration: 46300. Average reward per game:  -0.966153 , Elapsed time  556.05  minutes.
# Iteration: 46400. Average reward per game:  -0.895109 , Elapsed time  557.3  minutes.
# Iteration: 46500. Average reward per game:  -0.915728 , Elapsed time  558.59  minutes.
# Iteration: 46600. Average reward per game:  -0.938821 , Elapsed time  559.94  minutes.
# Iteration: 46700. Average reward per game:  -0.88635 , Elapsed time  561.26  minutes.
# Iteration: 46800. Average reward per game:  -0.95314 , Elapsed time  562.53  minutes.
# Iteration: 46900. Average reward per game:  -0.974425 , Elapsed time  563.79  minutes.
# Iteration: 47000. Average reward per game:  -0.931238 , Elapsed time  565.07  minutes.
# Iteration: 47100. Average reward per game:  -0.926036 , Elapsed time  566.31  minutes.
# Iteration: 47200. Average reward per game:  -0.936848 , Elapsed time  567.56  minutes.
# Iteration: 47300. Average reward per game:  -0.912853 , Elapsed time  568.79  minutes.
# Iteration: 47400. Average reward per game:  -0.896083 , Elapsed time  570.06  minutes.
# Iteration: 47500. Average reward per game:  -0.912251 , Elapsed time  571.31  minutes.
# Iteration: 47600. Average reward per game:  -0.839694 , Elapsed time  572.57  minutes.
# Iteration: 47700. Average reward per game:  -0.908829 , Elapsed time  573.81  minutes.
# Iteration: 47800. Average reward per game:  -0.889563 , Elapsed time  575.08  minutes.
# Iteration: 47900. Average reward per game:  -0.979759 , Elapsed time  576.32  minutes.
# Iteration: 48000. Average reward per game:  -0.929296 , Elapsed time  577.58  minutes.
# Iteration: 48100. Average reward per game:  -0.985023 , Elapsed time  578.83  minutes.
# Iteration: 48200. Average reward per game:  -0.937695 , Elapsed time  580.05  minutes.
# Iteration: 48300. Average reward per game:  -0.9744 , Elapsed time  581.3  minutes.
# Iteration: 48400. Average reward per game:  -0.981554 , Elapsed time  582.55  minutes.
# Iteration: 48500. Average reward per game:  -0.972204 , Elapsed time  583.78  minutes.
# Iteration: 48600. Average reward per game:  -0.938719 , Elapsed time  585.04  minutes.
# Iteration: 48700. Average reward per game:  -0.968448 , Elapsed time  586.28  minutes.
# Iteration: 48800. Average reward per game:  -0.940671 , Elapsed time  587.5  minutes.
# Iteration: 48900. Average reward per game:  -0.909205 , Elapsed time  588.75  minutes.
# Iteration: 49000. Average reward per game:  -0.947228 , Elapsed time  590.01  minutes.
# Iteration: 49100. Average reward per game:  -0.942139 , Elapsed time  591.25  minutes.
# Iteration: 49200. Average reward per game:  -0.89969 , Elapsed time  592.52  minutes.
# Iteration: 49300. Average reward per game:  -0.870577 , Elapsed time  593.77  minutes.
# Iteration: 49400. Average reward per game:  -0.945796 , Elapsed time  595.01  minutes.
# Iteration: 49500. Average reward per game:  -0.888584 , Elapsed time  596.25  minutes.
# Iteration: 49600. Average reward per game:  -0.898954 , Elapsed time  597.63  minutes.
# Iteration: 49700. Average reward per game:  -0.960826 , Elapsed time  599.0  minutes.
# Iteration: 49800. Average reward per game:  -0.997347 , Elapsed time  600.34  minutes.
# Iteration: 49900. Average reward per game:  -0.973145 , Elapsed time  601.82  minutes.
# Iteration: 50000. Average reward per game:  -0.86375 , Elapsed time  603.19  minutes.
# Iteration: 50100. Average reward per game:  -0.927858 , Elapsed time  604.45  minutes.
# Iteration: 50200. Average reward per game:  -0.887825 , Elapsed time  605.71  minutes.
# Iteration: 50300. Average reward per game:  -0.873139 , Elapsed time  606.99  minutes.
# Iteration: 50400. Average reward per game:  -0.875105 , Elapsed time  608.27  minutes.
# Iteration: 50500. Average reward per game:  -1.010811 , Elapsed time  609.52  minutes.
# Iteration: 50600. Average reward per game:  -0.924809 , Elapsed time  610.81  minutes.
# Iteration: 50700. Average reward per game:  -0.894505 , Elapsed time  612.08  minutes.
# Iteration: 50800. Average reward per game:  -0.886301 , Elapsed time  613.36  minutes.
# Iteration: 50900. Average reward per game:  -0.930233 , Elapsed time  614.66  minutes.
# Iteration: 51000. Average reward per game:  -0.879506 , Elapsed time  615.95  minutes.
# Iteration: 51100. Average reward per game:  -0.862322 , Elapsed time  617.23  minutes.
# Iteration: 51200. Average reward per game:  -0.940738 , Elapsed time  618.5  minutes.
# Iteration: 51300. Average reward per game:  -0.86846 , Elapsed time  619.77  minutes.
# Iteration: 51400. Average reward per game:  -0.884233 , Elapsed time  621.04  minutes.
# Iteration: 51500. Average reward per game:  -0.920053 , Elapsed time  622.3  minutes.
# Iteration: 51600. Average reward per game:  -0.86341 , Elapsed time  623.59  minutes.
# Iteration: 51700. Average reward per game:  -0.846115 , Elapsed time  624.86  minutes.
# Iteration: 51800. Average reward per game:  -0.948256 , Elapsed time  626.15  minutes.
# Iteration: 51900. Average reward per game:  -0.897082 , Elapsed time  627.39  minutes.
# Iteration: 52000. Average reward per game:  -0.959445 , Elapsed time  628.68  minutes.
# Iteration: 52100. Average reward per game:  -0.953328 , Elapsed time  629.96  minutes.
# Iteration: 52200. Average reward per game:  -0.85038 , Elapsed time  631.28  minutes.
# Iteration: 52300. Average reward per game:  -0.954781 , Elapsed time  632.56  minutes.
# Iteration: 52400. Average reward per game:  -0.97956 , Elapsed time  633.87  minutes.
# Iteration: 52500. Average reward per game:  -1.050212 , Elapsed time  635.15  minutes.
# Iteration: 52600. Average reward per game:  -1.019704 , Elapsed time  636.43  minutes.
# Iteration: 52700. Average reward per game:  -1.027309 , Elapsed time  637.68  minutes.
# Iteration: 52800. Average reward per game:  -0.938462 , Elapsed time  638.97  minutes.
# Iteration: 52900. Average reward per game:  -0.94333 , Elapsed time  640.23  minutes.
# Iteration: 53000. Average reward per game:  -0.869336 , Elapsed time  641.45  minutes.
# ...
# Iteration: 55900. Average reward per game:  -1.006848 , Elapsed time  678.62  minutes.
# Iteration: 56000. Average reward per game:  -0.931272 , Elapsed time  679.88  minutes.
# Iteration: 56100. Average reward per game:  -0.928432 , Elapsed time  681.11  minutes.
# Iteration: 56200. Average reward per game:  -0.912566 , Elapsed time  682.38  minutes.
# Iteration: 56300. Average reward per game:  -0.910348 , Elapsed time  683.62  minutes.
# Iteration: 56400. Average reward per game:  -0.923861 , Elapsed time  684.86  minutes.
# Iteration: 56500. Average reward per game:  -0.966595 , Elapsed time  686.13  minutes.
# Iteration: 56600. Average reward per game:  -0.892335 , Elapsed time  687.36  minutes.
# Iteration: 56700. Average reward per game:  -0.944426 , Elapsed time  688.6  minutes.
# Iteration: 56800. Average reward per game:  -0.935098 , Elapsed time  689.84  minutes.
# Iteration: 56900. Average reward per game:  -0.869206 , Elapsed time  691.09  minutes.
# Iteration: 57000. Average reward per game:  -0.906457 , Elapsed time  692.32  minutes.
# Iteration: 57100. Average reward per game:  -0.846898 , Elapsed time  693.56  minutes.
# Iteration: 57200. Average reward per game:  -0.90381 , Elapsed time  694.79  minutes.
# Iteration: 57300. Average reward per game:  -0.899058 , Elapsed time  696.04  minutes.
# Iteration: 57400. Average reward per game:  -0.868015 , Elapsed time  697.26  minutes.
# Iteration: 57500. Average reward per game:  -0.837559 , Elapsed time  698.51  minutes.
# Iteration: 57600. Average reward per game:  -0.899707 , Elapsed time  699.71  minutes.
# Iteration: 57700. Average reward per game:  -0.826239 , Elapsed time  700.93  minutes.
# Iteration: 57800. Average reward per game:  -0.844362 , Elapsed time  702.17  minutes.
# Iteration: 57900. Average reward per game:  -0.864364 , Elapsed time  703.4  minutes.
# Iteration: 58000. Average reward per game:  -0.919418 , Elapsed time  704.63  minutes.
# Iteration: 58100. Average reward per game:  -0.841033 , Elapsed time  705.8  minutes.
# Iteration: 58200. Average reward per game:  -1.132611 , Elapsed time  707.06  minutes.
# Iteration: 58300. Average reward per game:  -1.022987 , Elapsed time  708.28  minutes.
# Iteration: 58400. Average reward per game:  -1.089456 , Elapsed time  709.55  minutes.
# Iteration: 58500. Average reward per game:  -1.056858 , Elapsed time  710.81  minutes.
# Iteration: 58600. Average reward per game:  -1.028041 , Elapsed time  712.04  minutes.
# Iteration: 58700. Average reward per game:  -0.910222 , Elapsed time  713.26  minutes.
# Iteration: 58800. Average reward per game:  -0.845843 , Elapsed time  714.51  minutes.
# Iteration: 58900. Average reward per game:  -0.832201 , Elapsed time  715.74  minutes.
# Iteration: 59000. Average reward per game:  -0.942785 , Elapsed time  716.97  minutes.
# Iteration: 59100. Average reward per game:  -0.892981 , Elapsed time  718.2  minutes.
# Iteration: 59200. Average reward per game:  -0.781318 , Elapsed time  719.43  minutes.
# Iteration: 59300. Average reward per game:  -0.927441 , Elapsed time  720.68  minutes.
# Iteration: 59400. Average reward per game:  -0.812133 , Elapsed time  721.92  minutes.
# Iteration: 59500. Average reward per game:  -0.920778 , Elapsed time  723.17  minutes.
# Iteration: 59600. Average reward per game:  -0.870005 , Elapsed time  724.42  minutes.
# Iteration: 59700. Average reward per game:  -0.913287 , Elapsed time  725.66  minutes.
# Iteration: 59800. Average reward per game:  -0.966455 , Elapsed time  726.92  minutes.
# Iteration: 59900. Average reward per game:  -0.890061 , Elapsed time  728.16  minutes.
# Iteration: 60000. Average reward per game:  -0.889421 , Elapsed time  729.4  minutes.
# Iteration: 60100. Average reward per game:  -0.898866 , Elapsed time  730.65  minutes.
# Iteration: 60200. Average reward per game:  -0.88413 , Elapsed time  731.9  minutes.
# Iteration: 60300. Average reward per game:  -0.937971 , Elapsed time  733.13  minutes.
# Iteration: 60400. Average reward per game:  -0.914796 , Elapsed time  734.37  minutes.
# Iteration: 60500. Average reward per game:  -0.95149 , Elapsed time  735.63  minutes.
# Iteration: 60600. Average reward per game:  -0.949026 , Elapsed time  736.84  minutes.
# Iteration: 60700. Average reward per game:  -0.95678 , Elapsed time  738.06  minutes.
# Iteration: 60800. Average reward per game:  -0.923738 , Elapsed time  739.31  minutes.
# Iteration: 60900. Average reward per game:  -0.929812 , Elapsed time  740.56  minutes.
# Iteration: 61000. Average reward per game:  -0.89534 , Elapsed time  741.79  minutes.
# Iteration: 61100. Average reward per game:  -0.980367 , Elapsed time  743.05  minutes.
# Iteration: 61200. Average reward per game:  -1.037861 , Elapsed time  744.27  minutes.
# Iteration: 61300. Average reward per game:  -1.031398 , Elapsed time  745.52  minutes.
# Iteration: 61400. Average reward per game:  -1.000399 , Elapsed time  746.77  minutes.
# Iteration: 61500. Average reward per game:  -1.014382 , Elapsed time  747.99  minutes.
# Iteration: 61600. Average reward per game:  -1.053006 , Elapsed time  749.26  minutes.
# Iteration: 61700. Average reward per game:  -1.137092 , Elapsed time  750.54  minutes.
# Iteration: 61800. Average reward per game:  -1.01237 , Elapsed time  751.78  minutes.
# Iteration: 61900. Average reward per game:  -0.966295 , Elapsed time  753.03  minutes.
# Iteration: 62000. Average reward per game:  -0.948739 , Elapsed time  754.27  minutes.
# Iteration: 62100. Average reward per game:  -0.978253 , Elapsed time  755.5  minutes.
# Iteration: 62200. Average reward per game:  -1.014375 , Elapsed time  756.74  minutes.
# Iteration: 62300. Average reward per game:  -0.984128 , Elapsed time  757.99  minutes.
# Iteration: 62400. Average reward per game:  -0.994066 , Elapsed time  759.23  minutes.
# Iteration: 62500. Average reward per game:  -1.025899 , Elapsed time  760.47  minutes.
# Iteration: 62600. Average reward per game:  -0.906223 , Elapsed time  761.63  minutes.
# Iteration: 62700. Average reward per game:  -0.93371 , Elapsed time  762.89  minutes.
# Iteration: 62800. Average reward per game:  -0.888446 , Elapsed time  764.14  minutes.
# Iteration: 62900. Average reward per game:  -0.859674 , Elapsed time  765.37  minutes.
# Iteration: 63000. Average reward per game:  -0.869588 , Elapsed time  766.6  minutes.
# Iteration: 63100. Average reward per game:  -0.891407 , Elapsed time  767.78  minutes.
# Iteration: 63200. Average reward per game:  -0.854534 , Elapsed time  769.04  minutes.
# Iteration: 63300. Average reward per game:  -0.962631 , Elapsed time  770.28  minutes.
# Iteration: 63400. Average reward per game:  -0.909898 , Elapsed time  771.51  minutes.
# Iteration: 63500. Average reward per game:  -0.863306 , Elapsed time  772.68  minutes.
# Iteration: 63600. Average reward per game:  -0.911457 , Elapsed time  773.92  minutes.
# Iteration: 63700. Average reward per game:  -0.88686 , Elapsed time  775.17  minutes.
# Iteration: 63800. Average reward per game:  -0.951335 , Elapsed time  776.43  minutes.
# Iteration: 63900. Average reward per game:  -0.944044 , Elapsed time  777.68  minutes.
# Iteration: 64000. Average reward per game:  -0.994711 , Elapsed time  778.96  minutes.
# Iteration: 64100. Average reward per game:  -0.916685 , Elapsed time  780.21  minutes.
# Iteration: 64200. Average reward per game:  -0.957163 , Elapsed time  781.45  minutes.
# Iteration: 64300. Average reward per game:  -0.976829 , Elapsed time  782.66  minutes.
# Iteration: 64400. Average reward per game:  -0.948525 , Elapsed time  783.89  minutes.
# Iteration: 64500. Average reward per game:  -0.991383 , Elapsed time  785.15  minutes.
# Iteration: 64600. Average reward per game:  -0.907317 , Elapsed time  786.42  minutes.
# Iteration: 64700. Average reward per game:  -0.889479 , Elapsed time  787.71  minutes.
# Iteration: 64800. Average reward per game:  -0.896146 , Elapsed time  788.97  minutes.
# Iteration: 64900. Average reward per game:  -0.903112 , Elapsed time  790.22  minutes.
# Iteration: 65000. Average reward per game:  -0.911195 , Elapsed time  791.48  minutes.
# Iteration: 65100. Average reward per game:  -0.865581 , Elapsed time  792.76  minutes.
# Iteration: 65200. Average reward per game:  -0.951796 , Elapsed time  793.97  minutes.
# Iteration: 65300. Average reward per game:  -0.943241 , Elapsed time  795.24  minutes.
# Iteration: 65400. Average reward per game:  -0.873981 , Elapsed time  796.51  minutes.
# Iteration: 65500. Average reward per game:  -0.899628 , Elapsed time  797.76  minutes.
# Iteration: 65600. Average reward per game:  -0.925845 , Elapsed time  798.96  minutes.
# Iteration: 65700. Average reward per game:  -0.924597 , Elapsed time  800.22  minutes.
# Iteration: 65800. Average reward per game:  -0.863964 , Elapsed time  801.47  minutes.
# Iteration: 65900. Average reward per game:  -0.927803 , Elapsed time  802.85  minutes.
# Iteration: 66000. Average reward per game:  -0.907666 , Elapsed time  804.2  minutes.
# Iteration: 66100. Average reward per game:  -0.987546 , Elapsed time  805.55  minutes.
# Iteration: 66200. Average reward per game:  -0.953623 , Elapsed time  806.92  minutes.
# Iteration: 66300. Average reward per game:  -0.925279 , Elapsed time  808.27  minutes.
# Iteration: 66400. Average reward per game:  -0.920799 , Elapsed time  809.62  minutes.
# Iteration: 66500. Average reward per game:  -0.935973 , Elapsed time  810.99  minutes.
# Iteration: 66600. Average reward per game:  -0.942434 , Elapsed time  812.32  minutes.
# Iteration: 66700. Average reward per game:  -0.986978 , Elapsed time  813.59  minutes.
# Iteration: 66800. Average reward per game:  -0.893242 , Elapsed time  814.87  minutes.
# Iteration: 66900. Average reward per game:  -1.389009 , Elapsed time  816.2  minutes.
# Iteration: 67000. Average reward per game:  -0.964352 , Elapsed time  817.55  minutes.
# Iteration: 67100. Average reward per game:  -1.155012 , Elapsed time  818.86  minutes.
# Iteration: 67200. Average reward per game:  -0.887804 , Elapsed time  820.22  minutes.
# Iteration: 67300. Average reward per game:  -0.865358 , Elapsed time  821.52  minutes.
# Iteration: 67400. Average reward per game:  -0.844831 , Elapsed time  822.79  minutes.
# Iteration: 67500. Average reward per game:  -0.875648 , Elapsed time  824.13  minutes.
# Iteration: 67600. Average reward per game:  -0.874615 , Elapsed time  825.44  minutes.
# Iteration: 67700. Average reward per game:  -0.91623 , Elapsed time  826.74  minutes.
# Iteration: 67800. Average reward per game:  -0.927766 , Elapsed time  828.05  minutes.
# Iteration: 67900. Average reward per game:  -0.950896 , Elapsed time  829.38  minutes.
# Iteration: 68000. Average reward per game:  -0.881318 , Elapsed time  830.55  minutes.
# Iteration: 68100. Average reward per game:  -0.881412 , Elapsed time  831.77  minutes.
# Iteration: 68200. Average reward per game:  -0.921198 , Elapsed time  833.0  minutes.
# Iteration: 68300. Average reward per game:  -0.83469 , Elapsed time  834.34  minutes.
# Iteration: 68400. Average reward per game:  -0.934427 , Elapsed time  835.68  minutes.
# Iteration: 68500. Average reward per game:  -0.913073 , Elapsed time  836.95  minutes.
# Iteration: 68600. Average reward per game:  -0.889426 , Elapsed time  838.28  minutes.
# Iteration: 68700. Average reward per game:  -0.884423 , Elapsed time  839.61  minutes.
# Iteration: 68800. Average reward per game:  -0.951971 , Elapsed time  840.96  minutes.
# Iteration: 68900. Average reward per game:  -0.868747 , Elapsed time  842.31  minutes.
# Iteration: 69000. Average reward per game:  -0.870792 , Elapsed time  843.63  minutes.
# Iteration: 69100. Average reward per game:  -0.880393 , Elapsed time  844.96  minutes.
# Iteration: 69200. Average reward per game:  -0.871435 , Elapsed time  846.25  minutes.
# Iteration: 69300. Average reward per game:  -0.93321 , Elapsed time  847.6  minutes.
# Iteration: 69400. Average reward per game:  -0.93072 , Elapsed time  848.92  minutes.
# Iteration: 69500. Average reward per game:  -0.904315 , Elapsed time  850.23  minutes.
# Iteration: 69600. Average reward per game:  -1.029992 , Elapsed time  851.54  minutes.
# Iteration: 69700. Average reward per game:  -0.905835 , Elapsed time  852.87  minutes.
# Iteration: 69800. Average reward per game:  -0.919891 , Elapsed time  854.21  minutes.
# Iteration: 69900. Average reward per game:  -0.910135 , Elapsed time  855.58  minutes.
# Iteration: 70000. Average reward per game:  -0.872577 , Elapsed time  856.85  minutes.
# Iteration: 70100. Average reward per game:  -0.903388 , Elapsed time  858.13  minutes.
# Iteration: 70200. Average reward per game:  -0.892217 , Elapsed time  859.4  minutes.
# Iteration: 70300. Average reward per game:  -0.944785 , Elapsed time  860.66  minutes.
# Iteration: 70400. Average reward per game:  -0.877903 , Elapsed time  861.87  minutes.
# Iteration: 70500. Average reward per game:  -0.947235 , Elapsed time  863.09  minutes.
# Iteration: 70600. Average reward per game:  -0.937751 , Elapsed time  864.35  minutes.
# Iteration: 70700. Average reward per game:  -0.961819 , Elapsed time  865.61  minutes.
# Iteration: 70800. Average reward per game:  -0.94822 , Elapsed time  866.85  minutes.
# Iteration: 70900. Average reward per game:  -0.935395 , Elapsed time  868.11  minutes.
# Iteration: 71000. Average reward per game:  -0.923384 , Elapsed time  869.35  minutes.
# Iteration: 71100. Average reward per game:  -0.921411 , Elapsed time  870.6  minutes.
# Iteration: 71200. Average reward per game:  -0.957402 , Elapsed time  871.86  minutes.
# Iteration: 71300. Average reward per game:  -0.891065 , Elapsed time  873.11  minutes.
# Iteration: 71400. Average reward per game:  -0.870028 , Elapsed time  874.37  minutes.
# Iteration: 71500. Average reward per game:  -0.937737 , Elapsed time  875.63  minutes.
# Iteration: 71600. Average reward per game:  -0.854062 , Elapsed time  876.88  minutes.
# Iteration: 71700. Average reward per game:  -0.860383 , Elapsed time  878.08  minutes.
# Iteration: 71800. Average reward per game:  -0.86981 , Elapsed time  879.33  minutes.
# Iteration: 71900. Average reward per game:  -0.887684 , Elapsed time  880.58  minutes.
# Iteration: 72000. Average reward per game:  -0.941063 , Elapsed time  881.85  minutes.
# Iteration: 72100. Average reward per game:  -0.907947 , Elapsed time  883.1  minutes.
# Iteration: 72200. Average reward per game:  -0.835158 , Elapsed time  884.34  minutes.
# Iteration: 72300. Average reward per game:  -0.886164 , Elapsed time  885.58  minutes.
# Iteration: 72400. Average reward per game:  -0.936215 , Elapsed time  886.83  minutes.
# Iteration: 72500. Average reward per game:  -0.948605 , Elapsed time  888.09  minutes.
# Iteration: 72600. Average reward per game:  -0.945671 , Elapsed time  889.35  minutes.
# Iteration: 72700. Average reward per game:  -0.991125 , Elapsed time  890.53  minutes.
# Iteration: 72800. Average reward per game:  -1.010026 , Elapsed time  891.79  minutes.
# Iteration: 72900. Average reward per game:  -1.039006 , Elapsed time  893.06  minutes.
# Iteration: 73000. Average reward per game:  -0.964081 , Elapsed time  894.33  minutes.
# Iteration: 73100. Average reward per game:  -0.915427 , Elapsed time  895.59  minutes.
# Iteration: 73200. Average reward per game:  -0.916546 , Elapsed time  896.85  minutes.
# Iteration: 73300. Average reward per game:  -0.916913 , Elapsed time  898.11  minutes.
# Iteration: 73400. Average reward per game:  -0.889965 , Elapsed time  899.35  minutes.
# Iteration: 73500. Average reward per game:  -0.892874 , Elapsed time  900.59  minutes.
# Iteration: 73600. Average reward per game:  -0.911899 , Elapsed time  901.83  minutes.
# Iteration: 73700. Average reward per game:  -0.844519 , Elapsed time  903.1  minutes.
# Iteration: 73800. Average reward per game:  -0.835437 , Elapsed time  904.36  minutes.
# Iteration: 73900. Average reward per game:  -0.876908 , Elapsed time  905.61  minutes.
# Iteration: 74000. Average reward per game:  -0.920751 , Elapsed time  906.87  minutes.
# Iteration: 74100. Average reward per game:  -0.959088 , Elapsed time  908.13  minutes.
# Iteration: 74200. Average reward per game:  -0.926899 , Elapsed time  909.34  minutes.
# Iteration: 74216

# %% [markdown]
# ## Visualizations

# %%
# Visualizing train simulation:

#episode =episodes
#simulation_id = 2
#step = 30

discrewards = pd.read_table(rewards_file, sep = ",")* 10 #we divided by the number of games per episode at running time

indices = [i for i in range(0,n_iterations,1)]

plt.plot(discrewards['iteration'][indices],discrewards['discreward'][indices], label = "Discounted rewards")
plt.title("Discounted rewards per episode during training")
plt.xlabel("Episode")
plt.ylabel("Discounted reward")

plt.savefig(simulation_directory + '/discounted-rewards-sim' + '{}'.format(simulation_id) + '.pdf')

plt.show()
plt.close()

# %% [markdown]
# # PG Testing

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 1

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 


with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
               
        env.close()
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation328/NN-models/pdenv_best_policy_net_pg.ckpt

# %% [markdown]
# ## Giff animation

# %%
test_anim = ut.create_system_animation(frames, n_episodes * episode_length)
plt.close()

HTML(test_anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## Visualization with matplotlib

# %%
from utils_pg import is_empty
from utils_pg import my_indicator

def visualize_simulation(states_file,
                        test_toy_system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list):
    test_states = pd.read_table(states_file, sep = ",")
    test_states.head()


    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, n)]
    lvl_colors = ["Orange", "Green","Orange"]

    #tanks = test_toy_system.tanks
    tanks_max_load = system.tank_max_loads
    level_percentages = system.load_level_percentages

    for i, color in enumerate(colors, start=1):    
        plt.subplot(2,3,i)
        states = test_states['stock{}'.format(i-1)]
        plt.plot(test_states['step'],states, label = "Shop {}".format(i-1), color = "Black")
        plt.title("Shop {}".format(i-1))

        plt.axhline(y= tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = "Red", linestyle = '--')
        for lvl_color, lvl in zip(lvl_colors, level_percentages[i-1]):
            plt.axhline(y= lvl * tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = lvl_color, 
                        linestyle = '--')
        plt.axhline(y= 0, xmin=0, xmax=episode_length, hold=None, color = "Red", linestyle = '--')


        percentages = level_percentages[i-1]           
        c = percentages[1]
        e = percentages[2]          
        d = ct.p0_GLOBAL*e+(1-ct.p0_GLOBAL)*c
        plt.axhline(y= d*tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = "lawngreen", 
                    linestyle = '-.')

        plt.axhline(y= np.mean(states), xmin=0, xmax=episode_length, hold=None, 
                    color = "blue", linestyle = '-.')
        plt.xticks(range(0,episode_length*n_episodes+1,5*n_episodes
                        ))
        
        #################### INFO LEVELS
        b = percentages[0]
        level_counts = np.zeros(5, dtype = np.int64)
        
        x_mins = np.array([0,b,c,e])*tanks_max_load[i-1]
        x_maxs = np.array([b,c,e,1])*tanks_max_load[i-1]

        for x in states:
            level_counts[0] = level_counts[0] + is_empty(x)
            for j in range(1,5):
                level_counts[j] = level_counts[j] + my_indicator(x_mins[j-1], x, x_maxs[j-1])
            
        level_counts_list.append(level_counts)
        ###################################################

    plt.subplot(2,3,6)
    plt.title("Legend")
    plt.axis('off')

    #plt.legend(bbox_to_anchor=(0.5 ,0.8), loc=2, borderaxespad=0.)
    plt.yticks([])
    plt.xticks([])

    patch1 = mpatches.Patch(color='red', label='Max/Min capacities', linestyle = '--', fill = False, linewidth = 2)
    patch2 = mpatches.Patch(color='orange', label='Max/Min levels', linestyle = '--', fill = False, linewidth = 2)
    patch3 = mpatches.Patch(color='green', label='Danger level', linestyle = '--', fill = False, linewidth = 2)
    patch4 = mpatches.Patch(color='lawngreen', label='Max reward level (M)', linestyle = '-.', fill = False, linewidth = 2)
    patch5 = mpatches.Patch(color='blue', label='Observed mean level', linestyle = '-.', fill = False, linewidth = 2)
    patch6 = mpatches.Patch(color='black', label='Current stock level', linestyle = '-', fill = False, linewidth = 2)


    plt.legend(handles=[patch1, patch2, patch3, patch4, patch5, patch6], loc = 'center')

    plt.tight_layout() 
    plt.savefig(simulation_directory + '/tank-levels-sim' + '{}'.format(simulation_id) + '.pdf')
    plt.show()
    plt.close()

# %%
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list)

# %% [markdown]
# ## Performance metrics

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 100

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 

####
test_visualization_steps = []
test_rewards_list = []
test_level_rewards_list = []
test_transport_rewards_list = []
test_trucks_sent_list = []
test_number_of_first_trucks_sent_list = []
test_number_of_second_trucks_sent_list = []
test_number_of_trucks_not_deliverying_list = []
####

with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            #####
            discounted_reward = 0 
            transport_rewards = 0
            level_rewards = 0
            number_of_trucks_sent = 0
            number_of_first_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_second_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_trucks_not_deliverying = 0                   
            #####         
         
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
            
                trucks_not_del = info["trucks_not_deliverying"]
                level_reward = info["level_rewards"]
                transport_reward = info["transport_rewards"]
                ### STORE STEP INFO
                discounted_reward = discounted_reward + (discount_rate**(step)) * reward
                transport_rewards = transport_rewards+transport_reward
                level_rewards = level_rewards + level_reward
                
                number_of_trucks_sent = number_of_trucks_sent + np.sum(vect_action == 5)
                index1 = vect_action[0]
                number_of_first_trucks_sent[index1] = number_of_first_trucks_sent[index1] + 1
                index2 = vect_action[1]
                number_of_second_trucks_sent[index2] = number_of_second_trucks_sent[index2] + 1
                number_of_trucks_not_deliverying =  number_of_trucks_not_deliverying + trucks_not_del
                
            test_rewards_list.append(discounted_reward);
            test_transport_rewards_list.append(transport_rewards);
            test_level_rewards_list.append(level_rewards);
            test_trucks_sent_list.append(episode_length * system.k - number_of_trucks_sent);
            test_number_of_first_trucks_sent_list.append(number_of_first_trucks_sent);
            test_number_of_second_trucks_sent_list.append(number_of_second_trucks_sent);
            test_number_of_trucks_not_deliverying_list.append(number_of_trucks_not_deliverying);                   
                
               
        env.close()
        
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list) 

print("Total discounted rewards","Level rewards", "Transport rewards")
print(sum(test_rewards_list)/n_episodes, sum(test_level_rewards_list)/n_episodes,sum(test_transport_rewards_list)/n_episodes )
print("Average trucks sent: ", sum(test_trucks_sent_list)/n_episodes)
    
#     if n_episodes == 1:
first_type = sum(test_number_of_first_trucks_sent_list)/n_episodes
print("Average 1st type Trucks sent to each shop:", first_type)
print("Average 1st type Trucks sent:", sum(first_type[0:n] ) )

second_type = sum(test_number_of_second_trucks_sent_list)/n_episodes
print("Average 2nd type Trucks sent to each shop:", second_type)
print("Average 2nd type Trucks sent:",  sum(second_type[0:n] ))

print("Average number of trucks not deliverying:", sum(test_number_of_trucks_not_deliverying_list)/n_episodes )

for i in range(n):
        print("Average level counts for shop {}:".format(i), test_level_counts_list[i]/n_episodes )

        
print("Average total level counts:", sum(test_level_counts_list)/n_episodes )
print("Percentage total level counts:", (sum(test_level_counts_list)/n_episodes)/(episode_length * n) * 100 )
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation328/NN-models/pdenv_best_policy_net_pg.ckpt
# Total discounted rewards Level rewards Transport rewards
# -1681171.0510550437 -5556855.720255325 29341.096634099977
# Average trucks sent:  39.52
# Average 1st type Trucks sent to each shop: [ 7.1   0.93  4.41  0.    6.06 11.5 ]
# Average 1st type Trucks sent: 18.5
# Average 2nd type Trucks sent to each shop: [ 0.    0.    0.   16.61  4.41  8.98]
# Average 2nd type Trucks sent: 21.02
# Average number of trucks not deliverying: 0.66
# Average level counts for shop 0: [ 1.02  0.38 11.08 17.52  0.  ]
# Average level counts for shop 1: [3.000e-02 1.000e-02 4.000e-02 2.992e+01 0.000e+00]
# Average level counts for shop 2: [ 0.42  0.84  3.42 25.32  0.  ]
# Average level counts for shop 3: [ 2.18  4.84  6.33 16.65  0.  ]
# Average level counts for shop 4: [ 0.8   1.65  8.14 19.41  0.  ]
# Average total level counts: [  4.45   7.72  29.01 108.82   0.  ]
# Percentage total level counts: [ 2.96666667  5.14666667 19.34       72.54666667  0.        ]

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 1

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 

####
test_visualization_steps = []
test_rewards_list = []
test_level_rewards_list = []
test_transport_rewards_list = []
test_trucks_sent_list = []
test_number_of_first_trucks_sent_list = []
test_number_of_second_trucks_sent_list = []
test_number_of_trucks_not_deliverying_list = []
####

with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            #####
            discounted_reward = 0 
            transport_rewards = 0
            level_rewards = 0
            number_of_trucks_sent = 0
            number_of_first_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_second_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_trucks_not_deliverying = 0                   
            #####         
         
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
            
                trucks_not_del = info["trucks_not_deliverying"]
                level_reward = info["level_rewards"]
                transport_reward = info["transport_rewards"]
                ### STORE STEP INFO
                discounted_reward = discounted_reward + (discount_rate**(step)) * reward
                transport_rewards = transport_rewards+transport_reward
                level_rewards = level_rewards + level_reward
                
                number_of_trucks_sent = number_of_trucks_sent + np.sum(vect_action == 5)
                index1 = vect_action[0]
                number_of_first_trucks_sent[index1] = number_of_first_trucks_sent[index1] + 1
                index2 = vect_action[1]
                number_of_second_trucks_sent[index2] = number_of_second_trucks_sent[index2] + 1
                number_of_trucks_not_deliverying =  number_of_trucks_not_deliverying + trucks_not_del
                
            test_rewards_list.append(discounted_reward);
            test_transport_rewards_list.append(transport_rewards);
            test_level_rewards_list.append(level_rewards);
            test_trucks_sent_list.append(episode_length * system.k - number_of_trucks_sent);
            test_number_of_first_trucks_sent_list.append(number_of_first_trucks_sent);
            test_number_of_second_trucks_sent_list.append(number_of_second_trucks_sent);
            test_number_of_trucks_not_deliverying_list.append(number_of_trucks_not_deliverying);                   
                
               
        env.close()
        
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list) 

print("Total discounted rewards","Level rewards", "Transport rewards")
print(sum(test_rewards_list)/n_episodes, sum(test_level_rewards_list)/n_episodes,sum(test_transport_rewards_list)/n_episodes )
print("Average trucks sent: ", sum(test_trucks_sent_list)/n_episodes)
    
#     if n_episodes == 1:
first_type = sum(test_number_of_first_trucks_sent_list)/n_episodes
print("Average 1st type Trucks sent to each shop:", first_type)
print("Average 1st type Trucks sent:", sum(first_type[0:n] ) )

second_type = sum(test_number_of_second_trucks_sent_list)/n_episodes
print("Average 2nd type Trucks sent to each shop:", second_type)
print("Average 2nd type Trucks sent:",  sum(second_type[0:n] ))

print("Average number of trucks not deliverying:", sum(test_number_of_trucks_not_deliverying_list)/n_episodes )

for i in range(n):
        print("Average level counts for shop {}:".format(i), test_level_counts_list[i]/n_episodes )

        
print("Average total level counts:", sum(test_level_counts_list)/n_episodes )
print("Percentage total level counts:", (sum(test_level_counts_list)/n_episodes)/(episode_length * n) * 100 )
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation328/NN-models/pdenv_best_policy_net_pg.ckpt
# Total discounted rewards Level rewards Transport rewards
# -394990.19240016415 -4056644.19947166 31073.775209999985
# Average trucks sent:  40.0
# Average 1st type Trucks sent to each shop: [ 6.  1.  5.  0.  5. 13.]
# Average 1st type Trucks sent: 17.0
# Average 2nd type Trucks sent to each shop: [ 0.  0.  0. 18.  5.  7.]
# Average 2nd type Trucks sent: 23.0
# Average number of trucks not deliverying: 0.0
# Average level counts for shop 0: [ 1.  0. 12. 17.  0.]
# Average level counts for shop 1: [ 0.  0.  0. 30.  0.]
# Average level counts for shop 2: [ 0.  0.  2. 28.  0.]
# Average level counts for shop 3: [ 3.  5. 10. 12.  0.]
# Average level counts for shop 4: [ 0.  4.  8. 18.  0.]
# Average total level counts: [  4.   9.  32. 105.   0.]
# Percentage total level counts: [ 2.66666667  6.         21.33333333 70.          0.        ]
