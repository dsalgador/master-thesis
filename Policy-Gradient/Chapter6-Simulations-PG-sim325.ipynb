# %%
""" 
The algorithm is tested on the PDSystemEnv  gym task 
and developed with Tensorflow

Author: Daniel Salgado Rojo
"""

import tensorflow as tf
import numpy as np
import gym
import gym_pdsystem
from gym import wrappers
#import tflearn
import argparse
import pprint as pp

#from ddpg.replay_buffer import ReplayBuffer

from datetime import datetime

import random

from gym_pdsystem.envs.pdsystem_env import PDSystemEnv
import gym_pdsystem.utils.utilsq as ut
import gym_pdsystem.utils.constants as ct
import gym_pdsystem.utils.functions as fnc


from matplotlib import animation, rc
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import HTML


import pandas as pd
import time

from functools import partial

import os

#TO OMMIT WARNINGS
import warnings
warnings.filterwarnings('ignore')

def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)
    
simulations_directory = './simulations'
if not os.path.exists(simulations_directory):
    os.makedirs(simulations_directory)
# Out:
# /home/dsalgador/anaconda3/envs/tensorflow/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # System's parmeters

# %%
# In order to change the parameters of the system, such as number of shops, trucks, etc, one must change
# the corresponding constants in the 'constants.py' file from the 'gym pd_system' package.

CASE = ct.CASE
STOCHASTIC = ct.STOCHASTIC 

###########################################################

TANK_MAX_LOADS = ct.TANK_MAX_LOADS
LEVEL_PERCENTAGES = ct.LEVEL_PERCENTAGES 
TRUCK_MAX_LOADS = ct.TRUCK_MAX_LOADS
GRAPH_WEIGHTS = ct.GRAPH_WEIGHTS 
DISCRETE = ct.DISCRETE

n = len(TANK_MAX_LOADS)
k = len(TRUCK_MAX_LOADS)

env = gym.make("PDSystemEnv-v0")
episode_length = 30
env._max_episode_steps = episode_length

###########################################################

print("System with k={} trucks and n={} shops. Episodes of {} days.".format(k,n,episode_length))
# Out:
# System with k=2 trucks and n=5 shops. Episodes of 30 days.

# %%
import utils_pg
from utils_pg import int_to_action
from utils_pg import action_to_int
from utils_pg import discount_rewards
from utils_pg import normalize_rewards

# %% [markdown]
# # Tensorflow graph (DNN) for MC Policy Gradient Algorithm

# %%
simulation_id = 325

# Create directories for the simulations' outputs

simulation_directory = './simulations/simulation{}'.format(simulation_id)
rewards_file = simulation_directory+'/discrewards'+ '/rewards-sim{}.csv'.format(simulation_id)
states_file = simulation_directory+'/vis'+ '/states-sim{}.csv'.format(simulation_id) # for testing
models_dir = simulation_directory + '/NN-models'

if not os.path.exists(simulation_directory):
    os.makedirs(simulation_directory)
    os.makedirs(models_dir)
    os.makedirs(simulation_directory + '/discrewards')
    os.makedirs(simulation_directory + '/vis')
    
else:
    raise Exception("The simulation id you tried to use has been already used before. Try to change it to a new one.")

# Output headers to file
with open(rewards_file,'w') as f:
     np.savetxt(f, [["iteration", "discreward"]], fmt="%s", delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-032162cd66c5> in <module>()
#      15
#      16 else:
# ---> 17     raise Exception("The simulation id you tried to use has been already used before. Try to change it to a new one.")
#      18
#      19 # Output headers to file
#
# Exception: The simulation id you tried to use has been already used before. Try to change it to a new one.

# %%
seed = 42
reset_graph(seed)

################################
# TensorBoard summary directories
now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
root_logdir = "tf_logs"
logdir = "{}/run-{}/".format(root_logdir, now)   
################################

## DNN hyperparameters ################
learning_rate = 0.01 #0.01

hidden1_neurons = 100 #100
hidden2_neurons = 50 #50

# batch_normalization = True  
# batch_norm_momentum = 0.9
######################################



######################################
#### Training hyperparameters ########
######################################
# File names for the model

model_file = models_dir + "/pdenv_policy_net_pg.ckpt"#.format(learning_rate)
best_model_file = models_dir + "/pdenv_best_policy_net_pg.ckpt"#.format(learning_rate)
graph_file =  '{}.meta'.format(model_file)


# Simulation / Training parameters
n_games_per_update = 10
n_max_steps = episode_length
n_iterations = 10**5 #2*10**4
save_iterations = 100 # USEFUL WHEN USING EARLY STOPPING
discount_rate = 0.9

info_freq = 100 #100
round_time = 2
round_reward = 6
summary_freq = 20#int(info_freq/2), 10

# Early stopping
max_checks_without_progress = np.inf # 10,  one for each "info_freq" (in terms of iterations it would be
                                                            #max_checks_without_progress *  info_freq)
checks_without_progress = 0
best_reward = -np.infty


retrain = False
########################################



###### TENSORFLOW GRAPH #########
tf.set_random_seed(seed)
with tf.name_scope("dnn"):
        
            # 1. Parameters to determine the NN architecture

            n_inputs = env.observation_space.shape[1]
            n_hidden1 = hidden1_neurons; activation1 = tf.nn.sigmoid#tf.nn.elu
            n_hidden2 = hidden2_neurons; activation2 = tf.nn.sigmoid#tf.nn.elu
            n_outputs = env.action_space.shape[1]**env.action_space.shape[0]
            
            he_init = tf.contrib.layers.variance_scaling_initializer(seed = seed)

            X = tf.placeholder(tf.float32, shape = (None, n_inputs), name = "X")
            
                    
            hidden1 = tf.layers.dense(X, n_hidden1, activation = activation1,
                                     kernel_initializer = he_init)
            hidden2 = tf.layers.dense(hidden1, n_hidden2, activation = activation2,
                                     kernel_initializer = he_init)
            logits = tf.layers.dense(hidden2, n_outputs, name = "logits"
                                     ,kernel_initializer = he_init)
            
            outputs = tf.nn.softmax(logits)
                   
            
with tf.name_scope("action"):
            # 3. Select a random action (where to go) based on the estimated probabilities
            action = tf.multinomial(tf.log(outputs), num_samples = 1)
            test_action = tf.argmax(outputs, axis = 1)
  
            y = tf.reshape(action, [1])
            
with tf.name_scope("loss"):
            xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels = y,logits = logits)
            loss = tf.reduce_mean(xentropy, name = "loss")
            
tf.summary.scalar('average_cross_entropy', loss)


with tf.name_scope("train"):
            # Optimization Op
            optimizer = tf.train.AdamOptimizer(learning_rate)
            
            grads_and_vars = optimizer.compute_gradients(xentropy)
            gradients = [grad for grad, variable in grads_and_vars]
            gradient_placeholders = []
            grads_and_vars_feed = []
            for grad, variable in grads_and_vars:
                gradient_placeholder = tf.placeholder(tf.float32, shape=grad.get_shape())
                gradient_placeholders.append(gradient_placeholder)
                grads_and_vars_feed.append((gradient_placeholder, variable))
            training_op = optimizer.apply_gradients(grads_and_vars_feed)
                        
                                       
merged = tf.summary.merge_all()
init = tf.global_variables_initializer()
file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
        
saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From /home/dsalgador/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %% [markdown]
# # PG Training

# %%
# with tf.Session() as sess:
    
#     #train_writer = tf.summary.FileWriter(logdir + '/pgtrain', sess.graph)
#     if retrain:
#         saver.restore(sess, model_file)
        
#     summary2 = tf.Summary()
#     if not retrain:
#         init.run()
#     time_start = time.time()

#     for iteration in range(n_iterations+1):
#         print("\rIteration: {}".format(iteration), end="")
#         all_rewards = []
#         all_gradients = []
#         for game in range(n_games_per_update):
#             current_rewards = []
#             current_gradients = []
#             obs = env.reset()
#             for step in range(n_max_steps):
#                 action_val, gradients_val = sess.run([action, gradients], feed_dict={X: obs.reshape(1, n_inputs)}) 
#                 #print(action_val)
#                 vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
#                 #print(vect_action)
#                 obs, reward, done, info = env.step(vect_action)
#                 current_rewards.append(reward)
#                 current_gradients.append(gradients_val)                
                
#                 if done:
#                     break
#             all_rewards.append(current_rewards)
#             all_gradients.append(current_gradients)
            
        
#         all_disc_rewards =  [discount_rewards(rewards, discount_rate) for rewards in all_rewards]
#         all_disc_norm_rewards = normalize_rewards(all_disc_rewards)     

#         feed_dict = {}
#         for var_index, gradient_placeholder in enumerate(gradient_placeholders):
#             mean_gradients = np.mean([reward * all_gradients[game_index][step][var_index]
#                                       for game_index, rewards in enumerate(all_disc_norm_rewards)
#                                           for step, reward in enumerate(rewards)], axis=0)
#             feed_dict[gradient_placeholder] = mean_gradients
         
       
#         #tf.summary.scalar('avg_rewards', avg_rewards)
#         #train_writer.add_summary(avg_rewards, iteration)

#         # Summary and info printings     ###################################################################
#         if iteration % info_freq == 0 or iteration % summary_freq == 0:  
            
#             #avg_rewards =np.array([np.mean(np.array(all_rewards)) / n_games_per_update])
#             avg_rewards =np.mean(np.array(all_disc_rewards)) / n_games_per_update
# #             print(avg_rewards)
#             #avg_rewards_list.append(avg_rewards)
#             if iteration % summary_freq == 0:
#                 summary2.value.add(tag='average_reward_per_game', simple_value = avg_rewards)
#                 file_writer.add_summary(summary2, iteration)

#                 feed_dict[X] = obs.reshape(1, n_inputs)
#                 summary = sess.run(merged, feed_dict= feed_dict)

#                 file_writer.add_summary(summary, iteration)
                
#                   # Disc rewards, etc ####
       
#                 with open(rewards_file,'ab') as f:
#                             np.savetxt(f, [np.array([iteration,  avg_rewards])], fmt=("%d",'%.10f'), delimiter=',') 

#             if iteration % info_freq == 0:
#                 time_end = time.time()
#                 print(". Average reward per game: ",  round(avg_rewards, round_reward), 
#                       ", Elapsed time ", round( (time_end-time_start)/60., round_time), " minutes.") 
                
                
#         ###########################################################################      
                
#         if avg_rewards > best_reward:
#                     saver.save(sess, best_model_file)
#                     print("Saved Model with average discounted rewards per game ", avg_rewards)
#                     best_reward = avg_rewards
#                     checks_without_progress = 0
#         else:
#                     checks_without_progress += 1
#                     if checks_without_progress > max_checks_without_progress:
#                         print("Early stopping!")
#                         break
#         ####################################################################################################
#         if iteration % save_iterations == 0:
#                  saver.save(sess, model_file)
        
#         sess.run(training_op, feed_dict=feed_dict)
    
#     #saver.save(sess, model_file + "final")
#     file_writer.flush()
#     file_writer.close()
                 
#     time_end = time.time()
#     print("Simulation finished. Elapsed time ", round( (time_end-time_start)/60., round_time), " minutes.")
# Out:
# Iteration: 0. Average reward per game:  -1.85041 , Elapsed time  0.0  minutes.
# Saved Model with average discounted rewards per game  -1.850409967808983
# Iteration: 20Saved Model with average discounted rewards per game  -1.217137790440639
# Iteration: 40Saved Model with average discounted rewards per game  -0.8213987666554907
# Iteration: 60Saved Model with average discounted rewards per game  -0.7599972542853821
# Iteration: 80Saved Model with average discounted rewards per game  -0.46121556828105925
# Iteration: 100. Average reward per game:  -0.278653 , Elapsed time  0.39  minutes.
# Saved Model with average discounted rewards per game  -0.27865268304164703
# Iteration: 120Saved Model with average discounted rewards per game  -0.26422206983701046
# Iteration: 140Saved Model with average discounted rewards per game  -0.18348144702469418
# Iteration: 160Saved Model with average discounted rewards per game  -0.1357272594474444
# Iteration: 180Saved Model with average discounted rewards per game  -0.11113378716220042
# Iteration: 200. Average reward per game:  -0.084281 , Elapsed time  0.81  minutes.
# Saved Model with average discounted rewards per game  -0.08428085545450957
# Iteration: 220Saved Model with average discounted rewards per game  -0.057619493600865636
# Iteration: 240Saved Model with average discounted rewards per game  -0.05623976138103624
# Iteration: 300. Average reward per game:  -0.047062 , Elapsed time  1.31  minutes.
# Saved Model with average discounted rewards per game  -0.047061797166059155
# Iteration: 340Saved Model with average discounted rewards per game  -0.03335469695072442
# Iteration: 360Saved Model with average discounted rewards per game  -0.02688707667543417
# Iteration: 400. Average reward per game:  -0.105453 , Elapsed time  1.81  minutes.
# Iteration: 500. Average reward per game:  -0.041355 , Elapsed time  2.39  minutes.
# Iteration: 600. Average reward per game:  -0.076036 , Elapsed time  3.07  minutes.
# Iteration: 700. Average reward per game:  -0.03424 , Elapsed time  3.94  minutes.
# Iteration: 740Saved Model with average discounted rewards per game  -0.026425551583462305
# Iteration: 800. Average reward per game:  -0.015104 , Elapsed time  4.68  minutes.
# Saved Model with average discounted rewards per game  -0.015103968880665472
# Iteration: 900. Average reward per game:  -0.062824 , Elapsed time  5.25  minutes.
# Iteration: 1000. Average reward per game:  -0.066623 , Elapsed time  5.93  minutes.
# Iteration: 1100. Average reward per game:  -0.043375 , Elapsed time  6.56  minutes.
# Iteration: 1200. Average reward per game:  -0.049919 , Elapsed time  7.21  minutes.
# Iteration: 1300. Average reward per game:  -0.063432 , Elapsed time  7.85  minutes.
# Iteration: 1400. Average reward per game:  -0.051444 , Elapsed time  8.46  minutes.
# Iteration: 1500. Average reward per game:  -0.034336 , Elapsed time  9.05  minutes.
# Iteration: 1600. Average reward per game:  -0.066355 , Elapsed time  9.68  minutes.
# Iteration: 1700. Average reward per game:  -0.019485 , Elapsed time  10.21  minutes.
# Iteration: 1800. Average reward per game:  -0.021854 , Elapsed time  10.87  minutes.
# Iteration: 1900. Average reward per game:  -0.039796 , Elapsed time  11.39  minutes.
# Iteration: 2000. Average reward per game:  -0.037511 , Elapsed time  12.08  minutes.
# Iteration: 2100. Average reward per game:  -0.029438 , Elapsed time  12.84  minutes.
# Iteration: 2200. Average reward per game:  -0.034369 , Elapsed time  13.51  minutes.
# Iteration: 2300. Average reward per game:  -0.033767 , Elapsed time  14.34  minutes.
# Iteration: 2400. Average reward per game:  -0.0453 , Elapsed time  14.93  minutes.
# Iteration: 2500. Average reward per game:  -0.049861 , Elapsed time  15.62  minutes.
# Iteration: 2600. Average reward per game:  -0.052253 , Elapsed time  16.35  minutes.
# Iteration: 2700. Average reward per game:  -0.019158 , Elapsed time  16.94  minutes.
# Iteration: 2800. Average reward per game:  -0.035086 , Elapsed time  17.69  minutes.
# Iteration: 2900. Average reward per game:  -0.029901 , Elapsed time  18.44  minutes.
# Iteration: 3000. Average reward per game:  -0.057732 , Elapsed time  19.04  minutes.
# Iteration: 3100. Average reward per game:  -0.037825 , Elapsed time  19.79  minutes.
# Iteration: 3200. Average reward per game:  -0.05531 , Elapsed time  20.34  minutes.
# Iteration: 3300. Average reward per game:  -0.048147 , Elapsed time  21.05  minutes.
# Iteration: 3400. Average reward per game:  -0.093726 , Elapsed time  21.66  minutes.
# Iteration: 3500. Average reward per game:  -0.016943 , Elapsed time  22.43  minutes.
# Iteration: 3600. Average reward per game:  -0.044528 , Elapsed time  23.25  minutes.
# Iteration: 3700. Average reward per game:  -0.045389 , Elapsed time  24.07  minutes.
# Iteration: 3800. Average reward per game:  -0.031661 , Elapsed time  24.9  minutes.
# Iteration: 3880Saved Model with average discounted rewards per game  -0.01486146047255248
# Iteration: 3900. Average reward per game:  -0.035669 , Elapsed time  25.46  minutes.
# Iteration: 4000. Average reward per game:  -0.050843 , Elapsed time  26.0  minutes.
# Iteration: 4100. Average reward per game:  -0.053967 , Elapsed time  26.68  minutes.
# Iteration: 4200. Average reward per game:  -0.044259 , Elapsed time  27.5  minutes.
# Iteration: 4300. Average reward per game:  -0.038112 , Elapsed time  28.33  minutes.
# Iteration: 4400. Average reward per game:  -0.025405 , Elapsed time  29.1  minutes.
# Iteration: 4500. Average reward per game:  -0.07478 , Elapsed time  29.7  minutes.
# Iteration: 4600. Average reward per game:  -0.087489 , Elapsed time  30.52  minutes.
# Iteration: 4700. Average reward per game:  -0.052009 , Elapsed time  31.15  minutes.
# Iteration: 4800. Average reward per game:  -0.054098 , Elapsed time  31.9  minutes.
# Iteration: 4900. Average reward per game:  -0.053387 , Elapsed time  32.52  minutes.
# Iteration: 5000. Average reward per game:  -0.012798 , Elapsed time  33.39  minutes.
# Saved Model with average discounted rewards per game  -0.012798348987422884
# Iteration: 5100. Average reward per game:  -0.02109 , Elapsed time  34.16  minutes.
# Iteration: 5200. Average reward per game:  -0.051049 , Elapsed time  34.7  minutes.
# Iteration: 5300. Average reward per game:  -0.038221 , Elapsed time  35.35  minutes.
# Iteration: 5400. Average reward per game:  -0.02582 , Elapsed time  35.96  minutes.
# Iteration: 5500. Average reward per game:  -0.02651 , Elapsed time  36.52  minutes.
# Iteration: 5600. Average reward per game:  -0.076444 , Elapsed time  37.23  minutes.
# Iteration: 5700. Average reward per game:  -0.048815 , Elapsed time  37.89  minutes.
# Iteration: 5800. Average reward per game:  -0.035376 , Elapsed time  38.61  minutes.
# Iteration: 5900. Average reward per game:  -0.05779 , Elapsed time  39.37  minutes.
# Iteration: 6000. Average reward per game:  -0.015183 , Elapsed time  39.96  minutes.
# Iteration: 6100. Average reward per game:  -0.075129 , Elapsed time  40.64  minutes.
# Iteration: 6200. Average reward per game:  -0.08025 , Elapsed time  41.26  minutes.
# Iteration: 6300. Average reward per game:  -0.039457 , Elapsed time  41.79  minutes.
# Iteration: 6400. Average reward per game:  -0.039272 , Elapsed time  42.5  minutes.
# Iteration: 6500. Average reward per game:  -0.031584 , Elapsed time  43.1  minutes.
# Iteration: 6600. Average reward per game:  -0.043619 , Elapsed time  43.89  minutes.
# Iteration: 6700. Average reward per game:  -0.064964 , Elapsed time  44.47  minutes.
# Iteration: 6800. Average reward per game:  -0.037941 , Elapsed time  45.16  minutes.
# Iteration: 6900. Average reward per game:  -0.021513 , Elapsed time  45.8  minutes.
# Iteration: 7000. Average reward per game:  -0.037273 , Elapsed time  46.39  minutes.
# Iteration: 7100. Average reward per game:  -0.044292 , Elapsed time  47.03  minutes.
# Iteration: 7200. Average reward per game:  -0.059644 , Elapsed time  47.56  minutes.
# Iteration: 7300. Average reward per game:  -0.052073 , Elapsed time  48.31  minutes.
# Iteration: 7400. Average reward per game:  -0.043813 , Elapsed time  49.07  minutes.
# Iteration: 7500. Average reward per game:  -0.049885 , Elapsed time  49.56  minutes.
# Iteration: 7600. Average reward per game:  -0.031104 , Elapsed time  50.15  minutes.
# Iteration: 7700. Average reward per game:  -0.013528 , Elapsed time  50.69  minutes.
# Iteration: 7800. Average reward per game:  -0.04086 , Elapsed time  51.2  minutes.
# Iteration: 7900. Average reward per game:  -0.04382 , Elapsed time  51.74  minutes.
# Iteration: 8000. Average reward per game:  -0.033105 , Elapsed time  52.5  minutes.
# Iteration: 8100. Average reward per game:  -0.039136 , Elapsed time  53.12  minutes.
# Iteration: 8200. Average reward per game:  -0.034997 , Elapsed time  53.78  minutes.
# Iteration: 8300. Average reward per game:  -0.04757 , Elapsed time  54.33  minutes.
# Iteration: 8400. Average reward per game:  -0.041109 , Elapsed time  55.0  minutes.
# Iteration: 8500. Average reward per game:  -0.0222 , Elapsed time  55.76  minutes.
# Iteration: 8600. Average reward per game:  -0.022102 , Elapsed time  56.35  minutes.
# Iteration: 8700. Average reward per game:  -0.054249 , Elapsed time  56.93  minutes.
# Iteration: 8800. Average reward per game:  -0.03781 , Elapsed time  57.47  minutes.
# Iteration: 8900. Average reward per game:  -0.062981 , Elapsed time  58.04  minutes.
# Iteration: 9000. Average reward per game:  -0.038581 , Elapsed time  58.79  minutes.
# Iteration: 9100. Average reward per game:  -0.053559 , Elapsed time  59.57  minutes.
# Iteration: 9200. Average reward per game:  -0.032679 , Elapsed time  60.15  minutes.
# Iteration: 9300. Average reward per game:  -0.122646 , Elapsed time  60.9  minutes.
# Iteration: 9400. Average reward per game:  -0.082777 , Elapsed time  61.42  minutes.
# Iteration: 9500. Average reward per game:  -0.051509 , Elapsed time  62.13  minutes.
# Iteration: 9600. Average reward per game:  -0.03668 , Elapsed time  62.78  minutes.
# Iteration: 9700. Average reward per game:  -0.057741 , Elapsed time  63.36  minutes.
# Iteration: 9800. Average reward per game:  -0.053854 , Elapsed time  63.94  minutes.
# Iteration: 9900. Average reward per game:  -0.047277 , Elapsed time  64.48  minutes.
# Iteration: 10000. Average reward per game:  -0.062051 , Elapsed time  65.2  minutes.
# Iteration: 10100. Average reward per game:  -0.090247 , Elapsed time  65.95  minutes.
# Iteration: 10200. Average reward per game:  -0.059074 , Elapsed time  66.5  minutes.
# Iteration: 10300. Average reward per game:  -0.098996 , Elapsed time  67.12  minutes.
# Iteration: 10400. Average reward per game:  -0.036135 , Elapsed time  67.61  minutes.
# Iteration: 10500. Average reward per game:  -0.041912 , Elapsed time  68.22  minutes.
# Iteration: 10600. Average reward per game:  -0.023319 , Elapsed time  68.87  minutes.
# Iteration: 10700. Average reward per game:  -0.035051 , Elapsed time  69.54  minutes.
# Iteration: 10780Saved Model with average discounted rewards per game  -0.008285768951550634
# Iteration: 10800. Average reward per game:  -0.051098 , Elapsed time  70.22  minutes.
# Iteration: 10900. Average reward per game:  -0.032929 , Elapsed time  70.79  minutes.
# Iteration: 11000. Average reward per game:  -0.051026 , Elapsed time  71.35  minutes.
# Iteration: 11100. Average reward per game:  -0.042897 , Elapsed time  71.9  minutes.
# Iteration: 11200. Average reward per game:  -0.013743 , Elapsed time  72.64  minutes.
# Iteration: 11300. Average reward per game:  -0.040755 , Elapsed time  73.23  minutes.
# Iteration: 11400. Average reward per game:  -0.028756 , Elapsed time  73.75  minutes.
# Iteration: 11420Saved Model with average discounted rewards per game  -0.008116782632497026
# Iteration: 11500. Average reward per game:  -0.040218 , Elapsed time  74.4  minutes.
# Iteration: 11600. Average reward per game:  -0.056481 , Elapsed time  75.08  minutes.
# Iteration: 11700. Average reward per game:  -0.024619 , Elapsed time  75.72  minutes.
# Iteration: 11800. Average reward per game:  -0.025406 , Elapsed time  76.33  minutes.
# Iteration: 11900. Average reward per game:  -0.025234 , Elapsed time  76.94  minutes.
# Iteration: 12000. Average reward per game:  -0.049379 , Elapsed time  77.51  minutes.
# Iteration: 12100. Average reward per game:  -0.01501 , Elapsed time  78.16  minutes.
# Iteration: 12200. Average reward per game:  -0.058606 , Elapsed time  78.79  minutes.
# Iteration: 12300. Average reward per game:  -0.03251 , Elapsed time  79.42  minutes.
# Iteration: 12400. Average reward per game:  -0.02946 , Elapsed time  79.96  minutes.
# Iteration: 12500. Average reward per game:  -0.047292 , Elapsed time  80.55  minutes.
# Iteration: 12600. Average reward per game:  -0.047491 , Elapsed time  81.18  minutes.
# Iteration: 12700. Average reward per game:  -0.044169 , Elapsed time  81.76  minutes.
# Iteration: 12800. Average reward per game:  -0.051531 , Elapsed time  82.44  minutes.
# Iteration: 12900. Average reward per game:  -0.062467 , Elapsed time  83.07  minutes.
# Iteration: 13000. Average reward per game:  -0.046333 , Elapsed time  83.58  minutes.
# Iteration: 13100. Average reward per game:  -0.06073 , Elapsed time  84.24  minutes.
# Iteration: 13200. Average reward per game:  -0.079322 , Elapsed time  84.82  minutes.
# Iteration: 13300. Average reward per game:  -0.026038 , Elapsed time  85.54  minutes.
# Iteration: 13400. Average reward per game:  -0.046857 , Elapsed time  86.13  minutes.
# Iteration: 13500. Average reward per game:  -0.021833 , Elapsed time  86.68  minutes.
# Iteration: 13600. Average reward per game:  -0.016676 , Elapsed time  87.34  minutes.
# Iteration: 13700. Average reward per game:  -0.050174 , Elapsed time  87.95  minutes.
# Iteration: 13800. Average reward per game:  -0.031258 , Elapsed time  88.52  minutes.
# Iteration: 13900. Average reward per game:  -0.08854 , Elapsed time  89.06  minutes.
# Iteration: 14000. Average reward per game:  -0.062053 , Elapsed time  89.69  minutes.
# Iteration: 14100. Average reward per game:  -0.051732 , Elapsed time  90.28  minutes.
# Iteration: 14200. Average reward per game:  -0.051767 , Elapsed time  90.94  minutes.
# Iteration: 14300. Average reward per game:  -0.093893 , Elapsed time  91.47  minutes.
# Iteration: 14400. Average reward per game:  -0.032452 , Elapsed time  92.05  minutes.
# Iteration: 14500. Average reward per game:  -0.053812 , Elapsed time  92.84  minutes.
# Iteration: 14600. Average reward per game:  -0.121666 , Elapsed time  93.36  minutes.
# Iteration: 14700. Average reward per game:  -0.022233 , Elapsed time  94.12  minutes.
# Iteration: 14800. Average reward per game:  -0.029383 , Elapsed time  94.81  minutes.
# Iteration: 14900. Average reward per game:  -0.038713 , Elapsed time  95.41  minutes.
# Iteration: 15000. Average reward per game:  -0.030178 , Elapsed time  95.98  minutes.
# Iteration: 15100. Average reward per game:  -0.075857 , Elapsed time  96.69  minutes.
# Iteration: 15200. Average reward per game:  -0.025082 , Elapsed time  97.26  minutes.
# Iteration: 15300. Average reward per game:  -0.035505 , Elapsed time  97.79  minutes.
# Iteration: 15400. Average reward per game:  -0.033229 , Elapsed time  98.48  minutes.
# Iteration: 15500. Average reward per game:  -0.023546 , Elapsed time  99.0  minutes.
# Iteration: 15600. Average reward per game:  -0.028118 , Elapsed time  99.71  minutes.
# Iteration: 15700. Average reward per game:  -0.04806 , Elapsed time  100.3  minutes.
# Iteration: 15800. Average reward per game:  -0.025302 , Elapsed time  101.01  minutes.
# Iteration: 15900. Average reward per game:  -0.022493 , Elapsed time  101.6  minutes.
# Iteration: 16000. Average reward per game:  -0.037456 , Elapsed time  102.32  minutes.
# Iteration: 16100. Average reward per game:  -0.033717 , Elapsed time  102.83  minutes.
# Iteration: 16200. Average reward per game:  -0.035332 , Elapsed time  103.37  minutes.
# Iteration: 16300. Average reward per game:  -0.05304 , Elapsed time  104.07  minutes.
# Iteration: 16400. Average reward per game:  -0.041488 , Elapsed time  104.81  minutes.
# Iteration: 16500. Average reward per game:  -0.029085 , Elapsed time  105.4  minutes.
# Iteration: 16600. Average reward per game:  -0.046678 , Elapsed time  105.97  minutes.
# Iteration: 16700. Average reward per game:  -0.015742 , Elapsed time  106.59  minutes.
# Iteration: 16800. Average reward per game:  -0.050031 , Elapsed time  107.24  minutes.
# Iteration: 16900. Average reward per game:  -0.044428 , Elapsed time  107.82  minutes.
# Iteration: 17000. Average reward per game:  -0.051566 , Elapsed time  108.52  minutes.
# Iteration: 17100. Average reward per game:  -0.028622 , Elapsed time  109.05  minutes.
# Iteration: 17200. Average reward per game:  -0.04532 , Elapsed time  109.68  minutes.
# Iteration: 17300. Average reward per game:  -0.018788 , Elapsed time  110.28  minutes.
# Iteration: 17400. Average reward per game:  -0.05934 , Elapsed time  110.93  minutes.
# Iteration: 17500. Average reward per game:  -0.084613 , Elapsed time  111.55  minutes.
# Iteration: 17600. Average reward per game:  -0.054119 , Elapsed time  112.11  minutes.
# Iteration: 17700. Average reward per game:  -0.022909 , Elapsed time  112.86  minutes.
# Iteration: 17800. Average reward per game:  -0.046849 , Elapsed time  113.42  minutes.
# Iteration: 17900. Average reward per game:  -0.036437 , Elapsed time  114.13  minutes.
# Iteration: 18000. Average reward per game:  -0.077188 , Elapsed time  114.81  minutes.
# Iteration: 18100. Average reward per game:  -0.059989 , Elapsed time  115.33  minutes.
# Iteration: 18200. Average reward per game:  -0.033789 , Elapsed time  115.97  minutes.
# Iteration: 18300. Average reward per game:  -0.04169 , Elapsed time  116.62  minutes.
# Iteration: 18400. Average reward per game:  -0.014828 , Elapsed time  117.32  minutes.
# Iteration: 18500. Average reward per game:  -0.034579 , Elapsed time  118.18  minutes.
# Iteration: 18600. Average reward per game:  -0.045324 , Elapsed time  118.99  minutes.
# Iteration: 18700. Average reward per game:  -0.046794 , Elapsed time  119.57  minutes.
# Iteration: 18800. Average reward per game:  -0.067665 , Elapsed time  120.3  minutes.
# Iteration: 18900. Average reward per game:  -0.052553 , Elapsed time  120.99  minutes.
# Iteration: 19000. Average reward per game:  -0.011088 , Elapsed time  121.54  minutes.
# Iteration: 19100. Average reward per game:  -0.016099 , Elapsed time  122.3  minutes.
# Iteration: 19200. Average reward per game:  -0.02467 , Elapsed time  122.96  minutes.
# Iteration: 19300. Average reward per game:  -0.05841 , Elapsed time  123.5  minutes.
# Iteration: 19400. Average reward per game:  -0.023624 , Elapsed time  124.04  minutes.
# Iteration: 19500. Average reward per game:  -0.031066 , Elapsed time  124.71  minutes.
# Iteration: 19600. Average reward per game:  -0.031179 , Elapsed time  125.52  minutes.
# Iteration: 19700. Average reward per game:  -0.020865 , Elapsed time  126.3  minutes.
# Iteration: 19800. Average reward per game:  -0.068315 , Elapsed time  127.09  minutes.
# Iteration: 19900. Average reward per game:  -0.049869 , Elapsed time  127.95  minutes.
# Iteration: 20000. Average reward per game:  -0.032234 , Elapsed time  128.86  minutes.
# Iteration: 20100. Average reward per game:  -0.027317 , Elapsed time  129.54  minutes.
# Iteration: 20200. Average reward per game:  -0.029522 , Elapsed time  130.2  minutes.
# Iteration: 20300. Average reward per game:  -0.034911 , Elapsed time  130.75  minutes.
# Iteration: 20400. Average reward per game:  -0.06356 , Elapsed time  131.45  minutes.
# Iteration: 20500. Average reward per game:  -0.038979 , Elapsed time  132.09  minutes.
# Iteration: 20600. Average reward per game:  -0.076601 , Elapsed time  132.67  minutes.
# Iteration: 20700. Average reward per game:  -0.0401 , Elapsed time  133.34  minutes.
# Iteration: 20800. Average reward per game:  -0.041626 , Elapsed time  133.83  minutes.
# Iteration: 20900. Average reward per game:  -0.038063 , Elapsed time  134.35  minutes.
# Iteration: 21000. Average reward per game:  -0.024809 , Elapsed time  134.86  minutes.
# Iteration: 21100. Average reward per game:  -0.068256 , Elapsed time  135.39  minutes.
# Iteration: 21200. Average reward per game:  -0.026376 , Elapsed time  136.12  minutes.
# Iteration: 21300. Average reward per game:  -0.024281 , Elapsed time  136.79  minutes.
# Iteration: 21400. Average reward per game:  -0.018477 , Elapsed time  137.34  minutes.
# Iteration: 21500. Average reward per game:  -0.033564 , Elapsed time  137.9  minutes.
# Iteration: 21600. Average reward per game:  -0.030755 , Elapsed time  138.48  minutes.
# Iteration: 21700. Average reward per game:  -0.05604 , Elapsed time  139.1  minutes.
# Iteration: 21800. Average reward per game:  -0.122463 , Elapsed time  139.64  minutes.
# Iteration: 21900. Average reward per game:  -0.031814 , Elapsed time  140.2  minutes.
# Iteration: 22000. Average reward per game:  -0.067086 , Elapsed time  140.75  minutes.
# Iteration: 22100. Average reward per game:  -0.033763 , Elapsed time  141.3  minutes.
# Iteration: 22200. Average reward per game:  -0.044623 , Elapsed time  141.81  minutes.
# Iteration: 22300. Average reward per game:  -0.504499 , Elapsed time  142.34  minutes.
# Iteration: 22400. Average reward per game:  -0.030235 , Elapsed time  142.9  minutes.
# Iteration: 22500. Average reward per game:  -0.04009 , Elapsed time  143.47  minutes.
# Iteration: 22600. Average reward per game:  -0.014585 , Elapsed time  144.02  minutes.
# Iteration: 22700. Average reward per game:  -0.02777 , Elapsed time  144.63  minutes.
# Iteration: 22800. Average reward per game:  -0.014858 , Elapsed time  145.22  minutes.
# Iteration: 22900. Average reward per game:  -0.044545 , Elapsed time  145.77  minutes.
# Iteration: 23000. Average reward per game:  -0.039522 , Elapsed time  146.25  minutes.
# Iteration: 23100. Average reward per game:  -0.052442 , Elapsed time  146.82  minutes.
# Iteration: 23200. Average reward per game:  -0.045054 , Elapsed time  147.39  minutes.
# Iteration: 23300. Average reward per game:  -0.022819 , Elapsed time  147.97  minutes.
# Iteration: 23400. Average reward per game:  -0.023969 , Elapsed time  148.53  minutes.
# Iteration: 23500. Average reward per game:  -0.021055 , Elapsed time  149.1  minutes.
# Iteration: 23600. Average reward per game:  -0.030072 , Elapsed time  149.67  minutes.
# Iteration: 23700. Average reward per game:  -0.03943 , Elapsed time  150.22  minutes.
# Iteration: 23800. Average reward per game:  -0.058636 , Elapsed time  150.77  minutes.
# Iteration: 23900. Average reward per game:  -0.036367 , Elapsed time  151.36  minutes.
# Iteration: 24000. Average reward per game:  -0.080735 , Elapsed time  151.94  minutes.
# Iteration: 24100. Average reward per game:  -0.03246 , Elapsed time  152.51  minutes.
# Iteration: 24200. Average reward per game:  -0.041516 , Elapsed time  153.12  minutes.
# Iteration: 24300. Average reward per game:  -0.022651 , Elapsed time  153.69  minutes.
# Iteration: 24400. Average reward per game:  -0.024646 , Elapsed time  154.26  minutes.
# Iteration: 24500. Average reward per game:  -0.055659 , Elapsed time  154.83  minutes.
# Iteration: 24600. Average reward per game:  -0.035188 , Elapsed time  155.42  minutes.
# Iteration: 24700. Average reward per game:  -0.041253 , Elapsed time  155.98  minutes.
# Iteration: 24800. Average reward per game:  -0.025078 , Elapsed time  156.56  minutes.
# Iteration: 24900. Average reward per game:  -0.039306 , Elapsed time  157.09  minutes.
# Iteration: 25000. Average reward per game:  -0.041356 , Elapsed time  157.7  minutes.
# Iteration: 25100. Average reward per game:  -0.046952 , Elapsed time  158.27  minutes.
# Iteration: 25200. Average reward per game:  -0.042532 , Elapsed time  158.86  minutes.
# Iteration: 25300. Average reward per game:  -0.029604 , Elapsed time  159.46  minutes.
# Iteration: 25400. Average reward per game:  -0.062335 , Elapsed time  160.06  minutes.
# Iteration: 25500. Average reward per game:  -0.027688 , Elapsed time  160.64  minutes.
# Iteration: 25600. Average reward per game:  -0.018734 , Elapsed time  161.22  minutes.
# Iteration: 25700. Average reward per game:  -0.030521 , Elapsed time  161.82  minutes.
# Iteration: 25800. Average reward per game:  -0.017005 , Elapsed time  162.41  minutes.
# Iteration: 25900. Average reward per game:  -0.015526 , Elapsed time  162.97  minutes.
# Iteration: 26000. Average reward per game:  -0.031948 , Elapsed time  163.58  minutes.
# Iteration: 26100. Average reward per game:  -0.053271 , Elapsed time  164.13  minutes.
# Iteration: 26200. Average reward per game:  -0.04799 , Elapsed time  164.69  minutes.
# Iteration: 26300. Average reward per game:  -0.066827 , Elapsed time  165.27  minutes.
# Iteration: 26400. Average reward per game:  -0.022004 , Elapsed time  165.86  minutes.
# Iteration: 26500. Average reward per game:  -0.041753 , Elapsed time  166.44  minutes.
# Iteration: 26600. Average reward per game:  -0.044709 , Elapsed time  166.99  minutes.
# Iteration: 26700. Average reward per game:  -0.023627 , Elapsed time  167.59  minutes.
# Iteration: 26800. Average reward per game:  -0.079458 , Elapsed time  168.16  minutes.
# Iteration: 26900. Average reward per game:  -0.134194 , Elapsed time  168.77  minutes.
# Iteration: 27000. Average reward per game:  -0.014315 , Elapsed time  169.4  minutes.
# Iteration: 27100. Average reward per game:  -0.023836 , Elapsed time  170.04  minutes.
# Iteration: 27200. Average reward per game:  -0.049342 , Elapsed time  170.67  minutes.
# Iteration: 27300. Average reward per game:  -0.047524 , Elapsed time  171.38  minutes.
# Iteration: 27400. Average reward per game:  -0.023807 , Elapsed time  172.05  minutes.
# Iteration: 27500. Average reward per game:  -0.033518 , Elapsed time  172.88  minutes.
# Iteration: 27600. Average reward per game:  -0.073886 , Elapsed time  173.7  minutes.
# Iteration: 27700. Average reward per game:  -0.082005 , Elapsed time  174.42  minutes.
# Iteration: 27800. Average reward per game:  -0.109706 , Elapsed time  175.29  minutes.
# Iteration: 27900. Average reward per game:  -0.060654 , Elapsed time  176.11  minutes.
# Iteration: 28000. Average reward per game:  -0.033572 , Elapsed time  176.98  minutes.
# Iteration: 28100. Average reward per game:  -0.022589 , Elapsed time  177.76  minutes.
# Iteration: 28200. Average reward per game:  -0.057483 , Elapsed time  178.47  minutes.
# Iteration: 28300. Average reward per game:  -0.047432 , Elapsed time  179.13  minutes.
# Iteration: 28400. Average reward per game:  -0.037463 , Elapsed time  179.8  minutes.
# Iteration: 28500. Average reward per game:  -0.045359 , Elapsed time  180.45  minutes.
# Iteration: 28600. Average reward per game:  -0.018428 , Elapsed time  181.11  minutes.
# Iteration: 28700. Average reward per game:  -0.043955 , Elapsed time  181.78  minutes.
# Iteration: 28800. Average reward per game:  -0.037947 , Elapsed time  182.45  minutes.
# Iteration: 28840Saved Model with average discounted rewards per game  -0.00755159098237568
# Iteration: 28900. Average reward per game:  -0.030386 , Elapsed time  183.13  minutes.
# Iteration: 29000. Average reward per game:  -0.062434 , Elapsed time  183.8  minutes.
# Iteration: 29100. Average reward per game:  -0.032201 , Elapsed time  184.56  minutes.
# Iteration: 29200. Average reward per game:  -0.034181 , Elapsed time  185.29  minutes.
# Iteration: 29300. Average reward per game:  -0.047312 , Elapsed time  185.94  minutes.
# Iteration: 29400. Average reward per game:  -0.021656 , Elapsed time  186.59  minutes.
# Iteration: 29500. Average reward per game:  -0.032708 , Elapsed time  187.23  minutes.
# Iteration: 29600. Average reward per game:  -0.032877 , Elapsed time  187.91  minutes.
# Iteration: 29700. Average reward per game:  -0.040766 , Elapsed time  188.6  minutes.
# Iteration: 29800. Average reward per game:  -0.048908 , Elapsed time  189.36  minutes.
# Iteration: 29900. Average reward per game:  -0.042669 , Elapsed time  190.08  minutes.
# Iteration: 30000. Average reward per game:  -0.034182 , Elapsed time  190.92  minutes.
# Iteration: 30100. Average reward per game:  -0.039229 , Elapsed time  191.77  minutes.
# Iteration: 30200. Average reward per game:  -0.039467 , Elapsed time  192.49  minutes.
# Iteration: 30300. Average reward per game:  -0.042892 , Elapsed time  193.29  minutes.
# Iteration: 30400. Average reward per game:  -0.040641 , Elapsed time  194.08  minutes.
# Iteration: 30500. Average reward per game:  -0.027059 , Elapsed time  194.88  minutes.
# Iteration: 30600. Average reward per game:  -0.035341 , Elapsed time  195.68  minutes.
# Iteration: 30700. Average reward per game:  -0.08528 , Elapsed time  196.38  minutes.
# Iteration: 30800. Average reward per game:  -0.049726 , Elapsed time  197.13  minutes.
# Iteration: 30900. Average reward per game:  -0.041413 , Elapsed time  197.86  minutes.
# Iteration: 31000. Average reward per game:  -0.046933 , Elapsed time  198.56  minutes.
# Iteration: 31100. Average reward per game:  -0.042887 , Elapsed time  199.3  minutes.
# Iteration: 31200. Average reward per game:  -0.069048 , Elapsed time  200.13  minutes.
# Iteration: 31300. Average reward per game:  -0.107342 , Elapsed time  200.94  minutes.
# Iteration: 31400. Average reward per game:  -0.090952 , Elapsed time  201.7  minutes.
# Iteration: 31500. Average reward per game:  -0.035537 , Elapsed time  202.44  minutes.
# Iteration: 31600. Average reward per game:  -0.039858 , Elapsed time  203.15  minutes.
# Iteration: 31700. Average reward per game:  -0.031515 , Elapsed time  203.81  minutes.
# Iteration: 31800. Average reward per game:  -0.05107 , Elapsed time  204.47  minutes.
# Iteration: 31900. Average reward per game:  -0.029376 , Elapsed time  205.18  minutes.
# Iteration: 32000. Average reward per game:  -0.067564 , Elapsed time  206.0  minutes.
# Iteration: 32100. Average reward per game:  -0.032579 , Elapsed time  206.7  minutes.
# Iteration: 32200. Average reward per game:  -0.032355 , Elapsed time  207.45  minutes.
# Iteration: 32300. Average reward per game:  -0.026757 , Elapsed time  208.14  minutes.
# Iteration: 32400. Average reward per game:  -0.027026 , Elapsed time  208.8  minutes.
# Iteration: 32500. Average reward per game:  -0.036756 , Elapsed time  209.47  minutes.
# Iteration: 32600. Average reward per game:  -0.019548 , Elapsed time  210.16  minutes.
# Iteration: 32700. Average reward per game:  -0.05579 , Elapsed time  210.91  minutes.
# Iteration: 32800. Average reward per game:  -0.017868 , Elapsed time  211.79  minutes.
# Iteration: 32900. Average reward per game:  -0.0352 , Elapsed time  212.64  minutes.
# Iteration: 33000. Average reward per game:  -0.062679 , Elapsed time  213.45  minutes.
# Iteration: 33100. Average reward per game:  -0.043124 , Elapsed time  214.21  minutes.
# Iteration: 33200. Average reward per game:  -0.033948 , Elapsed time  215.02  minutes.
# Iteration: 33300. Average reward per game:  -0.037851 , Elapsed time  215.8  minutes.
# Iteration: 33400. Average reward per game:  -0.024166 , Elapsed time  216.55  minutes.
# Iteration: 33500. Average reward per game:  -0.019214 , Elapsed time  217.31  minutes.
# Iteration: 33600. Average reward per game:  -0.026357 , Elapsed time  218.1  minutes.
# Iteration: 33700. Average reward per game:  -0.036107 , Elapsed time  218.79  minutes.
# Iteration: 33800. Average reward per game:  -0.047149 , Elapsed time  219.49  minutes.
# Iteration: 33900. Average reward per game:  -0.056534 , Elapsed time  220.15  minutes.
# Iteration: 34000. Average reward per game:  -0.032184 , Elapsed time  220.84  minutes.
# Iteration: 34100. Average reward per game:  -0.038925 , Elapsed time  221.45  minutes.
# Iteration: 34200. Average reward per game:  -0.059656 , Elapsed time  222.04  minutes.
# Iteration: 34300. Average reward per game:  -0.036646 , Elapsed time  222.65  minutes.
# Iteration: 34400. Average reward per game:  -0.053624 , Elapsed time  223.27  minutes.
# Iteration: 34500. Average reward per game:  -0.022916 , Elapsed time  223.88  minutes.
# Iteration: 34600. Average reward per game:  -0.037609 , Elapsed time  224.45  minutes.
# Iteration: 34700. Average reward per game:  -0.052738 , Elapsed time  225.01  minutes.
# Iteration: 34800. Average reward per game:  -0.037467 , Elapsed time  225.61  minutes.
# Iteration: 34900. Average reward per game:  -0.03252 , Elapsed time  226.21  minutes.
# Iteration: 35000. Average reward per game:  -0.047457 , Elapsed time  226.82  minutes.
# Iteration: 35100. Average reward per game:  -0.042598 , Elapsed time  227.44  minutes.
# Iteration: 35200. Average reward per game:  -0.067421 , Elapsed time  228.11  minutes.
# Iteration: 35300. Average reward per game:  -0.050204 , Elapsed time  228.73  minutes.
# Iteration: 35400. Average reward per game:  -0.04588 , Elapsed time  229.31  minutes.
# Iteration: 35500. Average reward per game:  -0.043682 , Elapsed time  229.91  minutes.
# Iteration: 35600. Average reward per game:  -0.068912 , Elapsed time  230.51  minutes.
# Iteration: 35700. Average reward per game:  -0.023688 , Elapsed time  231.09  minutes.
# Iteration: 35800. Average reward per game:  -0.029827 , Elapsed time  231.71  minutes.
# Iteration: 35900. Average reward per game:  -0.037751 , Elapsed time  232.28  minutes.
# Iteration: 36000. Average reward per game:  -0.01532 , Elapsed time  232.92  minutes.
# Iteration: 36100. Average reward per game:  -0.045989 , Elapsed time  233.52  minutes.
# Iteration: 36200. Average reward per game:  -0.021993 , Elapsed time  234.2  minutes.
# Iteration: 36300. Average reward per game:  -0.043762 , Elapsed time  234.79  minutes.
# Iteration: 36400. Average reward per game:  -0.073287 , Elapsed time  235.37  minutes.
# Iteration: 36500. Average reward per game:  -0.043178 , Elapsed time  236.0  minutes.
# Iteration: 36600. Average reward per game:  -0.032986 , Elapsed time  236.63  minutes.
# Iteration: 36700. Average reward per game:  -0.036143 , Elapsed time  237.3  minutes.
# Iteration: 36800. Average reward per game:  -0.031805 , Elapsed time  237.97  minutes.
# Iteration: 36900. Average reward per game:  -0.039491 , Elapsed time  238.68  minutes.
# Iteration: 37000. Average reward per game:  -0.039317 , Elapsed time  239.31  minutes.
# Iteration: 37100. Average reward per game:  -0.013379 , Elapsed time  239.98  minutes.
# Iteration: 37200. Average reward per game:  -0.028755 , Elapsed time  240.69  minutes.
# Iteration: 37300. Average reward per game:  -0.054639 , Elapsed time  241.38  minutes.
# Iteration: 37400. Average reward per game:  -0.023979 , Elapsed time  242.05  minutes.
# Iteration: 37500. Average reward per game:  -0.021507 , Elapsed time  242.7  minutes.
# Iteration: 37600. Average reward per game:  -0.049554 , Elapsed time  243.36  minutes.
# Iteration: 37700. Average reward per game:  -0.036486 , Elapsed time  244.03  minutes.
# Iteration: 37800. Average reward per game:  -0.018194 , Elapsed time  244.66  minutes.
# Iteration: 37900. Average reward per game:  -0.017394 , Elapsed time  245.27  minutes.
# Iteration: 38000. Average reward per game:  -0.040242 , Elapsed time  245.88  minutes.
# Iteration: 38100. Average reward per game:  -0.043366 , Elapsed time  246.58  minutes.
# Iteration: 38200. Average reward per game:  -0.078955 , Elapsed time  247.2  minutes.
# Iteration: 38300. Average reward per game:  -0.065422 , Elapsed time  247.84  minutes.
# Iteration: 38400. Average reward per game:  -0.050029 , Elapsed time  248.44  minutes.
# Iteration: 38500. Average reward per game:  -0.022839 , Elapsed time  249.0  minutes.
# Iteration: 38600. Average reward per game:  -0.038751 , Elapsed time  249.65  minutes.
# Iteration: 38700. Average reward per game:  -0.052618 , Elapsed time  250.33  minutes.
# Iteration: 38800. Average reward per game:  -0.052467 , Elapsed time  251.0  minutes.
# Iteration: 38900. Average reward per game:  -0.058448 , Elapsed time  251.67  minutes.
# Iteration: 39000. Average reward per game:  -0.08362 , Elapsed time  252.32  minutes.
# Iteration: 39100. Average reward per game:  -0.058449 , Elapsed time  252.98  minutes.
# Iteration: 39200. Average reward per game:  -0.043361 , Elapsed time  253.65  minutes.
# Iteration: 39300. Average reward per game:  -0.038233 , Elapsed time  254.29  minutes.
# Iteration: 39400. Average reward per game:  -0.01184 , Elapsed time  254.95  minutes.
# Iteration: 39500. Average reward per game:  -0.030223 , Elapsed time  255.66  minutes.
# Iteration: 39600. Average reward per game:  -0.055565 , Elapsed time  256.4  minutes.
# Iteration: 39700. Average reward per game:  -0.052932 , Elapsed time  257.07  minutes.
# Iteration: 39800. Average reward per game:  -0.024257 , Elapsed time  257.69  minutes.
# Iteration: 39900. Average reward per game:  -0.023534 , Elapsed time  258.31  minutes.
# Iteration: 40000. Average reward per game:  -0.029673 , Elapsed time  258.92  minutes.
# Iteration: 40100. Average reward per game:  -0.027751 , Elapsed time  259.5  minutes.
# Iteration: 40200. Average reward per game:  -0.04399 , Elapsed time  260.15  minutes.
# Iteration: 40300. Average reward per game:  -0.015642 , Elapsed time  260.77  minutes.
# Iteration: 40400. Average reward per game:  -0.044697 , Elapsed time  261.37  minutes.
# Iteration: 40500. Average reward per game:  -0.039102 , Elapsed time  261.97  minutes.
# Iteration: 40600. Average reward per game:  -0.025202 , Elapsed time  262.55  minutes.
# Iteration: 40700. Average reward per game:  -0.024445 , Elapsed time  263.16  minutes.
# Iteration: 40800. Average reward per game:  -0.019354 , Elapsed time  341.97  minutes.
# Iteration: 40900. Average reward per game:  -0.035124 , Elapsed time  342.42  minutes.
# Iteration: 41000. Average reward per game:  -0.017321 , Elapsed time  342.86  minutes.
# Iteration: 41100. Average reward per game:  -0.061207 , Elapsed time  343.31  minutes.
# Iteration: 41200. Average reward per game:  -0.045331 , Elapsed time  343.85  minutes.
# Iteration: 41300. Average reward per game:  -0.019802 , Elapsed time  344.41  minutes.
# Iteration: 41400. Average reward per game:  -0.032851 , Elapsed time  344.97  minutes.
# Iteration: 41500. Average reward per game:  -0.028667 , Elapsed time  345.54  minutes.
# Iteration: 41600. Average reward per game:  -0.020721 , Elapsed time  346.09  minutes.
# Iteration: 41700. Average reward per game:  -0.042289 , Elapsed time  346.66  minutes.
# Iteration: 41800. Average reward per game:  -0.040623 , Elapsed time  347.21  minutes.
# Iteration: 41900. Average reward per game:  -0.045378 , Elapsed time  347.77  minutes.
# Iteration: 42000. Average reward per game:  -0.02295 , Elapsed time  348.33  minutes.
# Iteration: 42100. Average reward per game:  -0.014645 , Elapsed time  348.93  minutes.
# Iteration: 42200. Average reward per game:  -0.021956 , Elapsed time  349.48  minutes.
# Iteration: 42300. Average reward per game:  -0.020631 , Elapsed time  350.05  minutes.
# Iteration: 42400. Average reward per game:  -0.027937 , Elapsed time  350.68  minutes.
# Iteration: 42500. Average reward per game:  -0.026476 , Elapsed time  351.28  minutes.
# Iteration: 42600. Average reward per game:  -0.043617 , Elapsed time  351.87  minutes.
# Iteration: 42700. Average reward per game:  -0.056806 , Elapsed time  352.49  minutes.
# Iteration: 42800. Average reward per game:  -0.032667 , Elapsed time  353.05  minutes.
# Iteration: 42900. Average reward per game:  -0.044585 , Elapsed time  353.77  minutes.
# Iteration: 43000. Average reward per game:  -0.019751 , Elapsed time  354.3  minutes.
# Iteration: 43100. Average reward per game:  -0.014483 , Elapsed time  355.02  minutes.
# Iteration: 43200. Average reward per game:  -0.014179 , Elapsed time  355.51  minutes.
# Iteration: 43300. Average reward per game:  -0.026 , Elapsed time  356.09  minutes.
# Iteration: 43400. Average reward per game:  -0.057461 , Elapsed time  356.86  minutes.
# Iteration: 43500. Average reward per game:  -0.050842 , Elapsed time  357.38  minutes.
# Iteration: 43600. Average reward per game:  -0.041683 , Elapsed time  357.91  minutes.
# Iteration: 43700. Average reward per game:  -0.052514 , Elapsed time  358.55  minutes.
# Iteration: 43800. Average reward per game:  -0.021241 , Elapsed time  359.2  minutes.
# Iteration: 43900. Average reward per game:  -0.055687 , Elapsed time  359.85  minutes.
# Iteration: 44000. Average reward per game:  -0.044651 , Elapsed time  360.47  minutes.
# Iteration: 44100. Average reward per game:  -0.04501 , Elapsed time  361.07  minutes.
# Iteration: 44200. Average reward per game:  -0.036158 , Elapsed time  361.69  minutes.
# Iteration: 44300. Average reward per game:  -0.029528 , Elapsed time  362.54  minutes.
# Iteration: 44400. Average reward per game:  -0.046089 , Elapsed time  363.07  minutes.
# Iteration: 44500. Average reward per game:  -0.035853 , Elapsed time  363.69  minutes.
# Iteration: 44600. Average reward per game:  -0.018081 , Elapsed time  364.55  minutes.
# Iteration: 44700. Average reward per game:  -0.037005 , Elapsed time  365.16  minutes.
# Iteration: 44800. Average reward per game:  -0.032764 , Elapsed time  365.86  minutes.
# Iteration: 44900. Average reward per game:  -0.024025 , Elapsed time  366.44  minutes.
# Iteration: 45000. Average reward per game:  -0.020676 , Elapsed time  367.25  minutes.
# Iteration: 45060Saved Model with average discounted rewards per game  -0.004146978734855898
# Iteration: 45100. Average reward per game:  -0.053359 , Elapsed time  367.87  minutes.
# Iteration: 45200. Average reward per game:  -0.037089 , Elapsed time  368.59  minutes.
# Iteration: 45300. Average reward per game:  -0.034207 , Elapsed time  369.27  minutes.
# Iteration: 45400. Average reward per game:  -0.045442 , Elapsed time  369.88  minutes.
# Iteration: 45500. Average reward per game:  -0.026011 , Elapsed time  370.53  minutes.
# Iteration: 45600. Average reward per game:  -0.051411 , Elapsed time  371.1  minutes.
# Iteration: 45700. Average reward per game:  -0.033492 , Elapsed time  371.78  minutes.
# Iteration: 45800. Average reward per game:  -0.043047 , Elapsed time  372.5  minutes.
# Iteration: 45900. Average reward per game:  -0.018232 , Elapsed time  373.11  minutes.
# Iteration: 46000. Average reward per game:  -0.053803 , Elapsed time  373.78  minutes.
# Iteration: 46100. Average reward per game:  -0.059407 , Elapsed time  374.5  minutes.
# Iteration: 46200. Average reward per game:  -0.048437 , Elapsed time  375.11  minutes.
# Iteration: 46300. Average reward per game:  -0.042264 , Elapsed time  375.65  minutes.
# Iteration: 46400. Average reward per game:  -0.038371 , Elapsed time  376.19  minutes.
# Iteration: 46500. Average reward per game:  -0.033533 , Elapsed time  376.93  minutes.
# Iteration: 46600. Average reward per game:  -0.03637 , Elapsed time  377.71  minutes.
# Iteration: 46700. Average reward per game:  -0.053265 , Elapsed time  378.28  minutes.
# Iteration: 46800. Average reward per game:  -0.063085 , Elapsed time  378.99  minutes.
# Iteration: 46900. Average reward per game:  -0.025244 , Elapsed time  379.63  minutes.
# Iteration: 47000. Average reward per game:  -0.060592 , Elapsed time  380.35  minutes.
# Iteration: 47100. Average reward per game:  -0.023652 , Elapsed time  380.92  minutes.
# Iteration: 47200. Average reward per game:  -0.032724 , Elapsed time  381.65  minutes.
# Iteration: 47300. Average reward per game:  -0.095665 , Elapsed time  382.42  minutes.
# Iteration: 47400. Average reward per game:  -0.031051 , Elapsed time  383.01  minutes.
# Iteration: 47500. Average reward per game:  -0.04219 , Elapsed time  383.63  minutes.
# Iteration: 47600. Average reward per game:  -0.030949 , Elapsed time  384.35  minutes.
# Iteration: 47700. Average reward per game:  -0.051266 , Elapsed time  385.07  minutes.
# Iteration: 47800. Average reward per game:  -0.00913 , Elapsed time  385.73  minutes.
# Iteration: 47900. Average reward per game:  -0.057586 , Elapsed time  386.33  minutes.
# Iteration: 48000. Average reward per game:  -0.035945 , Elapsed time  387.08  minutes.
# Iteration: 48100. Average reward per game:  -0.052715 , Elapsed time  387.7  minutes.
# Iteration: 48200. Average reward per game:  -0.044906 , Elapsed time  388.49  minutes.
# Iteration: 48300. Average reward per game:  -0.046002 , Elapsed time  389.1  minutes.
# Iteration: 48400. Average reward per game:  -0.051078 , Elapsed time  389.76  minutes.
# Iteration: 48500. Average reward per game:  -0.04026 , Elapsed time  390.43  minutes.
# Iteration: 48600. Average reward per game:  -0.026249 , Elapsed time  391.22  minutes.
# Iteration: 48700. Average reward per game:  -0.027254 , Elapsed time  391.8  minutes.
# Iteration: 48800. Average reward per game:  -0.020283 , Elapsed time  392.53  minutes.
# Iteration: 48900. Average reward per game:  -0.037255 , Elapsed time  393.22  minutes.
# Iteration: 49000. Average reward per game:  -0.028587 , Elapsed time  393.87  minutes.
# Iteration: 49100. Average reward per game:  -0.068189 , Elapsed time  394.55  minutes.
# Iteration: 49200. Average reward per game:  -0.040811 , Elapsed time  395.25  minutes.
# Iteration: 49300. Average reward per game:  -0.023294 , Elapsed time  395.86  minutes.
# Iteration: 49400. Average reward per game:  -0.030449 , Elapsed time  396.49  minutes.
# Iteration: 49500. Average reward per game:  -0.07179 , Elapsed time  397.22  minutes.
# Iteration: 49600. Average reward per game:  -0.018213 , Elapsed time  397.84  minutes.
# Iteration: 49700. Average reward per game:  -0.053624 , Elapsed time  398.62  minutes.
# Iteration: 49800. Average reward per game:  -0.029226 , Elapsed time  399.21  minutes.
# Iteration: 49900. Average reward per game:  -0.022564 , Elapsed time  399.84  minutes.
# Iteration: 50000. Average reward per game:  -0.039077 , Elapsed time  400.57  minutes.
# Iteration: 50100. Average reward per game:  -0.059739 , Elapsed time  401.1  minutes.
# Iteration: 50200. Average reward per game:  -0.064479 , Elapsed time  401.77  minutes.
# Iteration: 50300. Average reward per game:  -0.037429 , Elapsed time  402.49  minutes.
# Iteration: 50400. Average reward per game:  -0.02815 , Elapsed time  403.15  minutes.
# Iteration: 50500. Average reward per game:  -0.027199 , Elapsed time  403.94  minutes.
# Iteration: 50600. Average reward per game:  -0.0208 , Elapsed time  404.53  minutes.
# Iteration: 50700. Average reward per game:  -0.017236 , Elapsed time  405.32  minutes.
# Iteration: 50800. Average reward per game:  -0.048485 , Elapsed time  405.87  minutes.
# Iteration: 50900. Average reward per game:  -0.031301 , Elapsed time  406.65  minutes.
# Iteration: 51000. Average reward per game:  -0.015161 , Elapsed time  407.35  minutes.
# Iteration: 51100. Average reward per game:  -0.049048 , Elapsed time  408.02  minutes.
# Iteration: 51200. Average reward per game:  -0.053554 , Elapsed time  408.77  minutes.
# Iteration: 51300. Average reward per game:  -0.03037 , Elapsed time  409.33  minutes.
# Iteration: 51400. Average reward per game:  -0.017699 , Elapsed time  409.94  minutes.
# Iteration: 51500. Average reward per game:  -0.008694 , Elapsed time  410.54  minutes.
# Iteration: 51600. Average reward per game:  -0.065282 , Elapsed time  411.33  minutes.
# Iteration: 51700. Average reward per game:  -0.029506 , Elapsed time  412.01  minutes.
# Iteration: 51800. Average reward per game:  -0.04144 , Elapsed time  412.73  minutes.
# Iteration: 51900. Average reward per game:  -0.057802 , Elapsed time  413.52  minutes.
# Iteration: 52000. Average reward per game:  -0.032201 , Elapsed time  414.23  minutes.
# Iteration: 52100. Average reward per game:  -0.032936 , Elapsed time  414.79  minutes.
# Iteration: 52200. Average reward per game:  -0.030063 , Elapsed time  415.57  minutes.
# Iteration: 52300. Average reward per game:  -0.046517 , Elapsed time  416.36  minutes.
# Iteration: 52400. Average reward per game:  -0.048605 , Elapsed time  416.95  minutes.
# Iteration: 52500. Average reward per game:  -0.024291 , Elapsed time  417.73  minutes.
# Iteration: 52600. Average reward per game:  -0.031129 , Elapsed time  418.37  minutes.
# Iteration: 52700. Average reward per game:  -0.020492 , Elapsed time  419.13  minutes.
# Iteration: 52800. Average reward per game:  -0.028977 , Elapsed time  419.76  minutes.
# Iteration: 52900. Average reward per game:  -0.056183 , Elapsed time  420.54  minutes.
# Iteration: 53000. Average reward per game:  -0.048 , Elapsed time  421.15  minutes.
# Iteration: 53100. Average reward per game:  -0.02821 , Elapsed time  421.94  minutes.
# ...
# Iteration: 81800. Average reward per game:  -0.025818 , Elapsed time  636.48  minutes.
# Iteration: 81900. Average reward per game:  -0.06237 , Elapsed time  637.12  minutes.
# Iteration: 82000. Average reward per game:  -0.039184 , Elapsed time  637.69  minutes.
# Iteration: 82100. Average reward per game:  -0.028639 , Elapsed time  638.46  minutes.
# Iteration: 82200. Average reward per game:  -0.045094 , Elapsed time  639.23  minutes.
# Iteration: 82300. Average reward per game:  -0.023083 , Elapsed time  639.82  minutes.
# Iteration: 82400. Average reward per game:  -0.035947 , Elapsed time  640.61  minutes.
# Iteration: 82500. Average reward per game:  -0.038936 , Elapsed time  641.16  minutes.
# Iteration: 82600. Average reward per game:  -0.03652 , Elapsed time  641.84  minutes.
# Iteration: 82700. Average reward per game:  -0.026564 , Elapsed time  642.63  minutes.
# Iteration: 82800. Average reward per game:  -0.041923 , Elapsed time  643.46  minutes.
# Iteration: 82900. Average reward per game:  -0.027751 , Elapsed time  644.3  minutes.
# Iteration: 83000. Average reward per game:  -0.016339 , Elapsed time  645.14  minutes.
# Iteration: 83100. Average reward per game:  -0.029741 , Elapsed time  645.98  minutes.
# Iteration: 83200. Average reward per game:  -0.022976 , Elapsed time  646.83  minutes.
# Iteration: 83300. Average reward per game:  -0.044481 , Elapsed time  647.61  minutes.
# Iteration: 83400. Average reward per game:  -0.060371 , Elapsed time  648.43  minutes.
# Iteration: 83500. Average reward per game:  -0.04861 , Elapsed time  649.25  minutes.
# Iteration: 83600. Average reward per game:  -0.050308 , Elapsed time  650.04  minutes.
# Iteration: 83700. Average reward per game:  -0.04435 , Elapsed time  650.87  minutes.
# Iteration: 83800. Average reward per game:  -0.06883 , Elapsed time  651.71  minutes.
# Iteration: 83900. Average reward per game:  -0.087631 , Elapsed time  652.56  minutes.
# Iteration: 84000. Average reward per game:  -0.07288 , Elapsed time  653.4  minutes.
# Iteration: 84100. Average reward per game:  -0.079863 , Elapsed time  654.22  minutes.
# Iteration: 84200. Average reward per game:  -0.080837 , Elapsed time  655.07  minutes.
# Iteration: 84300. Average reward per game:  -0.035102 , Elapsed time  655.91  minutes.
# Iteration: 84400. Average reward per game:  -0.042631 , Elapsed time  656.75  minutes.
# Iteration: 84500. Average reward per game:  -0.051752 , Elapsed time  657.59  minutes.
# Iteration: 84600. Average reward per game:  -0.058719 , Elapsed time  658.41  minutes.
# Iteration: 84700. Average reward per game:  -0.025881 , Elapsed time  659.19  minutes.
# Iteration: 84800. Average reward per game:  -0.025719 , Elapsed time  659.98  minutes.
# Iteration: 84900. Average reward per game:  -0.078466 , Elapsed time  660.82  minutes.
# Iteration: 85000. Average reward per game:  -0.026583 , Elapsed time  661.65  minutes.
# Iteration: 85100. Average reward per game:  -0.060679 , Elapsed time  662.49  minutes.
# Iteration: 85200. Average reward per game:  -0.030502 , Elapsed time  663.33  minutes.
# Iteration: 85300. Average reward per game:  -0.033854 , Elapsed time  664.17  minutes.
# Iteration: 85400. Average reward per game:  -0.039634 , Elapsed time  665.02  minutes.
# Iteration: 85500. Average reward per game:  -0.113375 , Elapsed time  665.88  minutes.
# Iteration: 85600. Average reward per game:  -0.10668 , Elapsed time  666.75  minutes.
# Iteration: 85700. Average reward per game:  -0.067989 , Elapsed time  667.62  minutes.
# Iteration: 85800. Average reward per game:  -0.025024 , Elapsed time  668.41  minutes.
# Iteration: 85900. Average reward per game:  -0.055209 , Elapsed time  669.19  minutes.
# Iteration: 86000. Average reward per game:  -0.065175 , Elapsed time  669.97  minutes.
# Iteration: 86100. Average reward per game:  -0.104136 , Elapsed time  670.82  minutes.
# Iteration: 86200. Average reward per game:  -0.146898 , Elapsed time  671.66  minutes.
# Iteration: 86300. Average reward per game:  -0.08864 , Elapsed time  672.51  minutes.
# Iteration: 86400. Average reward per game:  -0.089947 , Elapsed time  673.3  minutes.
# Iteration: 86500. Average reward per game:  -0.058804 , Elapsed time  674.02  minutes.
# Iteration: 86600. Average reward per game:  -0.050246 , Elapsed time  674.7  minutes.
# Iteration: 86700. Average reward per game:  -0.040111 , Elapsed time  675.29  minutes.
# Iteration: 86800. Average reward per game:  -0.05428 , Elapsed time  675.98  minutes.
# Iteration: 86900. Average reward per game:  -0.030828 , Elapsed time  676.64  minutes.
# Iteration: 87000. Average reward per game:  -0.078023 , Elapsed time  677.26  minutes.
# Iteration: 87100. Average reward per game:  -0.070024 , Elapsed time  677.97  minutes.
# Iteration: 87200. Average reward per game:  -0.081287 , Elapsed time  678.62  minutes.
# Iteration: 87300. Average reward per game:  -0.081429 , Elapsed time  679.47  minutes.
# Iteration: 87400. Average reward per game:  -0.090274 , Elapsed time  680.08  minutes.
# Iteration: 87500. Average reward per game:  -0.023337 , Elapsed time  680.93  minutes.
# Iteration: 87600. Average reward per game:  -0.048394 , Elapsed time  681.78  minutes.
# Iteration: 87700. Average reward per game:  -0.022208 , Elapsed time  682.63  minutes.
# Iteration: 87800. Average reward per game:  -0.023728 , Elapsed time  683.47  minutes.
# Iteration: 87900. Average reward per game:  -0.028867 , Elapsed time  684.32  minutes.
# Iteration: 88000. Average reward per game:  -0.013908 , Elapsed time  685.16  minutes.
# Iteration: 88100. Average reward per game:  -0.038717 , Elapsed time  686.0  minutes.
# Iteration: 88200. Average reward per game:  -0.057414 , Elapsed time  686.84  minutes.
# Iteration: 88300. Average reward per game:  -0.046811 , Elapsed time  687.69  minutes.
# Iteration: 88400. Average reward per game:  -0.061456 , Elapsed time  688.53  minutes.
# Iteration: 88500. Average reward per game:  -0.033714 , Elapsed time  689.36  minutes.
# Iteration: 88600. Average reward per game:  -0.034627 , Elapsed time  690.2  minutes.
# Iteration: 88700. Average reward per game:  -0.026697 , Elapsed time  691.05  minutes.
# Iteration: 88800. Average reward per game:  -0.027739 , Elapsed time  691.89  minutes.
# Iteration: 88900. Average reward per game:  -0.03119 , Elapsed time  692.72  minutes.
# Iteration: 89000. Average reward per game:  -0.043974 , Elapsed time  693.58  minutes.
# Iteration: 89100. Average reward per game:  -0.043076 , Elapsed time  694.42  minutes.
# Iteration: 89200. Average reward per game:  -0.052817 , Elapsed time  695.26  minutes.
# Iteration: 89300. Average reward per game:  -0.049914 , Elapsed time  696.11  minutes.
# Iteration: 89400. Average reward per game:  -0.09015 , Elapsed time  696.96  minutes.
# Iteration: 89500. Average reward per game:  -0.039991 , Elapsed time  697.8  minutes.
# Iteration: 89600. Average reward per game:  -0.054646 , Elapsed time  698.66  minutes.
# Iteration: 89700. Average reward per game:  -0.06177 , Elapsed time  699.5  minutes.
# Iteration: 89800. Average reward per game:  -0.038363 , Elapsed time  700.3  minutes.
# Iteration: 89900. Average reward per game:  -0.081878 , Elapsed time  701.02  minutes.
# Iteration: 90000. Average reward per game:  -0.030592 , Elapsed time  701.7  minutes.
# Iteration: 90100. Average reward per game:  -0.046747 , Elapsed time  702.32  minutes.
# Iteration: 90200. Average reward per game:  -0.046275 , Elapsed time  702.98  minutes.
# Iteration: 90300. Average reward per game:  -0.047424 , Elapsed time  703.67  minutes.
# Iteration: 90400. Average reward per game:  -0.04139 , Elapsed time  704.28  minutes.
# Iteration: 90500. Average reward per game:  -0.039169 , Elapsed time  704.96  minutes.
# Iteration: 90600. Average reward per game:  -0.043232 , Elapsed time  705.55  minutes.
# Iteration: 90700. Average reward per game:  -0.022957 , Elapsed time  706.21  minutes.
# Iteration: 90800. Average reward per game:  -0.02881 , Elapsed time  706.9  minutes.
# Iteration: 90900. Average reward per game:  -0.028798 , Elapsed time  707.45  minutes.
# Iteration: 91000. Average reward per game:  -0.029086 , Elapsed time  708.19  minutes.
# Iteration: 91100. Average reward per game:  -0.022083 , Elapsed time  708.8  minutes.
# Iteration: 91200. Average reward per game:  -0.022325 , Elapsed time  709.52  minutes.
# Iteration: 91300. Average reward per game:  -0.019879 , Elapsed time  710.17  minutes.
# Iteration: 91400. Average reward per game:  -0.030193 , Elapsed time  710.8  minutes.
# Iteration: 91500. Average reward per game:  -0.07612 , Elapsed time  711.44  minutes.
# Iteration: 91600. Average reward per game:  -0.084403 , Elapsed time  712.15  minutes.
# Iteration: 91700. Average reward per game:  -0.119026 , Elapsed time  712.7  minutes.
# Iteration: 91800. Average reward per game:  -0.086742 , Elapsed time  713.47  minutes.
# Iteration: 91900. Average reward per game:  -0.096755 , Elapsed time  714.09  minutes.
# Iteration: 92000. Average reward per game:  -0.140611 , Elapsed time  714.89  minutes.
# Iteration: 92100. Average reward per game:  -0.054277 , Elapsed time  715.46  minutes.
# Iteration: 92200. Average reward per game:  -0.060193 , Elapsed time  716.06  minutes.
# Iteration: 92300. Average reward per game:  -0.091263 , Elapsed time  716.73  minutes.
# Iteration: 92400. Average reward per game:  -0.069015 , Elapsed time  717.4  minutes.
# Iteration: 92500. Average reward per game:  -0.039065 , Elapsed time  718.12  minutes.
# Iteration: 92600. Average reward per game:  -0.051076 , Elapsed time  718.67  minutes.
# Iteration: 92700. Average reward per game:  -0.035045 , Elapsed time  719.37  minutes.
# Iteration: 92800. Average reward per game:  -0.078655 , Elapsed time  720.06  minutes.
# Iteration: 92900. Average reward per game:  -0.05236 , Elapsed time  720.71  minutes.
# Iteration: 93000. Average reward per game:  -0.057397 , Elapsed time  721.29  minutes.
# Iteration: 93100. Average reward per game:  -0.036333 , Elapsed time  721.93  minutes.
# Iteration: 93200. Average reward per game:  -0.049075 , Elapsed time  722.66  minutes.
# Iteration: 93300. Average reward per game:  -0.051563 , Elapsed time  723.26  minutes.
# Iteration: 93400. Average reward per game:  -0.020993 , Elapsed time  724.03  minutes.
# Iteration: 93500. Average reward per game:  -0.025913 , Elapsed time  724.66  minutes.
# Iteration: 93600. Average reward per game:  -0.041518 , Elapsed time  725.36  minutes.
# Iteration: 93700. Average reward per game:  -0.032333 , Elapsed time  725.99  minutes.
# Iteration: 93800. Average reward per game:  -0.036749 , Elapsed time  726.72  minutes.
# Iteration: 93900. Average reward per game:  -0.037321 , Elapsed time  727.31  minutes.
# Iteration: 94000. Average reward per game:  -0.043806 , Elapsed time  728.1  minutes.
# Iteration: 94100. Average reward per game:  -0.037852 , Elapsed time  728.72  minutes.
# Iteration: 94200. Average reward per game:  -0.023898 , Elapsed time  729.47  minutes.
# Iteration: 94300. Average reward per game:  -0.058792 , Elapsed time  730.13  minutes.
# Iteration: 94400. Average reward per game:  -0.055199 , Elapsed time  730.69  minutes.
# Iteration: 94500. Average reward per game:  -0.026024 , Elapsed time  731.3  minutes.
# Iteration: 94600. Average reward per game:  -0.024027 , Elapsed time  732.0  minutes.
# Iteration: 94700. Average reward per game:  -0.040523 , Elapsed time  732.55  minutes.
# Iteration: 94800. Average reward per game:  -0.032972 , Elapsed time  733.31  minutes.
# Iteration: 94900. Average reward per game:  -0.037546 , Elapsed time  734.01  minutes.
# Iteration: 95000. Average reward per game:  -0.026063 , Elapsed time  734.73  minutes.
# Iteration: 95100. Average reward per game:  -0.036359 , Elapsed time  735.32  minutes.
# Iteration: 95200. Average reward per game:  -0.068698 , Elapsed time  736.03  minutes.
# Iteration: 95300. Average reward per game:  -0.031182 , Elapsed time  736.66  minutes.
# Iteration: 95400. Average reward per game:  -0.04878 , Elapsed time  737.46  minutes.
# Iteration: 95500. Average reward per game:  -0.051745 , Elapsed time  738.07  minutes.
# Iteration: 95600. Average reward per game:  -0.056803 , Elapsed time  738.81  minutes.
# Iteration: 95700. Average reward per game:  -0.073317 , Elapsed time  739.35  minutes.
# Iteration: 95800. Average reward per game:  -0.028739 , Elapsed time  740.11  minutes.
# Iteration: 95900. Average reward per game:  -0.044002 , Elapsed time  740.9  minutes.
# Iteration: 96000. Average reward per game:  -0.049487 , Elapsed time  741.61  minutes.
# Iteration: 96100. Average reward per game:  -0.035901 , Elapsed time  742.33  minutes.
# Iteration: 96200. Average reward per game:  -0.04019 , Elapsed time  742.92  minutes.
# Iteration: 96300. Average reward per game:  -0.033795 , Elapsed time  743.54  minutes.
# Iteration: 96400. Average reward per game:  -0.050547 , Elapsed time  744.25  minutes.
# Iteration: 96500. Average reward per game:  -0.050615 , Elapsed time  744.94  minutes.
# Iteration: 96600. Average reward per game:  -0.070809 , Elapsed time  745.57  minutes.
# Iteration: 96700. Average reward per game:  -0.095088 , Elapsed time  746.19  minutes.
# Iteration: 96800. Average reward per game:  -0.077924 , Elapsed time  746.93  minutes.
# Iteration: 96900. Average reward per game:  -0.067724 , Elapsed time  747.53  minutes.
# Iteration: 97000. Average reward per game:  -0.074813 , Elapsed time  748.3  minutes.
# Iteration: 97100. Average reward per game:  -0.03869 , Elapsed time  748.94  minutes.
# Iteration: 97200. Average reward per game:  -0.033265 , Elapsed time  749.71  minutes.
# Iteration: 97300. Average reward per game:  -0.104583 , Elapsed time  750.33  minutes.
# Iteration: 97400. Average reward per game:  -0.004856 , Elapsed time  750.98  minutes.
# Iteration: 97500. Average reward per game:  -0.030861 , Elapsed time  751.74  minutes.
# Iteration: 97600. Average reward per game:  -0.015711 , Elapsed time  752.36  minutes.
# Iteration: 97700. Average reward per game:  -0.031663 , Elapsed time  753.06  minutes.
# Iteration: 97800. Average reward per game:  -0.032122 , Elapsed time  753.72  minutes.
# Iteration: 97900. Average reward per game:  -0.031648 , Elapsed time  754.4  minutes.
# Iteration: 98000. Average reward per game:  -0.056115 , Elapsed time  755.14  minutes.
# Iteration: 98100. Average reward per game:  -0.051036 , Elapsed time  755.71  minutes.
# Iteration: 98200. Average reward per game:  -0.036986 , Elapsed time  756.39  minutes.
# Iteration: 98300. Average reward per game:  -0.060923 , Elapsed time  757.02  minutes.
# Iteration: 98400. Average reward per game:  -0.035244 , Elapsed time  757.77  minutes.
# Iteration: 98500. Average reward per game:  -0.00988 , Elapsed time  758.45  minutes.
# Iteration: 98600. Average reward per game:  -0.019466 , Elapsed time  759.08  minutes.
# Iteration: 98700. Average reward per game:  -0.025991 , Elapsed time  759.87  minutes.
# Iteration: 98800. Average reward per game:  -0.044282 , Elapsed time  760.44  minutes.
# Iteration: 98900. Average reward per game:  -0.037983 , Elapsed time  761.06  minutes.
# Iteration: 99000. Average reward per game:  -0.077577 , Elapsed time  761.69  minutes.
# Iteration: 99100. Average reward per game:  -0.020216 , Elapsed time  762.37  minutes.
# Iteration: 99200. Average reward per game:  -0.046182 , Elapsed time  762.97  minutes.
# Iteration: 99300. Average reward per game:  -0.059984 , Elapsed time  763.68  minutes.
# Iteration: 99400. Average reward per game:  -0.022843 , Elapsed time  764.22  minutes.
# Iteration: 99500. Average reward per game:  -0.017218 , Elapsed time  764.95  minutes.
# Iteration: 99600. Average reward per game:  -0.030738 , Elapsed time  765.73  minutes.
# Iteration: 99700. Average reward per game:  -0.048226 , Elapsed time  766.33  minutes.
# Iteration: 99800. Average reward per game:  -0.036279 , Elapsed time  767.03  minutes.
# Iteration: 99900. Average reward per game:  -0.038719 , Elapsed time  767.73  minutes.
# Iteration: 100000. Average reward per game:  -0.058699 , Elapsed time  768.36  minutes.
# Simulation finished. Elapsed time  768.36  minutes.

# %% [markdown]
# ## Visualizations

# %%
# Visualizing train simulation:

#episode =episodes
#simulation_id = 2
#step = 30

discrewards = pd.read_table(rewards_file, sep = ",")

indices = [i for i in range(0,n_iterations,1)]

plt.plot(discrewards['iteration'][indices],discrewards['discreward'][indices], label = "Discounted rewards")
plt.title("Discounted rewards per episode during training")
plt.xlabel("Episode")
plt.ylabel("Discounted reward")

plt.savefig(simulation_directory + '/discounted-rewards-sim' + '{}'.format(simulation_id) + '.pdf')

plt.show()
plt.close()

# %% [markdown]
# # PG Testing

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 1

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 


with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
               
        env.close()
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation325/NN-models/pdenv_best_policy_net_pg.ckpt

# %% [markdown]
# ## Giff animation

# %%
test_anim = ut.create_system_animation(frames, n_episodes * episode_length)
plt.close()

HTML(test_anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## Visualization with matplotlib

# %%
from utils_pg import is_empty
from utils_pg import my_indicator

def visualize_simulation(states_file,
                        test_toy_system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list):
    test_states = pd.read_table(states_file, sep = ",")
    test_states.head()


    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, n)]
    lvl_colors = ["Orange", "Green","Orange"]

    #tanks = test_toy_system.tanks
    tanks_max_load = system.tank_max_loads
    level_percentages = system.load_level_percentages

    for i, color in enumerate(colors, start=1):    
        plt.subplot(2,3,i)
        states = test_states['stock{}'.format(i-1)]
        plt.plot(test_states['step'],states, label = "Shop {}".format(i-1), color = "Black")
        plt.title("Shop {}".format(i-1))

        plt.axhline(y= tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = "Red", linestyle = '--')
        for lvl_color, lvl in zip(lvl_colors, level_percentages[i-1]):
            plt.axhline(y= lvl * tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = lvl_color, 
                        linestyle = '--')
        plt.axhline(y= 0, xmin=0, xmax=episode_length, hold=None, color = "Red", linestyle = '--')


        percentages = level_percentages[i-1]           
        c = percentages[1]
        e = percentages[2]          
        d = ct.p0_GLOBAL*e+(1-ct.p0_GLOBAL)*c
        plt.axhline(y= d*tanks_max_load[i-1], xmin=0, xmax=episode_length, hold=None, color = "lawngreen", 
                    linestyle = '-.')

        plt.axhline(y= np.mean(states), xmin=0, xmax=episode_length, hold=None, 
                    color = "blue", linestyle = '-.')
        plt.xticks(range(0,episode_length*n_episodes+1,5*n_episodes
                        ))
        
        #################### INFO LEVELS
        b = percentages[0]
        level_counts = np.zeros(5, dtype = np.int64)
        
        x_mins = np.array([0,b,c,e])*tanks_max_load[i-1]
        x_maxs = np.array([b,c,e,1])*tanks_max_load[i-1]

        for x in states:
            level_counts[0] = level_counts[0] + is_empty(x)
            for j in range(1,5):
                level_counts[j] = level_counts[j] + my_indicator(x_mins[j-1], x, x_maxs[j-1])
            
        level_counts_list.append(level_counts)
        ###################################################

    plt.subplot(2,3,6)
    plt.title("Legend")
    plt.axis('off')

    #plt.legend(bbox_to_anchor=(0.5 ,0.8), loc=2, borderaxespad=0.)
    plt.yticks([])
    plt.xticks([])

    patch1 = mpatches.Patch(color='red', label='Max/Min capacities', linestyle = '--', fill = False, linewidth = 2)
    patch2 = mpatches.Patch(color='orange', label='Max/Min levels', linestyle = '--', fill = False, linewidth = 2)
    patch3 = mpatches.Patch(color='green', label='Danger level', linestyle = '--', fill = False, linewidth = 2)
    patch4 = mpatches.Patch(color='lawngreen', label='Max reward level (M)', linestyle = '-.', fill = False, linewidth = 2)
    patch5 = mpatches.Patch(color='blue', label='Observed mean level', linestyle = '-.', fill = False, linewidth = 2)
    patch6 = mpatches.Patch(color='black', label='Current stock level', linestyle = '-', fill = False, linewidth = 2)


    plt.legend(handles=[patch1, patch2, patch3, patch4, patch5, patch6], loc = 'center')

    plt.tight_layout() 
    plt.savefig(simulation_directory + '/tank-levels-sim' + '{}'.format(simulation_id) + '.pdf')
    plt.show()
    plt.close()

# %%
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list)

# %% [markdown]
# ## Performance metrics

# %%
seed = 45 # this seed determines the initialization of the system when calling env.reset() ,etc
np.random.seed(seed)

frames = []
n_episodes = 1

system = PDSystemEnv()
#model_file = "pdenv_policy_net_pg.ckpt"
test_model_file = best_model_file

with open(states_file,'w') as f:
         np.savetxt(f, [["step", "stock0", "stock1", "stock2","stock3", "stock4"]], fmt="%s", delimiter=',') 

####
test_visualization_steps = []
test_rewards_list = []
test_level_rewards_list = []
test_transport_rewards_list = []
test_trucks_sent_list = []
test_number_of_first_trucks_sent_list = []
test_number_of_second_trucks_sent_list = []
test_number_of_trucks_not_deliverying_list = []
####

with tf.Session() as sess:
        sess.run(init)
        saver.restore(sess, test_model_file)
        for episode in range(n_episodes):
            #####
            discounted_reward = 0 
            transport_rewards = 0
            level_rewards = 0
            number_of_trucks_sent = 0
            number_of_first_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_second_trucks_sent = np.zeros(n+1, dtype = np.int64)
            number_of_trucks_not_deliverying = 0                   
            #####         
         
            state = env.reset()
            for step in range(episode_length):
                system.state = state
                with open(states_file,'ab') as f:
                    np.savetxt(f, [np.array([(episode)*(episode_length)+step]+state.tolist())], fmt=("%d",'%.3f','%.3f','%.3f','%.3f','%.3f'), delimiter=',') 
                img = system.visualize()
                frames.append(img)

                action_val = test_action.eval(feed_dict={X: state.reshape(1, n_inputs)})
                #print(action_val)
                vect_action = int_to_action(action_val,env) #HERE WE CONVERT FROM INTEGER TO ACTION's Array
                #print(vect_action)
                state, reward, done, info = env.step(vect_action)
            
                trucks_not_del = info["trucks_not_deliverying"]
                level_reward = info["level_rewards"]
                transport_reward = info["transport_rewards"]
                ### STORE STEP INFO
                discounted_reward = discounted_reward + (discount_rate**(step)) * reward
                transport_rewards = transport_rewards+transport_reward
                level_rewards = level_rewards + level_reward
                
                number_of_trucks_sent = number_of_trucks_sent + np.sum(vect_action == 5)
                index1 = vect_action[0]
                number_of_first_trucks_sent[index1] = number_of_first_trucks_sent[index1] + 1
                index2 = vect_action[1]
                number_of_second_trucks_sent[index2] = number_of_second_trucks_sent[index2] + 1
                number_of_trucks_not_deliverying =  number_of_trucks_not_deliverying + trucks_not_del
                
            test_rewards_list.append(discounted_reward);
            test_transport_rewards_list.append(transport_rewards);
            test_level_rewards_list.append(level_rewards);
            test_trucks_sent_list.append(episode_length * system.k - number_of_trucks_sent);
            test_number_of_first_trucks_sent_list.append(number_of_first_trucks_sent);
            test_number_of_second_trucks_sent_list.append(number_of_second_trucks_sent);
            test_number_of_trucks_not_deliverying_list.append(number_of_trucks_not_deliverying);                   
                
               
        env.close()
        
test_level_counts_list = []

visualize_simulation(states_file,
                        system,
                        simulation_id,
                        simulation_directory,
                        level_counts_list = test_level_counts_list) 

print("Total discounted rewards","Level rewards", "Transport rewards")
print(sum(test_rewards_list)/n_episodes, sum(test_level_rewards_list)/n_episodes,sum(test_transport_rewards_list)/n_episodes )
print("Average trucks sent: ", sum(test_trucks_sent_list)/n_episodes)
    
#     if n_episodes == 1:
first_type = sum(test_number_of_first_trucks_sent_list)/n_episodes
print("Average 1st type Trucks sent to each shop:", first_type)
print("Average 1st type Trucks sent:", sum(first_type[0:n] ) )

second_type = sum(test_number_of_second_trucks_sent_list)/n_episodes
print("Average 2nd type Trucks sent to each shop:", second_type)
print("Average 2nd type Trucks sent:",  sum(second_type[0:n] ))

print("Average number of trucks not deliverying:", sum(test_number_of_trucks_not_deliverying_list)/n_episodes )

for i in range(n):
        print("Average level counts for shop {}:".format(i), test_level_counts_list[i]/n_episodes )

        
print("Average total level counts:", sum(test_level_counts_list)/n_episodes )
print("Percentage total level counts:", (sum(test_level_counts_list)/n_episodes)/(episode_length * n) * 100 )
# Out:
# INFO:tensorflow:Restoring parameters from ./simulations/simulation325/NN-models/pdenv_best_policy_net_pg.ckpt
# Total discounted rewards Level rewards Transport rewards
# -113262.73937622359 -1012349.7025437348 34223.40575999999
# Average trucks sent:  49.0
# Average 1st type Trucks sent to each shop: [ 6.  2.  5.  3. 14.  0.]
# Average 1st type Trucks sent: 30.0
# Average 2nd type Trucks sent to each shop: [ 0.  0.  0. 19.  0. 11.]
# Average 2nd type Trucks sent: 19.0
# Average number of trucks not deliverying: 0.0
# Average level counts for shop 0: [ 0.  0. 11. 19.  0.]
# Average level counts for shop 1: [ 0.  0.  0. 30.  0.]
# Average level counts for shop 2: [ 1.  0.  4. 25.  0.]
# Average level counts for shop 3: [ 0.  0.  2. 28.  0.]
# Average level counts for shop 4: [ 0.  1.  8. 21.  0.]
# Average total level counts: [  1.   1.  25. 123.   0.]
# Percentage total level counts: [ 0.66666667  0.66666667 16.66666667 82.          0.        ]
